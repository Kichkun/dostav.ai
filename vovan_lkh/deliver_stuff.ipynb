# %%
import json
import matplotlib.pyplot as plt
import numpy as np

DATA_PATH = 'workdir/data/contest_input_filtered.json'

json_file = json.load(open(DATA_PATH, 'r'))

# %%
orders
# Out:
# {'10001': {'order_id': 10001,
#   'pickup_point_id': 40001,
#   'pickup_from': 480,
#   'pickup_to': 570,
#   'pickup_location_x': 284,
#   'pickup_location_y': 235,
#   'dropoff_point_id': 60001,
#   'dropoff_from': 600,
#   'dropoff_to': 960,
#   'dropoff_location_x': 252,
#   'dropoff_location_y': 197,
#   'payment': 313},
#  '10003': {'order_id': 10003,
#   'pickup_point_id': 40003,
#   'pickup_from': 390,
#   'pickup_to': 1020,
#   'pickup_location_x': 225,
#   'pickup_location_y': 141,
#   'dropoff_point_id': 60003,
#   'dropoff_from': 1050,
#   'dropoff_to': 1080,
#   'dropoff_location_x': 115,
#   'dropoff_location_y': 38,
#   'payment': 380},
#  '10005': {'order_id': 10005,
#   'pickup_point_id': 40005,
#   'pickup_from': 300,
#   'pickup_to': 780,
#   'pickup_location_x': 233,
#   'pickup_location_y': 108,
#   'dropoff_point_id': 60005,
#   'dropoff_from': 840,
#   'dropoff_to': 870,
#   'dropoff_location_x': 12,
#   'dropoff_location_y': 101,
#   'payment': 482},
#  '10008': {'order_id': 10008,
#   'pickup_point_id': 40008,
#   'pickup_from': 360,
#   'pickup_to': 480,
#   'pickup_location_x': 241,
#   'pickup_location_y': 203,
#   'dropoff_point_id': 60008,
#   'dropoff_from': 420,
#   'dropoff_to': 780,
#   'dropoff_location_x': 193,
#   'dropoff_location_y': 112,
#   'payment': 337},
#  '10010': {'order_id': 10010,
#   'pickup_point_id': 40010,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 114,
#   'pickup_location_y': 48,
#   'dropoff_point_id': 60010,
#   'dropoff_from': 480,
#   'dropoff_to': 960,
#   'dropoff_location_x': 293,
#   'dropoff_location_y': 70,
#   'payment': 500},
#  '10011': {'order_id': 10011,
#   'pickup_point_id': 40011,
#   'pickup_from': 600,
#   'pickup_to': 840,
#   'pickup_location_x': 317,
#   'pickup_location_y': 143,
#   'dropoff_point_id': 60011,
#   'dropoff_from': 600,
#   'dropoff_to': 840,
#   'dropoff_location_x': 136,
#   'dropoff_location_y': 135,
#   'payment': 310},
#  '10012': {'order_id': 10012,
#   'pickup_point_id': 40012,
#   'pickup_from': 480,
#   'pickup_to': 540,
#   'pickup_location_x': 217,
#   'pickup_location_y': 145,
#   'dropoff_point_id': 60012,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 209,
#   'dropoff_location_y': 10,
#   'payment': 372},
#  '10013': {'order_id': 10013,
#   'pickup_point_id': 40013,
#   'pickup_from': 480,
#   'pickup_to': 540,
#   'pickup_location_x': 217,
#   'pickup_location_y': 145,
#   'dropoff_point_id': 60013,
#   'dropoff_from': 660,
#   'dropoff_to': 720,
#   'dropoff_location_x': 220,
#   'dropoff_location_y': 119,
#   'payment': 244},
#  '10014': {'order_id': 10014,
#   'pickup_point_id': 40014,
#   'pickup_from': 480,
#   'pickup_to': 840,
#   'pickup_location_x': 161,
#   'pickup_location_y': 153,
#   'dropoff_point_id': 60014,
#   'dropoff_from': 750,
#   'dropoff_to': 930,
#   'dropoff_location_x': 167,
#   'dropoff_location_y': 155,
#   'payment': 155},
#  '10015': {'order_id': 10015,
#   'pickup_point_id': 40015,
#   'pickup_from': 540,
#   'pickup_to': 570,
#   'pickup_location_x': 160,
#   'pickup_location_y': 136,
#   'dropoff_point_id': 60015,
#   'dropoff_from': 600,
#   'dropoff_to': 780,
#   'dropoff_location_x': 268,
#   'dropoff_location_y': 91,
#   'payment': 352},
#  '10016': {'order_id': 10016,
#   'pickup_point_id': 40016,
#   'pickup_from': 450,
#   'pickup_to': 510,
#   'pickup_location_x': 211,
#   'pickup_location_y': 118,
#   'dropoff_point_id': 60016,
#   'dropoff_from': 510,
#   'dropoff_to': 570,
#   'dropoff_location_x': 199,
#   'dropoff_location_y': 128,
#   'payment': 284},
#  '10017': {'order_id': 10017,
#   'pickup_point_id': 40017,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 208,
#   'pickup_location_y': 284,
#   'dropoff_point_id': 60017,
#   'dropoff_from': 420,
#   'dropoff_to': 660,
#   'dropoff_location_x': 202,
#   'dropoff_location_y': 208,
#   'payment': 260},
#  '10018': {'order_id': 10018,
#   'pickup_point_id': 40018,
#   'pickup_from': 420,
#   'pickup_to': 540,
#   'pickup_location_x': 222,
#   'pickup_location_y': 210,
#   'dropoff_point_id': 60018,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 120,
#   'dropoff_location_y': 232,
#   'payment': 370},
#  '10019': {'order_id': 10019,
#   'pickup_point_id': 40019,
#   'pickup_from': 360,
#   'pickup_to': 420,
#   'pickup_location_x': 177,
#   'pickup_location_y': 188,
#   'dropoff_point_id': 60019,
#   'dropoff_from': 660,
#   'dropoff_to': 780,
#   'dropoff_location_x': 211,
#   'dropoff_location_y': 229,
#   'payment': 431},
#  '10020': {'order_id': 10020,
#   'pickup_point_id': 40020,
#   'pickup_from': 420,
#   'pickup_to': 600,
#   'pickup_location_x': 266,
#   'pickup_location_y': 75,
#   'dropoff_point_id': 60020,
#   'dropoff_from': 420,
#   'dropoff_to': 840,
#   'dropoff_location_x': 150,
#   'dropoff_location_y': 159,
#   'payment': 291},
#  '10021': {'order_id': 10021,
#   'pickup_point_id': 40021,
#   'pickup_from': 570,
#   'pickup_to': 600,
#   'pickup_location_x': 201,
#   'pickup_location_y': 143,
#   'dropoff_point_id': 60021,
#   'dropoff_from': 660,
#   'dropoff_to': 810,
#   'dropoff_location_x': 236,
#   'dropoff_location_y': 126,
#   'payment': 342},
#  '10022': {'order_id': 10022,
#   'pickup_point_id': 40022,
#   'pickup_from': 540,
#   'pickup_to': 780,
#   'pickup_location_x': 343,
#   'pickup_location_y': 109,
#   'dropoff_point_id': 60022,
#   'dropoff_from': 540,
#   'dropoff_to': 780,
#   'dropoff_location_x': 273,
#   'dropoff_location_y': 113,
#   'payment': 302},
#  '10023': {'order_id': 10023,
#   'pickup_point_id': 40023,
#   'pickup_from': 480,
#   'pickup_to': 720,
#   'pickup_location_x': 237,
#   'pickup_location_y': 137,
#   'dropoff_point_id': 60023,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 256,
#   'dropoff_location_y': 110,
#   'payment': 321},
#  '10024': {'order_id': 10024,
#   'pickup_point_id': 40024,
#   'pickup_from': 390,
#   'pickup_to': 750,
#   'pickup_location_x': 82,
#   'pickup_location_y': 14,
#   'dropoff_point_id': 60024,
#   'dropoff_from': 720,
#   'dropoff_to': 840,
#   'dropoff_location_x': 274,
#   'dropoff_location_y': 110,
#   'payment': 513},
#  '10025': {'order_id': 10025,
#   'pickup_point_id': 40025,
#   'pickup_from': 660,
#   'pickup_to': 900,
#   'pickup_location_x': 199,
#   'pickup_location_y': 149,
#   'dropoff_point_id': 60025,
#   'dropoff_from': 660,
#   'dropoff_to': 900,
#   'dropoff_location_x': 275,
#   'dropoff_location_y': 110,
#   'payment': 294},
#  '10028': {'order_id': 10028,
#   'pickup_point_id': 40028,
#   'pickup_from': 360,
#   'pickup_to': 600,
#   'pickup_location_x': 130,
#   'pickup_location_y': 131,
#   'dropoff_point_id': 60028,
#   'dropoff_from': 420,
#   'dropoff_to': 840,
#   'dropoff_location_x': 26,
#   'dropoff_location_y': 138,
#   'payment': 650},
#  '10030': {'order_id': 10030,
#   'pickup_point_id': 40030,
#   'pickup_from': 420,
#   'pickup_to': 450,
#   'pickup_location_x': 167,
#   'pickup_location_y': 111,
#   'dropoff_point_id': 60030,
#   'dropoff_from': 450,
#   'dropoff_to': 540,
#   'dropoff_location_x': 149,
#   'dropoff_location_y': 75,
#   'payment': 346},
#  '10031': {'order_id': 10031,
#   'pickup_point_id': 40031,
#   'pickup_from': 330,
#   'pickup_to': 840,
#   'pickup_location_x': 207,
#   'pickup_location_y': 245,
#   'dropoff_point_id': 60031,
#   'dropoff_from': 960,
#   'dropoff_to': 1020,
#   'dropoff_location_x': 295,
#   'dropoff_location_y': 97,
#   'payment': 524},
#  '10033': {'order_id': 10033,
#   'pickup_point_id': 40033,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 170,
#   'pickup_location_y': 131,
#   'dropoff_point_id': 60033,
#   'dropoff_from': 540,
#   'dropoff_to': 780,
#   'dropoff_location_x': 146,
#   'dropoff_location_y': 55,
#   'payment': 293},
#  '10034': {'order_id': 10034,
#   'pickup_point_id': 40034,
#   'pickup_from': 510,
#   'pickup_to': 660,
#   'pickup_location_x': 136,
#   'pickup_location_y': 168,
#   'dropoff_point_id': 60034,
#   'dropoff_from': 510,
#   'dropoff_to': 810,
#   'dropoff_location_x': 229,
#   'dropoff_location_y': 77,
#   'payment': 385},
#  '10036': {'order_id': 10036,
#   'pickup_point_id': 40036,
#   'pickup_from': 450,
#   'pickup_to': 480,
#   'pickup_location_x': 195,
#   'pickup_location_y': 115,
#   'dropoff_point_id': 60036,
#   'dropoff_from': 540,
#   'dropoff_to': 600,
#   'dropoff_location_x': 182,
#   'dropoff_location_y': 88,
#   'payment': 242},
#  '10037': {'order_id': 10037,
#   'pickup_point_id': 40037,
#   'pickup_from': 450,
#   'pickup_to': 480,
#   'pickup_location_x': 268,
#   'pickup_location_y': 185,
#   'dropoff_point_id': 60037,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 218,
#   'dropoff_location_y': 121,
#   'payment': 317},
#  '10038': {'order_id': 10038,
#   'pickup_point_id': 40038,
#   'pickup_from': 570,
#   'pickup_to': 600,
#   'pickup_location_x': 201,
#   'pickup_location_y': 143,
#   'dropoff_point_id': 60038,
#   'dropoff_from': 660,
#   'dropoff_to': 810,
#   'dropoff_location_x': 236,
#   'dropoff_location_y': 126,
#   'payment': 342},
#  '10039': {'order_id': 10039,
#   'pickup_point_id': 40039,
#   'pickup_from': 420,
#   'pickup_to': 960,
#   'pickup_location_x': 173,
#   'pickup_location_y': 171,
#   'dropoff_point_id': 60039,
#   'dropoff_from': 480,
#   'dropoff_to': 960,
#   'dropoff_location_x': 140,
#   'dropoff_location_y': 102,
#   'payment': 287},
#  '10042': {'order_id': 10042,
#   'pickup_point_id': 40042,
#   'pickup_from': 390,
#   'pickup_to': 720,
#   'pickup_location_x': 195,
#   'pickup_location_y': 115,
#   'dropoff_point_id': 60042,
#   'dropoff_from': 780,
#   'dropoff_to': 900,
#   'dropoff_location_x': 307,
#   'dropoff_location_y': 72,
#   'payment': 348},
#  '10043': {'order_id': 10043,
#   'pickup_point_id': 40043,
#   'pickup_from': 330,
#   'pickup_to': 570,
#   'pickup_location_x': 247,
#   'pickup_location_y': 124,
#   'dropoff_point_id': 60043,
#   'dropoff_from': 600,
#   'dropoff_to': 840,
#   'dropoff_location_x': 308,
#   'dropoff_location_y': 27,
#   'payment': 309},
#  '10045': {'order_id': 10045,
#   'pickup_point_id': 40045,
#   'pickup_from': 420,
#   'pickup_to': 720,
#   'pickup_location_x': 223,
#   'pickup_location_y': 143,
#   'dropoff_point_id': 60045,
#   'dropoff_from': 420,
#   'dropoff_to': 900,
#   'dropoff_location_x': 242,
#   'dropoff_location_y': 119,
#   'payment': 242},
#  '10046': {'order_id': 10046,
#   'pickup_point_id': 40046,
#   'pickup_from': 450,
#   'pickup_to': 690,
#   'pickup_location_x': 223,
#   'pickup_location_y': 160,
#   'dropoff_point_id': 60046,
#   'dropoff_from': 660,
#   'dropoff_to': 900,
#   'dropoff_location_x': 155,
#   'dropoff_location_y': 136,
#   'payment': 238},
#  '10047': {'order_id': 10047,
#   'pickup_point_id': 40047,
#   'pickup_from': 390,
#   'pickup_to': 450,
#   'pickup_location_x': 206,
#   'pickup_location_y': 246,
#   'dropoff_point_id': 60047,
#   'dropoff_from': 540,
#   'dropoff_to': 570,
#   'dropoff_location_x': 241,
#   'dropoff_location_y': 134,
#   'payment': 426},
#  '10048': {'order_id': 10048,
#   'pickup_point_id': 40048,
#   'pickup_from': 420,
#   'pickup_to': 810,
#   'pickup_location_x': 180,
#   'pickup_location_y': 129,
#   'dropoff_point_id': 60048,
#   'dropoff_from': 420,
#   'dropoff_to': 840,
#   'dropoff_location_x': 207,
#   'dropoff_location_y': 80,
#   'payment': 224},
#  '10049': {'order_id': 10049,
#   'pickup_point_id': 40049,
#   'pickup_from': 420,
#   'pickup_to': 600,
#   'pickup_location_x': 229,
#   'pickup_location_y': 126,
#   'dropoff_point_id': 60049,
#   'dropoff_from': 420,
#   'dropoff_to': 720,
#   'dropoff_location_x': 187,
#   'dropoff_location_y': 141,
#   'payment': 287},
#  '10050': {'order_id': 10050,
#   'pickup_point_id': 40050,
#   'pickup_from': 630,
#   'pickup_to': 660,
#   'pickup_location_x': 225,
#   'pickup_location_y': 141,
#   'dropoff_point_id': 60050,
#   'dropoff_from': 690,
#   'dropoff_to': 720,
#   'dropoff_location_x': 234,
#   'dropoff_location_y': 192,
#   'payment': 380},
#  '10051': {'order_id': 10051,
#   'pickup_point_id': 40051,
#   'pickup_from': 390,
#   'pickup_to': 510,
#   'pickup_location_x': 305,
#   'pickup_location_y': 1,
#   'dropoff_point_id': 60051,
#   'dropoff_from': 390,
#   'dropoff_to': 690,
#   'dropoff_location_x': 164,
#   'dropoff_location_y': 120,
#   'payment': 547},
#  '10055': {'order_id': 10055,
#   'pickup_point_id': 40055,
#   'pickup_from': 420,
#   'pickup_to': 600,
#   'pickup_location_x': 141,
#   'pickup_location_y': 19,
#   'dropoff_point_id': 60055,
#   'dropoff_from': 600,
#   'dropoff_to': 1140,
#   'dropoff_location_x': 274,
#   'dropoff_location_y': 222,
#   'payment': 520},
#  '10057': {'order_id': 10057,
#   'pickup_point_id': 40057,
#   'pickup_from': 540,
#   'pickup_to': 840,
#   'pickup_location_x': 188,
#   'pickup_location_y': 136,
#   'dropoff_point_id': 60057,
#   'dropoff_from': 540,
#   'dropoff_to': 840,
#   'dropoff_location_x': 231,
#   'dropoff_location_y': 120,
#   'payment': 188},
#  '10058': {'order_id': 10058,
#   'pickup_point_id': 40058,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 246,
#   'pickup_location_y': 63,
#   'dropoff_point_id': 60058,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 44,
#   'dropoff_location_y': 119,
#   'payment': 448},
#  '10059': {'order_id': 10059,
#   'pickup_point_id': 40059,
#   'pickup_from': 450,
#   'pickup_to': 510,
#   'pickup_location_x': 171,
#   'pickup_location_y': 177,
#   'dropoff_point_id': 60059,
#   'dropoff_from': 480,
#   'dropoff_to': 540,
#   'dropoff_location_x': 207,
#   'dropoff_location_y': 162,
#   'payment': 403},
#  '10060': {'order_id': 10060,
#   'pickup_point_id': 40060,
#   'pickup_from': 420,
#   'pickup_to': 720,
#   'pickup_location_x': 186,
#   'pickup_location_y': 125,
#   'dropoff_point_id': 60060,
#   'dropoff_from': 420,
#   'dropoff_to': 870,
#   'dropoff_location_x': 262,
#   'dropoff_location_y': 4,
#   'payment': 353},
#  '10061': {'order_id': 10061,
#   'pickup_point_id': 40061,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 234,
#   'pickup_location_y': 137,
#   'dropoff_point_id': 60061,
#   'dropoff_from': 450,
#   'dropoff_to': 810,
#   'dropoff_location_x': 180,
#   'dropoff_location_y': 143,
#   'payment': 354},
#  '10062': {'order_id': 10062,
#   'pickup_point_id': 40062,
#   'pickup_from': 390,
#   'pickup_to': 630,
#   'pickup_location_x': 127,
#   'pickup_location_y': 16,
#   'dropoff_point_id': 60062,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 268,
#   'dropoff_location_y': 109,
#   'payment': 483},
#  '10063': {'order_id': 10063,
#   'pickup_point_id': 40063,
#   'pickup_from': 510,
#   'pickup_to': 570,
#   'pickup_location_x': 243,
#   'pickup_location_y': 178,
#   'dropoff_point_id': 60063,
#   'dropoff_from': 570,
#   'dropoff_to': 660,
#   'dropoff_location_x': 236,
#   'dropoff_location_y': 150,
#   'payment': 262},
#  '10065': {'order_id': 10065,
#   'pickup_point_id': 40065,
#   'pickup_from': 300,
#   'pickup_to': 540,
#   'pickup_location_x': 315,
#   'pickup_location_y': 108,
#   'dropoff_point_id': 60065,
#   'dropoff_from': 300,
#   'dropoff_to': 780,
#   'dropoff_location_x': 289,
#   'dropoff_location_y': 116,
#   'payment': 181},
#  '10066': {'order_id': 10066,
#   'pickup_point_id': 40066,
#   'pickup_from': 510,
#   'pickup_to': 750,
#   'pickup_location_x': 274,
#   'pickup_location_y': 112,
#   'dropoff_point_id': 60066,
#   'dropoff_from': 660,
#   'dropoff_to': 900,
#   'dropoff_location_x': 275,
#   'dropoff_location_y': 139,
#   'payment': 271},
#  '10067': {'order_id': 10067,
#   'pickup_point_id': 40067,
#   'pickup_from': 450,
#   'pickup_to': 510,
#   'pickup_location_x': 171,
#   'pickup_location_y': 177,
#   'dropoff_point_id': 60067,
#   'dropoff_from': 480,
#   'dropoff_to': 540,
#   'dropoff_location_x': 207,
#   'dropoff_location_y': 162,
#   'payment': 403},
#  '10069': {'order_id': 10069,
#   'pickup_point_id': 40069,
#   'pickup_from': 420,
#   'pickup_to': 960,
#   'pickup_location_x': 16,
#   'pickup_location_y': 98,
#   'dropoff_point_id': 60069,
#   'dropoff_from': 960,
#   'dropoff_to': 1050,
#   'dropoff_location_x': 127,
#   'dropoff_location_y': 96,
#   'payment': 400},
#  '10070': {'order_id': 10070,
#   'pickup_point_id': 40070,
#   'pickup_from': 450,
#   'pickup_to': 780,
#   'pickup_location_x': 201,
#   'pickup_location_y': 105,
#   'dropoff_point_id': 60070,
#   'dropoff_from': 480,
#   'dropoff_to': 900,
#   'dropoff_location_x': 195,
#   'dropoff_location_y': 146,
#   'payment': 225},
#  '10071': {'order_id': 10071,
#   'pickup_point_id': 40071,
#   'pickup_from': 450,
#   'pickup_to': 600,
#   'pickup_location_x': 122,
#   'pickup_location_y': 210,
#   'dropoff_point_id': 60071,
#   'dropoff_from': 480,
#   'dropoff_to': 840,
#   'dropoff_location_x': 344,
#   'dropoff_location_y': 148,
#   'payment': 553},
#  '10072': {'order_id': 10072,
#   'pickup_point_id': 40072,
#   'pickup_from': 390,
#   'pickup_to': 480,
#   'pickup_location_x': 298,
#   'pickup_location_y': 19,
#   'dropoff_point_id': 60072,
#   'dropoff_from': 420,
#   'dropoff_to': 660,
#   'dropoff_location_x': 231,
#   'dropoff_location_y': 103,
#   'payment': 318},
#  '10073': {'order_id': 10073,
#   'pickup_point_id': 40073,
#   'pickup_from': 360,
#   'pickup_to': 600,
#   'pickup_location_x': 249,
#   'pickup_location_y': 94,
#   'dropoff_point_id': 60073,
#   'dropoff_from': 360,
#   'dropoff_to': 840,
#   'dropoff_location_x': 176,
#   'dropoff_location_y': 168,
#   'payment': 231},
#  '10074': {'order_id': 10074,
#   'pickup_point_id': 40074,
#   'pickup_from': 510,
#   'pickup_to': 540,
#   'pickup_location_x': 210,
#   'pickup_location_y': 218,
#   'dropoff_point_id': 60074,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 295,
#   'dropoff_location_y': 214,
#   'payment': 352},
#  '10076': {'order_id': 10076,
#   'pickup_point_id': 40076,
#   'pickup_from': 420,
#   'pickup_to': 450,
#   'pickup_location_x': 253,
#   'pickup_location_y': 164,
#   'dropoff_point_id': 60076,
#   'dropoff_from': 450,
#   'dropoff_to': 600,
#   'dropoff_location_x': 332,
#   'dropoff_location_y': 144,
#   'payment': 552},
#  '10078': {'order_id': 10078,
#   'pickup_point_id': 40078,
#   'pickup_from': 450,
#   'pickup_to': 690,
#   'pickup_location_x': 245,
#   'pickup_location_y': 141,
#   'dropoff_point_id': 60078,
#   'dropoff_from': 450,
#   'dropoff_to': 690,
#   'dropoff_location_x': 251,
#   'dropoff_location_y': 110,
#   'payment': 187},
#  '10081': {'order_id': 10081,
#   'pickup_point_id': 40081,
#   'pickup_from': 480,
#   'pickup_to': 540,
#   'pickup_location_x': 328,
#   'pickup_location_y': 111,
#   'dropoff_point_id': 60081,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 207,
#   'dropoff_location_y': 195,
#   'payment': 447},
#  '10082': {'order_id': 10082,
#   'pickup_point_id': 40082,
#   'pickup_from': 420,
#   'pickup_to': 1050,
#   'pickup_location_x': 332,
#   'pickup_location_y': 40,
#   'dropoff_point_id': 60082,
#   'dropoff_from': 960,
#   'dropoff_to': 1200,
#   'dropoff_location_x': 310,
#   'dropoff_location_y': 30,
#   'payment': 333},
#  '10083': {'order_id': 10083,
#   'pickup_point_id': 40083,
#   'pickup_from': 540,
#   'pickup_to': 660,
#   'pickup_location_x': 163,
#   'pickup_location_y': 117,
#   'dropoff_point_id': 60083,
#   'dropoff_from': 540,
#   'dropoff_to': 780,
#   'dropoff_location_x': 319,
#   'dropoff_location_y': 154,
#   'payment': 470},
#  '10084': {'order_id': 10084,
#   'pickup_point_id': 40084,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 215,
#   'pickup_location_y': 107,
#   'dropoff_point_id': 60084,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 261,
#   'dropoff_location_y': 100,
#   'payment': 331},
#  '10086': {'order_id': 10086,
#   'pickup_point_id': 40086,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 216,
#   'pickup_location_y': 218,
#   'dropoff_point_id': 60086,
#   'dropoff_from': 510,
#   'dropoff_to': 600,
#   'dropoff_location_x': 277,
#   'dropoff_location_y': 137,
#   'payment': 376},
#  '10087': {'order_id': 10087,
#   'pickup_point_id': 40087,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 230,
#   'pickup_location_y': 110,
#   'dropoff_point_id': 60087,
#   'dropoff_from': 600,
#   'dropoff_to': 840,
#   'dropoff_location_x': 297,
#   'dropoff_location_y': 13,
#   'payment': 329},
#  '10088': {'order_id': 10088,
#   'pickup_point_id': 40088,
#   'pickup_from': 390,
#   'pickup_to': 840,
#   'pickup_location_x': 286,
#   'pickup_location_y': 130,
#   'dropoff_point_id': 60088,
#   'dropoff_from': 390,
#   'dropoff_to': 900,
#   'dropoff_location_x': 220,
#   'dropoff_location_y': 139,
#   'payment': 210},
#  '10089': {'order_id': 10089,
#   'pickup_point_id': 40089,
#   'pickup_from': 330,
#   'pickup_to': 360,
#   'pickup_location_x': 225,
#   'pickup_location_y': 141,
#   'dropoff_point_id': 60089,
#   'dropoff_from': 390,
#   'dropoff_to': 420,
#   'dropoff_location_x': 188,
#   'dropoff_location_y': 147,
#   'payment': 380},
#  '10090': {'order_id': 10090,
#   'pickup_point_id': 40090,
#   'pickup_from': 360,
#   'pickup_to': 480,
#   'pickup_location_x': 338,
#   'pickup_location_y': 168,
#   'dropoff_point_id': 60090,
#   'dropoff_from': 480,
#   'dropoff_to': 780,
#   'dropoff_location_x': 334,
#   'dropoff_location_y': 46,
#   'payment': 501},
#  '10091': {'order_id': 10091,
#   'pickup_point_id': 40091,
#   'pickup_from': 420,
#   'pickup_to': 540,
#   'pickup_location_x': 209,
#   'pickup_location_y': 166,
#   'dropoff_point_id': 60091,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 96,
#   'dropoff_location_y': 143,
#   'payment': 388},
#  '10092': {'order_id': 10092,
#   'pickup_point_id': 40092,
#   'pickup_from': 450,
#   'pickup_to': 570,
#   'pickup_location_x': 250,
#   'pickup_location_y': 185,
#   'dropoff_point_id': 60092,
#   'dropoff_from': 570,
#   'dropoff_to': 720,
#   'dropoff_location_x': 96,
#   'dropoff_location_y': 143,
#   'payment': 418},
#  '10093': {'order_id': 10093,
#   'pickup_point_id': 40093,
#   'pickup_from': 420,
#   'pickup_to': 540,
#   'pickup_location_x': 271,
#   'pickup_location_y': 216,
#   'dropoff_point_id': 60093,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 214,
#   'dropoff_location_y': 164,
#   'payment': 363},
#  '10094': {'order_id': 10094,
#   'pickup_point_id': 40094,
#   'pickup_from': 390,
#   'pickup_to': 450,
#   'pickup_location_x': 239,
#   'pickup_location_y': 138,
#   'dropoff_point_id': 60094,
#   'dropoff_from': 420,
#   'dropoff_to': 510,
#   'dropoff_location_x': 262,
#   'dropoff_location_y': 193,
#   'payment': 247},
#  '10095': {'order_id': 10095,
#   'pickup_point_id': 40095,
#   'pickup_from': 540,
#   'pickup_to': 780,
#   'pickup_location_x': 161,
#   'pickup_location_y': 177,
#   'dropoff_point_id': 60095,
#   'dropoff_from': 600,
#   'dropoff_to': 840,
#   'dropoff_location_x': 127,
#   'dropoff_location_y': 131,
#   'payment': 338},
#  '10096': {'order_id': 10096,
#   'pickup_point_id': 40096,
#   'pickup_from': 390,
#   'pickup_to': 450,
#   'pickup_location_x': 100,
#   'pickup_location_y': 143,
#   'dropoff_point_id': 60096,
#   'dropoff_from': 390,
#   'dropoff_to': 720,
#   'dropoff_location_x': 133,
#   'dropoff_location_y': 135,
#   'payment': 303},
#  '10097': {'order_id': 10097,
#   'pickup_point_id': 40097,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 201,
#   'pickup_location_y': 180,
#   'dropoff_point_id': 60097,
#   'dropoff_from': 450,
#   'dropoff_to': 780,
#   'dropoff_location_x': 233,
#   'dropoff_location_y': 144,
#   'payment': 219},
#  '10099': {'order_id': 10099,
#   'pickup_point_id': 40099,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 221,
#   'pickup_location_y': 149,
#   'dropoff_point_id': 60099,
#   'dropoff_from': 480,
#   'dropoff_to': 540,
#   'dropoff_location_x': 232,
#   'dropoff_location_y': 152,
#   'payment': 403},
#  '10101': {'order_id': 10101,
#   'pickup_point_id': 40101,
#   'pickup_from': 420,
#   'pickup_to': 960,
#   'pickup_location_x': 281,
#   'pickup_location_y': 152,
#   'dropoff_point_id': 60101,
#   'dropoff_from': 1020,
#   'dropoff_to': 1080,
#   'dropoff_location_x': 267,
#   'dropoff_location_y': 192,
#   'payment': 376},
#  '10103': {'order_id': 10103,
#   'pickup_point_id': 40103,
#   'pickup_from': 420,
#   'pickup_to': 510,
#   'pickup_location_x': 110,
#   'pickup_location_y': 279,
#   'dropoff_point_id': 60103,
#   'dropoff_from': 540,
#   'dropoff_to': 840,
#   'dropoff_location_x': 211,
#   'dropoff_location_y': 200,
#   'payment': 619},
#  '10104': {'order_id': 10104,
#   'pickup_point_id': 40104,
#   'pickup_from': 600,
#   'pickup_to': 660,
#   'pickup_location_x': 243,
#   'pickup_location_y': 176,
#   'dropoff_point_id': 60104,
#   'dropoff_from': 720,
#   'dropoff_to': 900,
#   'dropoff_location_x': 196,
#   'dropoff_location_y': 5,
#   'payment': 560},
#  '10105': {'order_id': 10105,
#   'pickup_point_id': 40105,
#   'pickup_from': 360,
#   'pickup_to': 600,
#   'pickup_location_x': 170,
#   'pickup_location_y': 11,
#   'dropoff_point_id': 60105,
#   'dropoff_from': 540,
#   'dropoff_to': 780,
#   'dropoff_location_x': 167,
#   'dropoff_location_y': 18,
#   'payment': 183},
#  '10106': {'order_id': 10106,
#   'pickup_point_id': 40106,
#   'pickup_from': 360,
#   'pickup_to': 720,
#   'pickup_location_x': 218,
#   'pickup_location_y': 168,
#   'dropoff_point_id': 60106,
#   'dropoff_from': 360,
#   'dropoff_to': 900,
#   'dropoff_location_x': 193,
#   'dropoff_location_y': 113,
#   'payment': 452},
#  '10107': {'order_id': 10107,
#   'pickup_point_id': 40107,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 179,
#   'pickup_location_y': 128,
#   'dropoff_point_id': 60107,
#   'dropoff_from': 450,
#   'dropoff_to': 540,
#   'dropoff_location_x': 137,
#   'dropoff_location_y': 135,
#   'payment': 231},
#  '10108': {'order_id': 10108,
#   'pickup_point_id': 40108,
#   'pickup_from': 360,
#   'pickup_to': 720,
#   'pickup_location_x': 218,
#   'pickup_location_y': 168,
#   'dropoff_point_id': 60108,
#   'dropoff_from': 360,
#   'dropoff_to': 900,
#   'dropoff_location_x': 193,
#   'dropoff_location_y': 113,
#   'payment': 452},
#  '10110': {'order_id': 10110,
#   'pickup_point_id': 40110,
#   'pickup_from': 330,
#   'pickup_to': 840,
#   'pickup_location_x': 162,
#   'pickup_location_y': 149,
#   'dropoff_point_id': 60110,
#   'dropoff_from': 720,
#   'dropoff_to': 840,
#   'dropoff_location_x': 277,
#   'dropoff_location_y': 97,
#   'payment': 393},
#  '10111': {'order_id': 10111,
#   'pickup_point_id': 40111,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 285,
#   'pickup_location_y': 228,
#   'dropoff_point_id': 60111,
#   'dropoff_from': 420,
#   'dropoff_to': 780,
#   'dropoff_location_x': 252,
#   'dropoff_location_y': 206,
#   'payment': 276},
#  '10112': {'order_id': 10112,
#   'pickup_point_id': 40112,
#   'pickup_from': 480,
#   'pickup_to': 540,
#   'pickup_location_x': 166,
#   'pickup_location_y': 137,
#   'dropoff_point_id': 60112,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 152,
#   'dropoff_location_y': 147,
#   'payment': 383},
#  '10114': {'order_id': 10114,
#   'pickup_point_id': 40114,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 221,
#   'pickup_location_y': 149,
#   'dropoff_point_id': 60114,
#   'dropoff_from': 480,
#   'dropoff_to': 540,
#   'dropoff_location_x': 246,
#   'dropoff_location_y': 102,
#   'payment': 403},
#  '10115': {'order_id': 10115,
#   'pickup_point_id': 40115,
#   'pickup_from': 450,
#   'pickup_to': 690,
#   'pickup_location_x': 118,
#   'pickup_location_y': 217,
#   'dropoff_point_id': 60115,
#   'dropoff_from': 450,
#   'dropoff_to': 780,
#   'dropoff_location_x': 272,
#   'dropoff_location_y': 75,
#   'payment': 345},
#  '10117': {'order_id': 10117,
#   'pickup_point_id': 40117,
#   'pickup_from': 450,
#   'pickup_to': 780,
#   'pickup_location_x': 344,
#   'pickup_location_y': 36,
#   'dropoff_point_id': 60117,
#   'dropoff_from': 450,
#   'dropoff_to': 870,
#   'dropoff_location_x': 213,
#   'dropoff_location_y': 169,
#   'payment': 584},
#  '10119': {'order_id': 10119,
#   'pickup_point_id': 40119,
#   'pickup_from': 420,
#   'pickup_to': 840,
#   'pickup_location_x': 275,
#   'pickup_location_y': 99,
#   'dropoff_point_id': 60119,
#   'dropoff_from': 420,
#   'dropoff_to': 840,
#   'dropoff_location_x': 184,
#   'dropoff_location_y': 149,
#   'payment': 286},
#  '10120': {'order_id': 10120,
#   'pickup_point_id': 40120,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 288,
#   'pickup_location_y': 116,
#   'dropoff_point_id': 60120,
#   'dropoff_from': 420,
#   'dropoff_to': 600,
#   'dropoff_location_x': 159,
#   'dropoff_location_y': 134,
#   'payment': 346},
#  '10121': {'order_id': 10121,
#   'pickup_point_id': 40121,
#   'pickup_from': 450,
#   'pickup_to': 840,
#   'pickup_location_x': 30,
#   'pickup_location_y': 120,
#   'dropoff_point_id': 60121,
#   'dropoff_from': 450,
#   'dropoff_to': 840,
#   'dropoff_location_x': 231,
#   'dropoff_location_y': 149,
#   'payment': 390},
#  '10124': {'order_id': 10124,
#   'pickup_point_id': 40124,
#   'pickup_from': 360,
#   'pickup_to': 870,
#   'pickup_location_x': 267,
#   'pickup_location_y': 144,
#   'dropoff_point_id': 60124,
#   'dropoff_from': 720,
#   'dropoff_to': 900,
#   'dropoff_location_x': 250,
#   'dropoff_location_y': 21,
#   'payment': 417},
#  '10125': {'order_id': 10125,
#   'pickup_point_id': 40125,
#   'pickup_from': 420,
#   'pickup_to': 840,
#   'pickup_location_x': 275,
#   'pickup_location_y': 100,
#   'dropoff_point_id': 60125,
#   'dropoff_from': 420,
#   'dropoff_to': 840,
#   'dropoff_location_x': 122,
#   'dropoff_location_y': 77,
#   'payment': 341},
#  '10126': {'order_id': 10126,
#   'pickup_point_id': 40126,
#   'pickup_from': 480,
#   'pickup_to': 540,
#   'pickup_location_x': 202,
#   'pickup_location_y': 84,
#   'dropoff_point_id': 60126,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 142,
#   'dropoff_location_y': 153,
#   'payment': 431},
#  '10127': {'order_id': 10127,
#   'pickup_point_id': 40127,
#   'pickup_from': 360,
#   'pickup_to': 720,
#   'pickup_location_x': 82,
#   'pickup_location_y': 138,
#   'dropoff_point_id': 60127,
#   'dropoff_from': 360,
#   'dropoff_to': 870,
#   'dropoff_location_x': 201,
#   'dropoff_location_y': 1,
#   'payment': 394},
#  '10128': {'order_id': 10128,
#   'pickup_point_id': 40128,
#   'pickup_from': 540,
#   'pickup_to': 780,
#   'pickup_location_x': 268,
#   'pickup_location_y': 199,
#   'dropoff_point_id': 60128,
#   'dropoff_from': 630,
#   'dropoff_to': 870,
#   'dropoff_location_x': 234,
#   'dropoff_location_y': 9,
#   'payment': 528},
#  '10129': {'order_id': 10129,
#   'pickup_point_id': 40129,
#   'pickup_from': 450,
#   'pickup_to': 570,
#   'pickup_location_x': 216,
#   'pickup_location_y': 92,
#   'dropoff_point_id': 60129,
#   'dropoff_from': 480,
#   'dropoff_to': 870,
#   'dropoff_location_x': 302,
#   'dropoff_location_y': 151,
#   'payment': 379},
#  '10130': {'order_id': 10130,
#   'pickup_point_id': 40130,
#   'pickup_from': 420,
#   'pickup_to': 660,
#   'pickup_location_x': 238,
#   'pickup_location_y': 164,
#   'dropoff_point_id': 60130,
#   'dropoff_from': 420,
#   'dropoff_to': 780,
#   'dropoff_location_x': 113,
#   'dropoff_location_y': 86,
#   'payment': 358},
#  '10131': {'order_id': 10131,
#   'pickup_point_id': 40131,
#   'pickup_from': 420,
#   'pickup_to': 450,
#   'pickup_location_x': 133,
#   'pickup_location_y': 86,
#   'dropoff_point_id': 60131,
#   'dropoff_from': 510,
#   'dropoff_to': 840,
#   'dropoff_location_x': 256,
#   'dropoff_location_y': 76,
#   'payment': 370},
#  '10132': {'order_id': 10132,
#   'pickup_point_id': 40132,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 221,
#   'pickup_location_y': 149,
#   'dropoff_point_id': 60132,
#   'dropoff_from': 480,
#   'dropoff_to': 540,
#   'dropoff_location_x': 188,
#   'dropoff_location_y': 126,
#   'payment': 403},
#  '10133': {'order_id': 10133,
#   'pickup_point_id': 40133,
#   'pickup_from': 450,
#   'pickup_to': 720,
#   'pickup_location_x': 232,
#   'pickup_location_y': 170,
#   'dropoff_point_id': 60133,
#   'dropoff_from': 480,
#   'dropoff_to': 780,
#   'dropoff_location_x': 93,
#   'dropoff_location_y': 145,
#   'payment': 374},
#  '10135': {'order_id': 10135,
#   'pickup_point_id': 40135,
#   'pickup_from': 330,
#   'pickup_to': 900,
#   'pickup_location_x': 239,
#   'pickup_location_y': 164,
#   'dropoff_point_id': 60135,
#   'dropoff_from': 900,
#   'dropoff_to': 960,
#   'dropoff_location_x': 126,
#   'dropoff_location_y': 78,
#   'payment': 461},
#  '10137': {'order_id': 10137,
#   'pickup_point_id': 40137,
#   'pickup_from': 420,
#   'pickup_to': 450,
#   'pickup_location_x': 169,
#   'pickup_location_y': 191,
#   'dropoff_point_id': 60137,
#   'dropoff_from': 480,
#   'dropoff_to': 540,
#   'dropoff_location_x': 167,
#   'dropoff_location_y': 130,
#   'payment': 383},
#  '10139': {'order_id': 10139,
#   'pickup_point_id': 40139,
#   'pickup_from': 420,
#   'pickup_to': 450,
#   'pickup_location_x': 183,
#   'pickup_location_y': 152,
#   'dropoff_point_id': 60139,
#   'dropoff_from': 420,
#   'dropoff_to': 540,
#   'dropoff_location_x': 196,
#   'dropoff_location_y': 109,
#   'payment': 603},
#  '10141': {'order_id': 10141,
#   'pickup_point_id': 40141,
#   'pickup_from': 540,
#   'pickup_to': 780,
#   'pickup_location_x': 225,
#   'pickup_location_y': 245,
#   'dropoff_point_id': 60141,
#   'dropoff_from': 540,
#   'dropoff_to': 780,
#   'dropoff_location_x': 251,
#   'dropoff_location_y': 136,
#   'payment': 302},
#  '10142': {'order_id': 10142,
#   'pickup_point_id': 40142,
#   'pickup_from': 540,
#   'pickup_to': 600,
#   'pickup_location_x': 137,
#   'pickup_location_y': 131,
#   'dropoff_point_id': 60142,
#   'dropoff_from': 660,
#   'dropoff_to': 720,
#   'dropoff_location_x': 207,
#   'dropoff_location_y': 119,
#   'payment': 267},
#  '10143': {'order_id': 10143,
#   'pickup_point_id': 40143,
#   'pickup_from': 540,
#   'pickup_to': 900,
#   'pickup_location_x': 232,
#   'pickup_location_y': 137,
#   'dropoff_point_id': 60143,
#   'dropoff_from': 540,
#   'dropoff_to': 900,
#   'dropoff_location_x': 275,
#   'dropoff_location_y': 110,
#   'payment': 247},
#  '10144': {'order_id': 10144,
#   'pickup_point_id': 40144,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 216,
#   'pickup_location_y': 92,
#   'dropoff_point_id': 60144,
#   'dropoff_from': 540,
#   'dropoff_to': 660,
#   'dropoff_location_x': 195,
#   'dropoff_location_y': 146,
#   'payment': 376},
#  '10145': {'order_id': 10145,
#   'pickup_point_id': 40145,
#   'pickup_from': 450,
#   'pickup_to': 630,
#   'pickup_location_x': 179,
#   'pickup_location_y': 181,
#   'dropoff_point_id': 60145,
#   'dropoff_from': 480,
#   'dropoff_to': 660,
#   'dropoff_location_x': 179,
#   'dropoff_location_y': 123,
#   'payment': 393},
#  '10146': {'order_id': 10146,
#   'pickup_point_id': 40146,
#   'pickup_from': 420,
#   'pickup_to': 450,
#   'pickup_location_x': 211,
#   'pickup_location_y': 93,
#   'dropoff_point_id': 60146,
#   'dropoff_from': 420,
#   'dropoff_to': 540,
#   'dropoff_location_x': 212,
#   'dropoff_location_y': 81,
#   'payment': 293},
#  '10149': {'order_id': 10149,
#   'pickup_point_id': 40149,
#   'pickup_from': 360,
#   'pickup_to': 600,
#   'pickup_location_x': 222,
#   'pickup_location_y': 216,
#   'dropoff_point_id': 60149,
#   'dropoff_from': 360,
#   'dropoff_to': 600,
#   'dropoff_location_x': 275,
#   'dropoff_location_y': 177,
#   'payment': 299},
#  '10151': {'order_id': 10151,
#   'pickup_point_id': 40151,
#   'pickup_from': 450,
#   'pickup_to': 540,
#   'pickup_location_x': 209,
#   'pickup_location_y': 140,
#   'dropoff_point_id': 60151,
#   'dropoff_from': 600,
#   'dropoff_to': 720,
#   'dropoff_location_x': 216,
#   'dropoff_location_y': 92,
#   'payment': 413},
#  '10152': {'order_id': 10152,
#   'pickup_point_id': 40152,
#   'pickup_from': 480,
#   'pickup_to': 720,
#   'pickup_location_x': 223,
#   'pickup_location_y': 160,
#   'dropoff_point_id': 60152,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 231,
#   'dropoff_location_y': 134,
#   'payment': 219},
#  '10153': {'order_id': 10153,
#   'pickup_point_id': 40153,
#   'pickup_from': 450,
#   'pickup_to': 780,
#   'pickup_location_x': 264,
#   'pickup_location_y': 127,
#   'dropoff_point_id': 60153,
#   'dropoff_from': 480,
#   'dropoff_to': 900,
#   'dropoff_location_x': 268,
#   'dropoff_location_y': 144,
#   'payment': 242},
#  '10154': {'order_id': 10154,
#   'pickup_point_id': 40154,
#   'pickup_from': 360,
#   'pickup_to': 660,
#   'pickup_location_x': 212,
#   'pickup_location_y': 227,
#   'dropoff_point_id': 60154,
#   'dropoff_from': 660,
#   'dropoff_to': 840,
#   'dropoff_location_x': 305,
#   'dropoff_location_y': 1,
#   'payment': 628},
#  '10155': {'order_id': 10155,
#   'pickup_point_id': 40155,
#   'pickup_from': 480,
#   'pickup_to': 510,
#   'pickup_location_x': 171,
#   'pickup_location_y': 196,
#   'dropoff_point_id': 60155,
#   'dropoff_from': 570,
#   'dropoff_to': 780,
#   'dropoff_location_x': 270,
#   'dropoff_location_y': 219,
#   'payment': 459},
#  '10156': {'order_id': 10156,
#   'pickup_point_id': 40156,
#   'pickup_from': 540,
#   'pickup_to': 780,
#   'pickup_location_x': 211,
#   'pickup_location_y': 123,
#   'dropoff_point_id': 60156,
#   'dropoff_from': 690,
#   'dropoff_to': 930,
#   'dropoff_location_x': 196,
#   'dropoff_location_y': 147,
#   'payment': 247},
#  '10158': {'order_id': 10158,
#   'pickup_point_id': 40158,
#   'pickup_from': 360,
#   'pickup_to': 720,
#   'pickup_location_x': 183,
#   'pickup_location_y': 146,
#   'dropoff_point_id': 60158,
#   'dropoff_from': 360,
#   'dropoff_to': 720,
#   'dropoff_location_x': 229,
#   'dropoff_location_y': 93,
#   'payment': 287},
#  '10159': {'order_id': 10159,
#   'pickup_point_id': 40159,
#   'pickup_from': 390,
#   'pickup_to': 450,
#   'pickup_location_x': 168,
#   'pickup_location_y': 62,
#   'dropoff_point_id': 60159,
#   'dropoff_from': 480,
#   'dropoff_to': 660,
#   'dropoff_location_x': 174,
#   'dropoff_location_y': 237,
#   'payment': 513},
#  '10160': {'order_id': 10160,
#   'pickup_point_id': 40160,
#   'pickup_from': 390,
#   'pickup_to': 420,
#   'pickup_location_x': 252,
#   'pickup_location_y': 194,
#   'dropoff_point_id': 60160,
#   'dropoff_from': 480,
#   'dropoff_to': 600,
#   'dropoff_location_x': 109,
#   'dropoff_location_y': 200,
#   'payment': 492},
#  '10161': {'order_id': 10161,
#   'pickup_point_id': 40161,
#   'pickup_from': 330,
#   'pickup_to': 390,
#   'pickup_location_x': 168,
#   'pickup_location_y': 62,
#   'dropoff_point_id': 60161,
#   'dropoff_from': 480,
#   'dropoff_to': 660,
#   'dropoff_location_x': 174,
#   'dropoff_location_y': 237,
#   'payment': 513},
#  '10162': {'order_id': 10162,
#   'pickup_point_id': 40162,
#   'pickup_from': 660,
#   'pickup_to': 780,
#   'pickup_location_x': 94,
#   'pickup_location_y': 139,
#   'dropoff_point_id': 60162,
#   'dropoff_from': 780,
#   'dropoff_to': 900,
#   'dropoff_location_x': 183,
#   'dropoff_location_y': 147,
#   'payment': 518},
#  '10163': {'order_id': 10163,
#   'pickup_point_id': 40163,
#   'pickup_from': 330,
#   'pickup_to': 900,
#   'pickup_location_x': 223,
#   'pickup_location_y': 129,
#   'dropoff_point_id': 60163,
#   'dropoff_from': 900,
#   'dropoff_to': 960,
#   'dropoff_location_x': 236,
#   'dropoff_location_y': 102,
#   'payment': 305},
#  '10164': {'order_id': 10164,
#   'pickup_point_id': 40164,
#   'pickup_from': 360,
#   'pickup_to': 600,
#   'pickup_location_x': 360,
#   'pickup_location_y': 96,
#   'dropoff_point_id': 60164,
#   'dropoff_from': 480,
#   'dropoff_to': 780,
#   'dropoff_location_x': 272,
#   'dropoff_location_y': 70,
#   'payment': 371},
#  '10165': {'order_id': 10165,
#   'pickup_point_id': 40165,
#   'pickup_from': 390,
#   'pickup_to': 420,
#   'pickup_location_x': 127,
#   'pickup_location_y': 131,
#   'dropoff_point_id': 60165,
#   'dropoff_from': 480,
#   'dropoff_to': 660,
#   'dropoff_location_x': 107,
#   'dropoff_location_y': 73,
#   'payment': 386},
#  '10167': {'order_id': 10167,
#   'pickup_point_id': 40167,
#   'pickup_from': 390,
#   'pickup_to': 420,
#   'pickup_location_x': 127,
#   'pickup_location_y': 131,
#   'dropoff_point_id': 60167,
#   'dropoff_from': 480,
#   'dropoff_to': 660,
#   'dropoff_location_x': 106,
#   'dropoff_location_y': 148,
#   'payment': 301},
#  '10169': {'order_id': 10169,
#   'pickup_point_id': 40169,
#   'pickup_from': 420,
#   'pickup_to': 600,
#   'pickup_location_x': 211,
#   'pickup_location_y': 80,
#   'dropoff_point_id': 60169,
#   'dropoff_from': 420,
#   'dropoff_to': 840,
#   'dropoff_location_x': 173,
#   'dropoff_location_y': 148,
#   'payment': 395},
#  '10170': {'order_id': 10170,
#   'pickup_point_id': 40170,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 229,
#   'pickup_location_y': 143,
#   'dropoff_point_id': 60170,
#   'dropoff_from': 420,
#   'dropoff_to': 660,
#   'dropoff_location_x': 313,
#   'dropoff_location_y': 151,
#   'payment': 363},
#  '10171': {'order_id': 10171,
#   'pickup_point_id': 40171,
#   'pickup_from': 480,
#   'pickup_to': 600,
#   'pickup_location_x': 240,
#   'pickup_location_y': 131,
#   'dropoff_point_id': 60171,
#   'dropoff_from': 600,
#   'dropoff_to': 840,
#   'dropoff_location_x': 110,
#   'dropoff_location_y': 82,
#   'payment': 411},
#  '10172': {'order_id': 10172,
#   'pickup_point_id': 40172,
#   'pickup_from': 540,
#   'pickup_to': 900,
#   'pickup_location_x': 218,
#   'pickup_location_y': 224,
#   'dropoff_point_id': 60172,
#   'dropoff_from': 900,
#   'dropoff_to': 1020,
#   'dropoff_location_x': 128,
#   'dropoff_location_y': 57,
#   'payment': 407},
#  '10173': {'order_id': 10173,
#   'pickup_point_id': 40173,
#   'pickup_from': 480,
#   'pickup_to': 510,
#   'pickup_location_x': 230,
#   'pickup_location_y': 116,
#   'dropoff_point_id': 60173,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 300,
#   'dropoff_location_y': 3,
#   'payment': 359},
#  '10177': {'order_id': 10177,
#   'pickup_point_id': 40177,
#   'pickup_from': 600,
#   'pickup_to': 630,
#   'pickup_location_x': 255,
#   'pickup_location_y': 115,
#   'dropoff_point_id': 60177,
#   'dropoff_from': 660,
#   'dropoff_to': 840,
#   'dropoff_location_x': 238,
#   'dropoff_location_y': 164,
#   'payment': 354},
#  '10178': {'order_id': 10178,
#   'pickup_point_id': 40178,
#   'pickup_from': 540,
#   'pickup_to': 570,
#   'pickup_location_x': 252,
#   'pickup_location_y': 185,
#   'dropoff_point_id': 60178,
#   'dropoff_from': 600,
#   'dropoff_to': 660,
#   'dropoff_location_x': 276,
#   'dropoff_location_y': 154,
#   'payment': 342},
#  '10179': {'order_id': 10179,
#   'pickup_point_id': 40179,
#   'pickup_from': 390,
#   'pickup_to': 480,
#   'pickup_location_x': 325,
#   'pickup_location_y': 79,
#   'dropoff_point_id': 60179,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 371,
#   'dropoff_location_y': 114,
#   'payment': 419},
#  '10181': {'order_id': 10181,
#   'pickup_point_id': 40181,
#   'pickup_from': 480,
#   'pickup_to': 510,
#   'pickup_location_x': 190,
#   'pickup_location_y': 148,
#   'dropoff_point_id': 60181,
#   'dropoff_from': 600,
#   'dropoff_to': 840,
#   'dropoff_location_x': 259,
#   'dropoff_location_y': 74,
#   'payment': 352},
#  '10182': {'order_id': 10182,
#   'pickup_point_id': 40182,
#   'pickup_from': 420,
#   'pickup_to': 480,
#   'pickup_location_x': 216,
#   'pickup_location_y': 92,
#   'dropoff_point_id': 60182,
#   'dropoff_from': 540,
#   'dropoff_to': 660,
#   'dropoff_location_x': 277,
#   'dropoff_location_y': 137,
#   'payment': 376},
#  '10183': {'order_id': 10183,
#   'pickup_point_id': 40183,
#   'pickup_from': 360,
#   'pickup_to': 660,
#   'pickup_location_x': 341,
#   'pickup_location_y': 50,
#   'dropoff_point_id': 60183,
#   'dropoff_from': 360,
#   'dropoff_to': 780,
#   'dropoff_location_x': 344,
#   'dropoff_location_y': 37,
#   'payment': 231},
#  '10185': {'order_id': 10185,
#   'pickup_point_id': 40185,
#   'pickup_from': 480,
#   'pickup_to': 720,
#   'pickup_location_x': 200,
#   'pickup_location_y': 152,
#   'dropoff_point_id': 60185,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 241,
#   'dropoff_location_y': 58,
#   'payment': 277},
#  '10187': {'order_id': 10187,
#   'pickup_point_id': 40187,
#   'pickup_from': 480,
#   'pickup_to': 720,
#   'pickup_location_x': 192,
#   'pickup_location_y': 96,
#   'dropoff_point_id': 60187,
#   'dropoff_from': 510,
#   'dropoff_to': 750,
#   'dropoff_location_x': 211,
#   'dropoff_location_y': 101,
#   'payment': 260},
#  '10188': {'order_id': 10188,
#   'pickup_point_id': 40188,
#   'pickup_from': 390,
#   'pickup_to': 630,
#   'pickup_location_x': 232,
#   'pickup_location_y': 193,
#   'dropoff_point_id': 60188,
#   'dropoff_from': 600,
#   'dropoff_to': 840,
#   'dropoff_location_x': 200,
#   'dropoff_location_y': 45,
#   'payment': 361},
#  '10189': {'order_id': 10189,
#   'pickup_point_id': 40189,
#   'pickup_from': 480,
#   'pickup_to': 720,
#   'pickup_location_x': 192,
#   'pickup_location_y': 96,
#   'dropoff_point_id': 60189,
#   'dropoff_from': 510,
#   'dropoff_to': 810,
#   'dropoff_location_x': 121,
#   'dropoff_location_y': 109,
#   'payment': 338},
#  '10190': {'order_id': 10190,
#   'pickup_point_id': 40190,
#   'pickup_from': 300,
#   'pickup_to': 360,
#   'pickup_location_x': 183,
#   'pickup_location_y': 60,
#   'dropoff_point_id': 60190,
#   'dropoff_from': 360,
#   'dropoff_to': 510,
#   'dropoff_location_x': 210,
#   'dropoff_location_y': 138,
#   'payment': 424},
#  '10192': {'order_id': 10192,
#   'pickup_point_id': 40192,
#   'pickup_from': 420,
#   'pickup_to': 540,
#   'pickup_location_x': 288,
#   'pickup_location_y': 131,
#   'dropoff_point_id': 60192,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 221,
#   'dropoff_location_y': 149,
#   'payment': 374},
#  '10193': {'order_id': 10193,
#   'pickup_point_id': 40193,
#   'pickup_from': 390,
#   'pickup_to': 540,
#   'pickup_location_x': 188,
#   'pickup_location_y': 13,
#   'dropoff_point_id': 60193,
#   'dropoff_from': 540,
#   'dropoff_to': 780,
#   'dropoff_location_x': 249,
#   'dropoff_location_y': 94,
#   'payment': 388},
#  '10196': {'order_id': 10196,
#   'pickup_point_id': 40196,
#   'pickup_from': 480,
#   'pickup_to': 540,
#   'pickup_location_x': 271,
#   'pickup_location_y': 77,
#   'dropoff_point_id': 60196,
#   'dropoff_from': 540,
#   'dropoff_to': 600,
#   'dropoff_location_x': 197,
#   'dropoff_location_y': 60,
#   'payment': 379},
#  '10197': {'order_id': 10197,
#   'pickup_point_id': 40197,
#   'pickup_from': 420,
#   'pickup_to': 900,
#   'pickup_location_x': 173,
#   'pickup_location_y': 171,
#   'dropoff_point_id': 60197,
#   'dropoff_from': 420,
#   'dropoff_to': 900,
#   'dropoff_location_x': 281,
#   'dropoff_location_y': 121,
#   'payment': 293},
#  '10199': {'order_id': 10199,
#   'pickup_point_id': 40199,
#   'pickup_from': 390,
#   'pickup_to': 480,
#   'pickup_location_x': 217,
#   'pickup_location_y': 176,
#   'dropoff_point_id': 60199,
#   'dropoff_from': 390,
#   'dropoff_to': 960,
#   'dropoff_location_x': 136,
#   'dropoff_location_y': 300,
#   'payment': 478},
#  '10201': {'order_id': 10201,
#   'pickup_point_id': 40201,
#   'pickup_from': 450,
#   'pickup_to': 480,
#   'pickup_location_x': 68,
#   'pickup_location_y': 126,
#   'dropoff_point_id': 60201,
#   'dropoff_from': 570,
#   'dropoff_to': 630,
#   'dropoff_location_x': 152,
#   'dropoff_location_y': 109,
#   'payment': 318},
#  '10202': {'order_id': 10202,
#   'pickup_point_id': 40202,
#   'pickup_from': 420,
#   'pickup_to': 570,
#   'pickup_location_x': 255,
#   'pickup_location_y': 109,
#   'dropoff_point_id': 60202,
#   'dropoff_from': 480,
#   'dropoff_to': 660,
#   'dropoff_location_x': 205,
#   'dropoff_location_y': 159,
#   'payment': 405},
#  '10204': {'order_id': 10204,
#   'pickup_point_id': 40204,
#   'pickup_from': 480,
#   'pickup_to': 600,
#   'pickup_location_x': 196,
#   'pickup_location_y': 77,
#   'dropoff_point_id': 60204,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 255,
#   'dropoff_location_y': 109,
#   'payment': 440},
#  '10206': {'order_id': 10206,
#   'pickup_point_id': 40206,
#   'pickup_from': 390,
#   'pickup_to': 480,
#   'pickup_location_x': 272,
#   'pickup_location_y': 116,
#   'dropoff_point_id': 60206,
#   'dropoff_from': 450,
#   'dropoff_to': 660,
#   'dropoff_location_x': 228,
#   'dropoff_location_y': 102,
#   'payment': 415},
#  '10207': {'order_id': 10207,
#   'pickup_point_id': 40207,
#   'pickup_from': 360,
#   'pickup_to': 720,
#   'pickup_location_x': 322,
#   'pickup_location_y': 113,
#   'dropoff_point_id': 60207,
#   'dropoff_from': 420,
#   'dropoff_to': 840,
#   'dropoff_location_x': 164,
#   'dropoff_location_y': 171,
#   'payment': 294},
#  '10209': {'order_id': 10209,
#   'pickup_point_id': 40209,
#   'pickup_from': 540,
#   'pickup_to': 720,
#   'pickup_location_x': 263,
#   'pickup_location_y': 80,
#   'dropoff_point_id': 60209,
#   'dropoff_from': 540,
#   'dropoff_to': 900,
#   'dropoff_location_x': 255,
#   'dropoff_location_y': 109,
#   'payment': 319},
#  '10211': {'order_id': 10211,
#   'pickup_point_id': 40211,
#   'pickup_from': 480,
#   'pickup_to': 540,
#   'pickup_location_x': 199,
#   'pickup_location_y': 138,
#   'dropoff_point_id': 60211,
#   'dropoff_from': 540,
#   'dropoff_to': 600,
#   'dropoff_location_x': 231,
#   'dropoff_location_y': 103,
#   'payment': 355},
#  '10214': {'order_id': 10214,
#   'pickup_point_id': 40214,
#   'pickup_from': 360,
#   'pickup_to': 660,
#   'pickup_location_x': 204,
#   'pickup_location_y': 96,
#   'dropoff_point_id': 60214,
#   'dropoff_from': 360,
#   'dropoff_to': 660,
#   'dropoff_location_x': 172,
#   'dropoff_location_y': 66,
#   'payment': 177},
#  '10217': {'order_id': 10217,
#   'pickup_point_id': 40217,
#   'pickup_from': 600,
#   'pickup_to': 840,
#   'pickup_location_x': 345,
#   'pickup_location_y': 66,
#   'dropoff_point_id': 60217,
#   'dropoff_from': 990,
#   'dropoff_to': 1230,
#   'dropoff_location_x': 97,
#   'dropoff_location_y': 151,
#   'payment': 473},
#  '10218': {'order_id': 10218,
#   'pickup_point_id': 40218,
#   'pickup_from': 540,
#   'pickup_to': 660,
#   'pickup_location_x': 229,
#   'pickup_location_y': 126,
#   'dropoff_point_id': 60218,
#   'dropoff_from': 600,
#   'dropoff_to': 780,
#   'dropoff_location_x': 186,
#   'dropoff_location_y': 125,
#   'payment': 267},
#  '10219': {'order_id': 10219,
#   'pickup_point_id': 40219,
#   'pickup_from': 480,
#   'pickup_to': 720,
#   'pickup_location_x': 198,
#   'pickup_location_y': 116,
#   'dropoff_point_id': 60219,
#   'dropoff_from': 660,
#   'dropoff_to': 900,
#   'dropoff_location_x': 226,
#   'dropoff_location_y': 150,
#   'payment': 265},
#  '10220': {'order_id': 10220,
# ...
#   'dropoff_from': 436,
#   'dropoff_to': 526,
#   'dropoff_location_x': 314,
#   'dropoff_location_y': 58,
#   'payment': 368},
#  '11595': {'order_id': 11595,
#   'pickup_point_id': 41595,
#   'pickup_from': 435,
#   'pickup_to': 630,
#   'pickup_location_x': 216,
#   'pickup_location_y': 92,
#   'dropoff_point_id': 61595,
#   'dropoff_from': 540,
#   'dropoff_to': 840,
#   'dropoff_location_x': 173,
#   'dropoff_location_y': 130,
#   'payment': 407},
#  '11597': {'order_id': 11597,
#   'pickup_point_id': 41597,
#   'pickup_from': 435,
#   'pickup_to': 870,
#   'pickup_location_x': 117,
#   'pickup_location_y': 145,
#   'dropoff_point_id': 61597,
#   'dropoff_from': 930,
#   'dropoff_to': 960,
#   'dropoff_location_x': 115,
#   'dropoff_location_y': 45,
#   'payment': 418},
#  '11598': {'order_id': 11598,
#   'pickup_point_id': 41598,
#   'pickup_from': 441,
#   'pickup_to': 526,
#   'pickup_location_x': 181,
#   'pickup_location_y': 167,
#   'dropoff_point_id': 61598,
#   'dropoff_from': 526,
#   'dropoff_to': 616,
#   'dropoff_location_x': 110,
#   'dropoff_location_y': 185,
#   'payment': 500},
#  '11599': {'order_id': 11599,
#   'pickup_point_id': 41599,
#   'pickup_from': 630,
#   'pickup_to': 870,
#   'pickup_location_x': 240,
#   'pickup_location_y': 148,
#   'dropoff_point_id': 61599,
#   'dropoff_from': 630,
#   'dropoff_to': 1183,
#   'dropoff_location_x': 241,
#   'dropoff_location_y': 153,
#   'payment': 135},
#  '11603': {'order_id': 11603,
#   'pickup_point_id': 41603,
#   'pickup_from': 436,
#   'pickup_to': 510,
#   'pickup_location_x': 204,
#   'pickup_location_y': 189,
#   'dropoff_point_id': 61603,
#   'dropoff_from': 510,
#   'dropoff_to': 600,
#   'dropoff_location_x': 233,
#   'dropoff_location_y': 157,
#   'payment': 276},
#  '11604': {'order_id': 11604,
#   'pickup_point_id': 41604,
#   'pickup_from': 436,
#   'pickup_to': 540,
#   'pickup_location_x': 324,
#   'pickup_location_y': 104,
#   'dropoff_point_id': 61604,
#   'dropoff_from': 436,
#   'dropoff_to': 720,
#   'dropoff_location_x': 201,
#   'dropoff_location_y': 132,
#   'payment': 445},
#  '11605': {'order_id': 11605,
#   'pickup_point_id': 41605,
#   'pickup_from': 436,
#   'pickup_to': 510,
#   'pickup_location_x': 236,
#   'pickup_location_y': 158,
#   'dropoff_point_id': 61605,
#   'dropoff_from': 480,
#   'dropoff_to': 510,
#   'dropoff_location_x': 241,
#   'dropoff_location_y': 169,
#   'payment': 200},
#  '11606': {'order_id': 11606,
#   'pickup_point_id': 41606,
#   'pickup_from': 660,
#   'pickup_to': 690,
#   'pickup_location_x': 225,
#   'pickup_location_y': 141,
#   'dropoff_point_id': 61606,
#   'dropoff_from': 720,
#   'dropoff_to': 750,
#   'dropoff_location_x': 236,
#   'dropoff_location_y': 150,
#   'payment': 380},
#  '11607': {'order_id': 11607,
#   'pickup_point_id': 41607,
#   'pickup_from': 436,
#   'pickup_to': 510,
#   'pickup_location_x': 27,
#   'pickup_location_y': 119,
#   'dropoff_point_id': 61607,
#   'dropoff_from': 436,
#   'dropoff_to': 810,
#   'dropoff_location_x': 200,
#   'dropoff_location_y': 160,
#   'payment': 350},
#  '11608': {'order_id': 11608,
#   'pickup_point_id': 41608,
#   'pickup_from': 660,
#   'pickup_to': 720,
#   'pickup_location_x': 256,
#   'pickup_location_y': 156,
#   'dropoff_point_id': 61608,
#   'dropoff_from': 810,
#   'dropoff_to': 840,
#   'dropoff_location_x': 239,
#   'dropoff_location_y': 126,
#   'payment': 299},
#  '11610': {'order_id': 11610,
#   'pickup_point_id': 41610,
#   'pickup_from': 436,
#   'pickup_to': 480,
#   'pickup_location_x': 177,
#   'pickup_location_y': 121,
#   'dropoff_point_id': 61610,
#   'dropoff_from': 436,
#   'dropoff_to': 570,
#   'dropoff_location_x': 108,
#   'dropoff_location_y': 140,
#   'payment': 439},
#  '11611': {'order_id': 11611,
#   'pickup_point_id': 41611,
#   'pickup_from': 436,
#   'pickup_to': 540,
#   'pickup_location_x': 264,
#   'pickup_location_y': 77,
#   'dropoff_point_id': 61611,
#   'dropoff_from': 540,
#   'dropoff_to': 720,
#   'dropoff_location_x': 155,
#   'dropoff_location_y': 33,
#   'payment': 423},
#  '11612': {'order_id': 11612,
#   'pickup_point_id': 41612,
#   'pickup_from': 540,
#   'pickup_to': 720,
#   'pickup_location_x': 272,
#   'pickup_location_y': 116,
#   'dropoff_point_id': 61612,
#   'dropoff_from': 720,
#   'dropoff_to': 1020,
#   'dropoff_location_x': 182,
#   'dropoff_location_y': 74,
#   'payment': 362},
#  '11613': {'order_id': 11613,
#   'pickup_point_id': 41613,
#   'pickup_from': 437,
#   'pickup_to': 630,
#   'pickup_location_x': 279,
#   'pickup_location_y': 226,
#   'dropoff_point_id': 61613,
#   'dropoff_from': 437,
#   'dropoff_to': 870,
#   'dropoff_location_x': 295,
#   'dropoff_location_y': 57,
#   'payment': 457},
#  '11614': {'order_id': 11614,
#   'pickup_point_id': 41614,
#   'pickup_from': 540,
#   'pickup_to': 570,
#   'pickup_location_x': 241,
#   'pickup_location_y': 74,
#   'dropoff_point_id': 61614,
#   'dropoff_from': 600,
#   'dropoff_to': 630,
#   'dropoff_location_x': 258,
#   'dropoff_location_y': 81,
#   'payment': 242},
#  '11616': {'order_id': 11616,
#   'pickup_point_id': 41616,
#   'pickup_from': 437,
#   'pickup_to': 600,
#   'pickup_location_x': 351,
#   'pickup_location_y': 125,
#   'dropoff_point_id': 61616,
#   'dropoff_from': 437,
#   'dropoff_to': 780,
#   'dropoff_location_x': 176,
#   'dropoff_location_y': 165,
#   'payment': 383},
#  '11617': {'order_id': 11617,
#   'pickup_point_id': 41617,
#   'pickup_from': 437,
#   'pickup_to': 600,
#   'pickup_location_x': 256,
#   'pickup_location_y': 76,
#   'dropoff_point_id': 61617,
#   'dropoff_from': 600,
#   'dropoff_to': 750,
#   'dropoff_location_x': 139,
#   'dropoff_location_y': 205,
#   'payment': 413},
#  '11618': {'order_id': 11618,
#   'pickup_point_id': 41618,
#   'pickup_from': 437,
#   'pickup_to': 840,
#   'pickup_location_x': 165,
#   'pickup_location_y': 153,
#   'dropoff_point_id': 61618,
#   'dropoff_from': 437,
#   'dropoff_to': 1020,
#   'dropoff_location_x': 306,
#   'dropoff_location_y': 6,
#   'payment': 469},
#  '11619': {'order_id': 11619,
#   'pickup_point_id': 41619,
#   'pickup_from': 437,
#   'pickup_to': 510,
#   'pickup_location_x': 187,
#   'pickup_location_y': 29,
#   'dropoff_point_id': 61619,
#   'dropoff_from': 437,
#   'dropoff_to': 540,
#   'dropoff_location_x': 184,
#   'dropoff_location_y': 9,
#   'payment': 330},
#  '11621': {'order_id': 11621,
#   'pickup_point_id': 41621,
#   'pickup_from': 660,
#   'pickup_to': 720,
#   'pickup_location_x': 331,
#   'pickup_location_y': 109,
#   'dropoff_point_id': 61621,
#   'dropoff_from': 780,
#   'dropoff_to': 870,
#   'dropoff_location_x': 216,
#   'dropoff_location_y': 125,
#   'payment': 525},
#  '11622': {'order_id': 11622,
#   'pickup_point_id': 41622,
#   'pickup_from': 480,
#   'pickup_to': 510,
#   'pickup_location_x': 293,
#   'pickup_location_y': 57,
#   'dropoff_point_id': 61622,
#   'dropoff_from': 510,
#   'dropoff_to': 870,
#   'dropoff_location_x': 193,
#   'dropoff_location_y': 112,
#   'payment': 397},
#  '11627': {'order_id': 11627,
#   'pickup_point_id': 41627,
#   'pickup_from': 437,
#   'pickup_to': 690,
#   'pickup_location_x': 97,
#   'pickup_location_y': 84,
#   'dropoff_point_id': 61627,
#   'dropoff_from': 437,
#   'dropoff_to': 690,
#   'dropoff_location_x': 9,
#   'dropoff_location_y': 100,
#   'payment': 262},
#  '11632': {'order_id': 11632,
#   'pickup_point_id': 41632,
#   'pickup_from': 438,
#   'pickup_to': 540,
#   'pickup_location_x': 252,
#   'pickup_location_y': 185,
#   'dropoff_point_id': 61632,
#   'dropoff_from': 438,
#   'dropoff_to': 690,
#   'dropoff_location_x': 211,
#   'dropoff_location_y': 80,
#   'payment': 321},
#  '11633': {'order_id': 11633,
#   'pickup_point_id': 41633,
#   'pickup_from': 438,
#   'pickup_to': 510,
#   'pickup_location_x': 116,
#   'pickup_location_y': 84,
#   'dropoff_point_id': 61633,
#   'dropoff_from': 438,
#   'dropoff_to': 600,
#   'dropoff_location_x': 26,
#   'dropoff_location_y': 116,
#   'payment': 344},
#  '11634': {'order_id': 11634,
#   'pickup_point_id': 41634,
#   'pickup_from': 438,
#   'pickup_to': 510,
#   'pickup_location_x': 54,
#   'pickup_location_y': 203,
#   'dropoff_point_id': 61634,
#   'dropoff_from': 438,
#   'dropoff_to': 570,
#   'dropoff_location_x': 119,
#   'dropoff_location_y': 207,
#   'payment': 374},
#  '11635': {'order_id': 11635,
#   'pickup_point_id': 41635,
#   'pickup_from': 480,
#   'pickup_to': 600,
#   'pickup_location_x': 189,
#   'pickup_location_y': 87,
#   'dropoff_point_id': 61635,
#   'dropoff_from': 660,
#   'dropoff_to': 780,
#   'dropoff_location_x': 249,
#   'dropoff_location_y': 191,
#   'payment': 375},
#  '11636': {'order_id': 11636,
#   'pickup_point_id': 41636,
#   'pickup_from': 438,
#   'pickup_to': 540,
#   'pickup_location_x': 269,
#   'pickup_location_y': 91,
#   'dropoff_point_id': 61636,
#   'dropoff_from': 480,
#   'dropoff_to': 600,
#   'dropoff_location_x': 223,
#   'dropoff_location_y': 91,
#   'payment': 341},
#  '11639': {'order_id': 11639,
#   'pickup_point_id': 41639,
#   'pickup_from': 600,
#   'pickup_to': 630,
#   'pickup_location_x': 168,
#   'pickup_location_y': 167,
#   'dropoff_point_id': 61639,
#   'dropoff_from': 660,
#   'dropoff_to': 720,
#   'dropoff_location_x': 124,
#   'dropoff_location_y': 194,
#   'payment': 587},
#  '11640': {'order_id': 11640,
#   'pickup_point_id': 41640,
#   'pickup_from': 438,
#   'pickup_to': 480,
#   'pickup_location_x': 225,
#   'pickup_location_y': 129,
#   'dropoff_point_id': 61640,
#   'dropoff_from': 438,
#   'dropoff_to': 540,
#   'dropoff_location_x': 214,
#   'dropoff_location_y': 98,
#   'payment': 364},
#  '11642': {'order_id': 11642,
#   'pickup_point_id': 41642,
#   'pickup_from': 439,
#   'pickup_to': 480,
#   'pickup_location_x': 174,
#   'pickup_location_y': 266,
#   'dropoff_point_id': 61642,
#   'dropoff_from': 439,
#   'dropoff_to': 570,
#   'dropoff_location_x': 171,
#   'dropoff_location_y': 177,
#   'payment': 411},
#  '11643': {'order_id': 11643,
#   'pickup_point_id': 41643,
#   'pickup_from': 439,
#   'pickup_to': 690,
#   'pickup_location_x': 269,
#   'pickup_location_y': 109,
#   'dropoff_point_id': 61643,
#   'dropoff_from': 439,
#   'dropoff_to': 720,
#   'dropoff_location_x': 214,
#   'dropoff_location_y': 61,
#   'payment': 224},
#  '11644': {'order_id': 11644,
#   'pickup_point_id': 41644,
#   'pickup_from': 439,
#   'pickup_to': 750,
#   'pickup_location_x': 62,
#   'pickup_location_y': 128,
#   'dropoff_point_id': 61644,
#   'dropoff_from': 480,
#   'dropoff_to': 780,
#   'dropoff_location_x': 105,
#   'dropoff_location_y': 230,
#   'payment': 377},
#  '11645': {'order_id': 11645,
#   'pickup_point_id': 41645,
#   'pickup_from': 439,
#   'pickup_to': 510,
#   'pickup_location_x': 137,
#   'pickup_location_y': 132,
#   'dropoff_point_id': 61645,
#   'dropoff_from': 540,
#   'dropoff_to': 600,
#   'dropoff_location_x': 39,
#   'dropoff_location_y': 117,
#   'payment': 325},
#  '11646': {'order_id': 11646,
#   'pickup_point_id': 41646,
#   'pickup_from': 480,
#   'pickup_to': 570,
#   'pickup_location_x': 126,
#   'pickup_location_y': 233,
#   'dropoff_point_id': 61646,
#   'dropoff_from': 600,
#   'dropoff_to': 780,
#   'dropoff_location_x': 293,
#   'dropoff_location_y': 136,
#   'payment': 453},
#  '11647': {'order_id': 11647,
#   'pickup_point_id': 41647,
#   'pickup_from': 439,
#   'pickup_to': 720,
#   'pickup_location_x': 167,
#   'pickup_location_y': 113,
#   'dropoff_point_id': 61647,
#   'dropoff_from': 439,
#   'dropoff_to': 840,
#   'dropoff_location_x': 331,
#   'dropoff_location_y': 35,
#   'payment': 414},
#  '11649': {'order_id': 11649,
#   'pickup_point_id': 41649,
#   'pickup_from': 439,
#   'pickup_to': 630,
#   'pickup_location_x': 219,
#   'pickup_location_y': 227,
#   'dropoff_point_id': 61649,
#   'dropoff_from': 439,
#   'dropoff_to': 960,
#   'dropoff_location_x': 211,
#   'dropoff_location_y': 80,
#   'payment': 395},
#  '11651': {'order_id': 11651,
#   'pickup_point_id': 41651,
#   'pickup_from': 439,
#   'pickup_to': 840,
#   'pickup_location_x': 195,
#   'pickup_location_y': 110,
#   'dropoff_point_id': 61651,
#   'dropoff_from': 439,
#   'dropoff_to': 960,
#   'dropoff_location_x': 202,
#   'dropoff_location_y': 113,
#   'payment': 172},
#  '11652': {'order_id': 11652,
#   'pickup_point_id': 41652,
#   'pickup_from': 510,
#   'pickup_to': 570,
#   'pickup_location_x': 234,
#   'pickup_location_y': 206,
#   'dropoff_point_id': 61652,
#   'dropoff_from': 510,
#   'dropoff_to': 910,
#   'dropoff_location_x': 197,
#   'dropoff_location_y': 60,
#   'payment': 434},
#  '11653': {'order_id': 11653,
#   'pickup_point_id': 41653,
#   'pickup_from': 480,
#   'pickup_to': 510,
#   'pickup_location_x': 206,
#   'pickup_location_y': 139,
#   'dropoff_point_id': 61653,
#   'dropoff_from': 480,
#   'dropoff_to': 610,
#   'dropoff_location_x': 238,
#   'dropoff_location_y': 76,
#   'payment': 305},
#  '11655': {'order_id': 11655,
#   'pickup_point_id': 41655,
#   'pickup_from': 439,
#   'pickup_to': 559,
#   'pickup_location_x': 118,
#   'pickup_location_y': 101,
#   'dropoff_point_id': 61655,
#   'dropoff_from': 439,
#   'dropoff_to': 619,
#   'dropoff_location_x': 123,
#   'dropoff_location_y': 105,
#   'payment': 368},
#  '11660': {'order_id': 11660,
#   'pickup_point_id': 41660,
#   'pickup_from': 660,
#   'pickup_to': 810,
#   'pickup_location_x': 200,
#   'pickup_location_y': 141,
#   'dropoff_point_id': 61660,
#   'dropoff_from': 780,
#   'dropoff_to': 900,
#   'dropoff_location_x': 271,
#   'dropoff_location_y': 216,
#   'payment': 343},
#  '11661': {'order_id': 11661,
#   'pickup_point_id': 41661,
#   'pickup_from': 440,
#   'pickup_to': 570,
#   'pickup_location_x': 168,
#   'pickup_location_y': 40,
#   'dropoff_point_id': 61661,
#   'dropoff_from': 440,
#   'dropoff_to': 600,
#   'dropoff_location_x': 182,
#   'dropoff_location_y': 7,
#   'payment': 255},
#  '11662': {'order_id': 11662,
#   'pickup_point_id': 41662,
#   'pickup_from': 480,
#   'pickup_to': 510,
#   'pickup_location_x': 65,
#   'pickup_location_y': 136,
#   'dropoff_point_id': 61662,
#   'dropoff_from': 540,
#   'dropoff_to': 780,
#   'dropoff_location_x': 107,
#   'dropoff_location_y': 91,
#   'payment': 328},
#  '11663': {'order_id': 11663,
#   'pickup_point_id': 41663,
#   'pickup_from': 440,
#   'pickup_to': 510,
#   'pickup_location_x': 174,
#   'pickup_location_y': 142,
#   'dropoff_point_id': 61663,
#   'dropoff_from': 440,
#   'dropoff_to': 570,
#   'dropoff_location_x': 182,
#   'dropoff_location_y': 175,
#   'payment': 265},
#  '11664': {'order_id': 11664,
#   'pickup_point_id': 41664,
#   'pickup_from': 480,
#   'pickup_to': 600,
#   'pickup_location_x': 322,
#   'pickup_location_y': 105,
#   'dropoff_point_id': 61664,
#   'dropoff_from': 540,
#   'dropoff_to': 840,
#   'dropoff_location_x': 243,
#   'dropoff_location_y': 159,
#   'payment': 402},
#  '11668': {'order_id': 11668,
#   'pickup_point_id': 41668,
#   'pickup_from': 440,
#   'pickup_to': 540,
#   'pickup_location_x': 87,
#   'pickup_location_y': 146,
#   'dropoff_point_id': 61668,
#   'dropoff_from': 660,
#   'dropoff_to': 780,
#   'dropoff_location_x': 234,
#   'dropoff_location_y': 146,
#   'payment': 400},
#  '11669': {'order_id': 11669,
#   'pickup_point_id': 41669,
#   'pickup_from': 450,
#   'pickup_to': 840,
#   'pickup_location_x': 256,
#   'pickup_location_y': 76,
#   'dropoff_point_id': 61669,
#   'dropoff_from': 660,
#   'dropoff_to': 840,
#   'dropoff_location_x': 265,
#   'dropoff_location_y': 78,
#   'payment': 250},
#  '11670': {'order_id': 11670,
#   'pickup_point_id': 41670,
#   'pickup_from': 450,
#   'pickup_to': 840,
#   'pickup_location_x': 167,
#   'pickup_location_y': 226,
#   'dropoff_point_id': 61670,
#   'dropoff_from': 660,
#   'dropoff_to': 840,
#   'dropoff_location_x': 176,
#   'dropoff_location_y': 212,
#   'payment': 250},
#  '11671': {'order_id': 11671,
#   'pickup_point_id': 41671,
#   'pickup_from': 450,
#   'pickup_to': 1020,
#   'pickup_location_x': 345,
#   'pickup_location_y': 94,
#   'dropoff_point_id': 61671,
#   'dropoff_from': 840,
#   'dropoff_to': 1020,
#   'dropoff_location_x': 355,
#   'dropoff_location_y': 102,
#   'payment': 250},
#  '11672': {'order_id': 11672,
#   'pickup_point_id': 41672,
#   'pickup_from': 450,
#   'pickup_to': 870,
#   'pickup_location_x': 340,
#   'pickup_location_y': 122,
#   'dropoff_point_id': 61672,
#   'dropoff_from': 480,
#   'dropoff_to': 930,
#   'dropoff_location_x': 359,
#   'dropoff_location_y': 185,
#   'payment': 200},
#  '11674': {'order_id': 11674,
#   'pickup_point_id': 41674,
#   'pickup_from': 441,
#   'pickup_to': 480,
#   'pickup_location_x': 253,
#   'pickup_location_y': 164,
#   'dropoff_point_id': 61674,
#   'dropoff_from': 480,
#   'dropoff_to': 630,
#   'dropoff_location_x': 184,
#   'dropoff_location_y': 110,
#   'payment': 396},
#  '11675': {'order_id': 11675,
#   'pickup_point_id': 41675,
#   'pickup_from': 480,
#   'pickup_to': 720,
#   'pickup_location_x': 224,
#   'pickup_location_y': 128,
#   'dropoff_point_id': 61675,
#   'dropoff_from': 480,
#   'dropoff_to': 720,
#   'dropoff_location_x': 217,
#   'dropoff_location_y': 120,
#   'payment': 170},
#  ...}

# %%
couriers = json_file['couriers']

# %%
orders = json_file['orders']
orders_pickup_times_0 = np.array([(order['pickup_from'], order['pickup_to']) for order in orders.values()])
orders_pickup_times = np.array([(((order['pickup_from'])), ((order['pickup_to']))) for order in orders.values()])
orders_drop_times = np.array([(((order['dropoff_from'])), ((order['dropoff_to']))) for order in orders.values()])
orders_from = np.array([(order['pickup_location_x'], order['pickup_location_y']) for order in orders.values()])
orders_to = np.array([(order['dropoff_location_x'], order['dropoff_location_y']) for order in orders.values()])
payments = np.array([(order['payment']) for order in orders.values()])

delivery_dists = np.abs(orders_to - orders_from).sum(axis=1)

# %%
ord_from = [(a, b) for a, b in orders_from]
ord_to = [(a, b) for a, b in orders_to]

# %%
def plot_moves(x, y, cur_ids):
    from_points = orders_from[cur_ids]
    to_points = orders_from[cur_ids]

    plt.plot([x], [y], '*')
    plt.plot(from_points[:, 0], from_points[:, 1], '.', color='red')
#    plt.plot(to_points[:, 0], to_points[:, 1], '.', color='blue')

# %%
def from_point_xy(i):
    return orders_from[i]

def to_point_xy(i):
    return orders_to[i]

# %%
def single_step(x, y, used, cur_time=360, R=120, n_orders=8):
    dists = manhattan(orders_from, (x, y))
    dists_to = delivery_dists
    
    time_to_arrive = cur_time + dists + 10
    
    can_arrive = time_to_arrive < orders_pickup_times[:, 1]
    can_arrive_before = time_to_arrive + 10 > orders_pickup_times[:, 0]
    
    can_deliever = time_to_arrive + delivery_dists < orders_drop_times[:, 1]
    
    can_arrive_2 = can_arrive * can_arrive_before * can_deliever
    
    if np.all(can_arrive == False):
        return []
    
    near_dists = can_arrive_2 * dists + 1000000 * (1 - can_arrive)
    
    if np.all(near_dists == 1000000):
        return []
    
    pts = np.argsort(near_dists)[:n_orders]

    return pts

# %%
def manhattan(vector, point):
    return np.abs((vector - point)).sum(axis=1)

def courier_moves(x, y, cur_time, cur_step=0, used=None, max_step=15, n_vals=10):
    if cur_step > max_step:
        return np.zeros(0)

    current_to_use = single_step(x, y, used, cur_time, n_orders=n_vals)
    resulted_ids = list(current_to_use.copy())
    for cur_order in current_to_use:
        if used[cur_order] == 1:
            continue
        else:
            used[cur_order] = 1
            cur_x_f = orders_from[cur_order, 0]
            cur_y_f = orders_from[cur_order, 1]
            
            cur_x = orders_to[cur_order, 0]
            cur_y = orders_to[cur_order, 1]
            dist_manh = abs(cur_x - x) + abs(cur_y - y) #+ abs(cur_x_f - x) + abs(cur_y_f - y)
            
            resulted_ids = list(resulted_ids) + list(courier_moves(cur_x, cur_y, cur_time + dist_manh, cur_step + 1, used, max_step, max(1, n_vals // 2)))

    return resulted_ids

# %%
results = []

for cour in couriers:
    cou_x = cour['location_x']
    cou_y = cour['location_y']
    
    is_used = np.zeros(len(orders))
    cour = courier_moves(cou_x, cou_y, 360, used=is_used)
    results.append((cou_x, cou_y, cour))
    
    break

# %%
len(set(cour))
# Out:
# 190

# %%
inters = []

for _, _, i in results:
    for _, _, j in results:
        inters.append(len(set(i).intersection(j)))

# %%
def use_extra_orders(x, y, order_id):
    from_x, from_y = orders_from[order_id]
    to_x, to_y = orders_to[order_id]
    
    from_dist = abs(from_x - x) + abs(from_y - y)
    to_dist = abs(from_x - to_x) + abs(from_y - to_y)
    can_pick = (360 + from_dist + 10) < orders_pickup_times[order_id, 1]
        
    drop_time = 360 + max(from_dist, orders_pickup_times[order_id, 0]) + to_dist + 10
    can_drop = drop_time + 10 < orders_drop_times[order_id, 1]
    
    return can_drop and can_pick

# %%
for i, aaa in enumerate(results):
    _, _, cour = aaa
    courier = couriers[i]
    
    cour_x = courier['location_x']
    cour_y = courier['location_y']
    cr = list(set(cour))
    new_cr = [cr_val for cr_val in cr if use_extra_orders(cour_x, cour_y, cr_val)]
    
    print(len(cr), len(new_cr))
    
    
    ords = np.array(list(orders.values()))[new_cr]

    o = open(f'outs/{i}.json', 'w')
    
    result_json = {'orders': ords.tolist(), 'couriers': [courier]}
    
    json.dump(result_json, o)
    
    o.close()
    
    break
# Out:
# 190 105

# %%
ords
# Out:
# array([{'order_id': 16035, 'pickup_point_id': 46035, 'pickup_from': 390, 'pickup_to': 1110, 'pickup_location_x': 74, 'pickup_location_y': 126, 'dropoff_point_id': 66035, 'dropoff_from': 1140, 'dropoff_to': 1200, 'dropoff_location_x': 289, 'dropoff_location_y': 63, 'payment': 439},
#        {'order_id': 16551, 'pickup_point_id': 46551, 'pickup_from': 300, 'pickup_to': 900, 'pickup_location_x': 175, 'pickup_location_y': 199, 'dropoff_point_id': 66551, 'dropoff_from': 819, 'dropoff_to': 960, 'dropoff_location_x': 229, 'dropoff_location_y': 77, 'payment': 398},
#        {'order_id': 16042, 'pickup_point_id': 46042, 'pickup_from': 300, 'pickup_to': 900, 'pickup_location_x': 148, 'pickup_location_y': 95, 'dropoff_point_id': 66042, 'dropoff_from': 763, 'dropoff_to': 930, 'dropoff_location_x': 212, 'dropoff_location_y': 255, 'payment': 314},
#        {'order_id': 16557, 'pickup_point_id': 46557, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 232, 'pickup_location_y': 115, 'dropoff_point_id': 66557, 'dropoff_from': 820, 'dropoff_to': 900, 'dropoff_location_x': 297, 'dropoff_location_y': 66, 'payment': 366},
#        {'order_id': 16045, 'pickup_point_id': 46045, 'pickup_from': 300, 'pickup_to': 840, 'pickup_location_x': 89, 'pickup_location_y': 179, 'dropoff_point_id': 66045, 'dropoff_from': 764, 'dropoff_to': 900, 'dropoff_location_x': 242, 'dropoff_location_y': 179, 'payment': 413},
#        {'order_id': 16568, 'pickup_point_id': 46568, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 285, 'pickup_location_y': 150, 'dropoff_point_id': 66568, 'dropoff_from': 930, 'dropoff_to': 960, 'dropoff_location_x': 182, 'dropoff_location_y': 152, 'payment': 431},
#        {'order_id': 16056, 'pickup_point_id': 46056, 'pickup_from': 390, 'pickup_to': 810, 'pickup_location_x': 244, 'pickup_location_y': 120, 'dropoff_point_id': 66056, 'dropoff_from': 765, 'dropoff_to': 810, 'dropoff_location_x': 238, 'dropoff_location_y': 123, 'payment': 177},
#        {'order_id': 16574, 'pickup_point_id': 46574, 'pickup_from': 330, 'pickup_to': 870, 'pickup_location_x': 274, 'pickup_location_y': 110, 'dropoff_point_id': 66574, 'dropoff_from': 900, 'dropoff_to': 960, 'dropoff_location_x': 95, 'dropoff_location_y': 84, 'payment': 402},
#        {'order_id': 16576, 'pickup_point_id': 46576, 'pickup_from': 330, 'pickup_to': 1110, 'pickup_location_x': 176, 'pickup_location_y': 180, 'dropoff_point_id': 66576, 'dropoff_from': 1110, 'dropoff_to': 1140, 'dropoff_location_x': 133, 'dropoff_location_y': 58, 'payment': 405},
#        {'order_id': 17096, 'pickup_point_id': 47096, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 278, 'pickup_location_y': 114, 'dropoff_point_id': 67096, 'dropoff_from': 1050, 'dropoff_to': 1110, 'dropoff_location_x': 117, 'dropoff_location_y': 57, 'payment': 475},
#        {'order_id': 17097, 'pickup_point_id': 47097, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 260, 'pickup_location_y': 85, 'dropoff_point_id': 67097, 'dropoff_from': 934, 'dropoff_to': 1110, 'dropoff_location_x': 213, 'dropoff_location_y': 292, 'payment': 488},
#        {'order_id': 16595, 'pickup_point_id': 46595, 'pickup_from': 420, 'pickup_to': 900, 'pickup_location_x': 264, 'pickup_location_y': 141, 'dropoff_point_id': 66595, 'dropoff_from': 825, 'dropoff_to': 930, 'dropoff_location_x': 258, 'dropoff_location_y': 237, 'payment': 351},
#        {'order_id': 16599, 'pickup_point_id': 46599, 'pickup_from': 420, 'pickup_to': 1080, 'pickup_location_x': 197, 'pickup_location_y': 179, 'dropoff_point_id': 66599, 'dropoff_from': 826, 'dropoff_to': 930, 'dropoff_location_x': 225, 'dropoff_location_y': 123, 'payment': 264},
#        {'order_id': 10937, 'pickup_point_id': 40937, 'pickup_from': 360, 'pickup_to': 1140, 'pickup_location_x': 137, 'pickup_location_y': 201, 'dropoff_point_id': 60937, 'dropoff_from': 1170, 'dropoff_to': 1200, 'dropoff_location_x': 28, 'dropoff_location_y': 147, 'payment': 439},
#        {'order_id': 17126, 'pickup_point_id': 47126, 'pickup_from': 420, 'pickup_to': 1020, 'pickup_location_x': 278, 'pickup_location_y': 114, 'dropoff_point_id': 67126, 'dropoff_from': 943, 'dropoff_to': 1080, 'dropoff_location_x': 118, 'dropoff_location_y': 68, 'payment': 475},
#        {'order_id': 16614, 'pickup_point_id': 46614, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 223, 'pickup_location_y': 108, 'dropoff_point_id': 66614, 'dropoff_from': 930, 'dropoff_to': 990, 'dropoff_location_x': 24, 'dropoff_location_y': 67, 'payment': 500},
#        {'order_id': 11863, 'pickup_point_id': 41863, 'pickup_from': 454, 'pickup_to': 900, 'pickup_location_x': 174, 'pickup_location_y': 148, 'dropoff_point_id': 61863, 'dropoff_from': 454, 'dropoff_to': 930, 'dropoff_location_x': 176, 'dropoff_location_y': 240, 'payment': 233},
#        {'order_id': 17140, 'pickup_point_id': 47140, 'pickup_from': 390, 'pickup_to': 1050, 'pickup_location_x': 25, 'pickup_location_y': 77, 'dropoff_point_id': 67140, 'dropoff_from': 949, 'dropoff_to': 1140, 'dropoff_location_x': 290, 'dropoff_location_y': 14, 'payment': 622},
#        {'order_id': 17145, 'pickup_point_id': 47145, 'pickup_from': 390, 'pickup_to': 1110, 'pickup_location_x': 42, 'pickup_location_y': 162, 'dropoff_point_id': 67145, 'dropoff_from': 953, 'dropoff_to': 1140, 'dropoff_location_x': 185, 'dropoff_location_y': 5, 'payment': 544},
#        {'order_id': 17147, 'pickup_point_id': 47147, 'pickup_from': 300, 'pickup_to': 1200, 'pickup_location_x': 52, 'pickup_location_y': 193, 'dropoff_point_id': 67147, 'dropoff_from': 953, 'dropoff_to': 1230, 'dropoff_location_x': 158, 'dropoff_location_y': 163, 'payment': 235},
#        {'order_id': 16640, 'pickup_point_id': 46640, 'pickup_from': 330, 'pickup_to': 960, 'pickup_location_x': 244, 'pickup_location_y': 151, 'dropoff_point_id': 66640, 'dropoff_from': 990, 'dropoff_to': 1020, 'dropoff_location_x': 157, 'dropoff_location_y': 261, 'payment': 440},
#        {'order_id': 13604, 'pickup_point_id': 43604, 'pickup_from': 360, 'pickup_to': 1200, 'pickup_location_x': 218, 'pickup_location_y': 254, 'dropoff_point_id': 63604, 'dropoff_from': 990, 'dropoff_to': 1140, 'dropoff_location_x': 132, 'dropoff_location_y': 225, 'payment': 936},
#        {'order_id': 15623, 'pickup_point_id': 45623, 'pickup_from': 330, 'pickup_to': 930, 'pickup_location_x': 203, 'pickup_location_y': 94, 'dropoff_point_id': 65623, 'dropoff_from': 723, 'dropoff_to': 960, 'dropoff_location_x': 345, 'dropoff_location_y': 82, 'payment': 370},
#        {'order_id': 16654, 'pickup_point_id': 46654, 'pickup_from': 300, 'pickup_to': 900, 'pickup_location_x': 185, 'pickup_location_y': 18, 'dropoff_point_id': 66654, 'dropoff_from': 835, 'dropoff_to': 990, 'dropoff_location_x': 38, 'dropoff_location_y': 119, 'payment': 473},
#        {'order_id': 17170, 'pickup_point_id': 47170, 'pickup_from': 330, 'pickup_to': 1230, 'pickup_location_x': 263, 'pickup_location_y': 119, 'dropoff_point_id': 67170, 'dropoff_from': 990, 'dropoff_to': 1230, 'dropoff_location_x': 130, 'dropoff_location_y': 226, 'payment': 346},
#        {'order_id': 11918, 'pickup_point_id': 41918, 'pickup_from': 330, 'pickup_to': 900, 'pickup_location_x': 138, 'pickup_location_y': 218, 'dropoff_point_id': 61918, 'dropoff_from': 900, 'dropoff_to': 1020, 'dropoff_location_x': 260, 'dropoff_location_y': 52, 'payment': 465},
#        {'order_id': 17176, 'pickup_point_id': 47176, 'pickup_from': 330, 'pickup_to': 1230, 'pickup_location_x': 44, 'pickup_location_y': 198, 'dropoff_point_id': 67176, 'dropoff_from': 977, 'dropoff_to': 1230, 'dropoff_location_x': 322, 'dropoff_location_y': 51, 'payment': 431},
#        {'order_id': 14475, 'pickup_point_id': 44475, 'pickup_from': 330, 'pickup_to': 1080, 'pickup_location_x': 257, 'pickup_location_y': 70, 'dropoff_point_id': 64475, 'dropoff_from': 690, 'dropoff_to': 1230, 'dropoff_location_x': 78, 'dropoff_location_y': 45, 'payment': 579},
#        {'order_id': 16667, 'pickup_point_id': 46667, 'pickup_from': 420, 'pickup_to': 900, 'pickup_location_x': 232, 'pickup_location_y': 115, 'dropoff_point_id': 66667, 'dropoff_from': 900, 'dropoff_to': 960, 'dropoff_location_x': 130, 'dropoff_location_y': 141, 'payment': 343},
#        {'order_id': 11935, 'pickup_point_id': 41935, 'pickup_from': 470, 'pickup_to': 1020, 'pickup_location_x': 100, 'pickup_location_y': 226, 'dropoff_point_id': 61935, 'dropoff_from': 840, 'dropoff_to': 1020, 'dropoff_location_x': 116, 'dropoff_location_y': 218, 'payment': 290},
#        {'order_id': 16673, 'pickup_point_id': 46673, 'pickup_from': 420, 'pickup_to': 960, 'pickup_location_x': 195, 'pickup_location_y': 92, 'dropoff_point_id': 66673, 'dropoff_from': 838, 'dropoff_to': 990, 'dropoff_location_x': 263, 'dropoff_location_y': 64, 'payment': 378},
#        {'order_id': 17186, 'pickup_point_id': 47186, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 250, 'pickup_location_y': 73, 'dropoff_point_id': 67186, 'dropoff_from': 982, 'dropoff_to': 1080, 'dropoff_location_x': 207, 'dropoff_location_y': 134, 'payment': 290},
#        {'order_id': 16692, 'pickup_point_id': 46692, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 325, 'pickup_location_y': 122, 'dropoff_point_id': 66692, 'dropoff_from': 842, 'dropoff_to': 960, 'dropoff_location_x': 247, 'dropoff_location_y': 85, 'payment': 417},
#        {'order_id': 15674, 'pickup_point_id': 45674, 'pickup_from': 420, 'pickup_to': 870, 'pickup_location_x': 162, 'pickup_location_y': 198, 'dropoff_point_id': 65674, 'dropoff_from': 727, 'dropoff_to': 1020, 'dropoff_location_x': 205, 'dropoff_location_y': 54, 'payment': 487},
#        {'order_id': 17236, 'pickup_point_id': 47236, 'pickup_from': 330, 'pickup_to': 1140, 'pickup_location_x': 178, 'pickup_location_y': 131, 'dropoff_point_id': 67236, 'dropoff_from': 1025, 'dropoff_to': 1170, 'dropoff_location_x': 81, 'dropoff_location_y': 47, 'payment': 466},
#        {'order_id': 17237, 'pickup_point_id': 47237, 'pickup_from': 420, 'pickup_to': 1200, 'pickup_location_x': 371, 'pickup_location_y': 92, 'dropoff_point_id': 67237, 'dropoff_from': 1026, 'dropoff_to': 1230, 'dropoff_location_x': 286, 'dropoff_location_y': 9, 'payment': 472},
#        {'order_id': 17241, 'pickup_point_id': 47241, 'pickup_from': 390, 'pickup_to': 1200, 'pickup_location_x': 158, 'pickup_location_y': 208, 'dropoff_point_id': 67241, 'dropoff_from': 1030, 'dropoff_to': 1230, 'dropoff_location_x': 19, 'dropoff_location_y': 169, 'payment': 431},
#        {'order_id': 17244, 'pickup_point_id': 47244, 'pickup_from': 300, 'pickup_to': 1110, 'pickup_location_x': 100, 'pickup_location_y': 101, 'dropoff_point_id': 67244, 'dropoff_from': 1140, 'dropoff_to': 1200, 'dropoff_location_x': 242, 'dropoff_location_y': 102, 'payment': 391},
#        {'order_id': 17249, 'pickup_point_id': 47249, 'pickup_from': 300, 'pickup_to': 1110, 'pickup_location_x': 288, 'pickup_location_y': 103, 'dropoff_point_id': 67249, 'dropoff_from': 1140, 'dropoff_to': 1170, 'dropoff_location_x': 130, 'dropoff_location_y': 90, 'payment': 389},
#        {'order_id': 17254, 'pickup_point_id': 47254, 'pickup_from': 390, 'pickup_to': 1140, 'pickup_location_x': 130, 'pickup_location_y': 60, 'dropoff_point_id': 67254, 'dropoff_from': 1140, 'dropoff_to': 1230, 'dropoff_location_x': 269, 'dropoff_location_y': 254, 'payment': 441},
#        {'order_id': 17261, 'pickup_point_id': 47261, 'pickup_from': 420, 'pickup_to': 1200, 'pickup_location_x': 35, 'pickup_location_y': 79, 'dropoff_point_id': 67261, 'dropoff_from': 1080, 'dropoff_to': 1230, 'dropoff_location_x': 246, 'dropoff_location_y': 100, 'payment': 456},
#        {'order_id': 16755, 'pickup_point_id': 46755, 'pickup_from': 390, 'pickup_to': 930, 'pickup_location_x': 210, 'pickup_location_y': 187, 'dropoff_point_id': 66755, 'dropoff_from': 853, 'dropoff_to': 960, 'dropoff_location_x': 230, 'dropoff_location_y': 132, 'payment': 310},
#        {'order_id': 15732, 'pickup_point_id': 45732, 'pickup_from': 390, 'pickup_to': 990, 'pickup_location_x': 214, 'pickup_location_y': 107, 'dropoff_point_id': 65732, 'dropoff_from': 733, 'dropoff_to': 1050, 'dropoff_location_x': 20, 'dropoff_location_y': 71, 'payment': 522},
#        {'order_id': 17274, 'pickup_point_id': 47274, 'pickup_from': 360, 'pickup_to': 1140, 'pickup_location_x': 110, 'pickup_location_y': 128, 'dropoff_point_id': 67274, 'dropoff_from': 1058, 'dropoff_to': 1170, 'dropoff_location_x': 208, 'dropoff_location_y': 7, 'payment': 426},
#        {'order_id': 17280, 'pickup_point_id': 47280, 'pickup_from': 390, 'pickup_to': 1170, 'pickup_location_x': 219, 'pickup_location_y': 261, 'dropoff_point_id': 67280, 'dropoff_from': 1170, 'dropoff_to': 1200, 'dropoff_location_x': 311, 'dropoff_location_y': 5, 'payment': 510},
#        {'order_id': 17284, 'pickup_point_id': 47284, 'pickup_from': 420, 'pickup_to': 1140, 'pickup_location_x': 104, 'pickup_location_y': 91, 'dropoff_point_id': 67284, 'dropoff_from': 1074, 'dropoff_to': 1200, 'dropoff_location_x': 280, 'dropoff_location_y': 152, 'payment': 419},
#        {'order_id': 16262, 'pickup_point_id': 46262, 'pickup_from': 330, 'pickup_to': 900, 'pickup_location_x': 211, 'pickup_location_y': 118, 'dropoff_point_id': 66262, 'dropoff_from': 786, 'dropoff_to': 960, 'dropoff_location_x': 88, 'dropoff_location_y': 148, 'payment': 457},
#        {'order_id': 11263, 'pickup_point_id': 41263, 'pickup_from': 401, 'pickup_to': 1110, 'pickup_location_x': 18, 'pickup_location_y': 166, 'dropoff_point_id': 61263, 'dropoff_from': 480, 'dropoff_to': 1140, 'dropoff_location_x': 103, 'dropoff_location_y': 40, 'payment': 326},
#        {'order_id': 16782, 'pickup_point_id': 46782, 'pickup_from': 300, 'pickup_to': 990, 'pickup_location_x': 198, 'pickup_location_y': 158, 'dropoff_point_id': 66782, 'dropoff_from': 900, 'dropoff_to': 1020, 'dropoff_location_x': 106, 'dropoff_location_y': 99, 'payment': 327},
#        {'order_id': 17296, 'pickup_point_id': 47296, 'pickup_from': 300, 'pickup_to': 1170, 'pickup_location_x': 101, 'pickup_location_y': 101, 'dropoff_point_id': 67296, 'dropoff_from': 1103, 'dropoff_to': 1200, 'dropoff_location_x': 110, 'dropoff_location_y': 66, 'payment': 224},
#        {'order_id': 17297, 'pickup_point_id': 47297, 'pickup_from': 360, 'pickup_to': 1170, 'pickup_location_x': 110, 'pickup_location_y': 66, 'dropoff_point_id': 67297, 'dropoff_from': 1105, 'dropoff_to': 1200, 'dropoff_location_x': 101, 'dropoff_location_y': 101, 'payment': 236},
#        {'order_id': 17303, 'pickup_point_id': 47303, 'pickup_from': 330, 'pickup_to': 1170, 'pickup_location_x': 243, 'pickup_location_y': 115, 'dropoff_point_id': 67303, 'dropoff_from': 1200, 'dropoff_to': 1230, 'dropoff_location_x': 135, 'dropoff_location_y': 51, 'payment': 359},
#        {'order_id': 16815, 'pickup_point_id': 46815, 'pickup_from': 330, 'pickup_to': 959, 'pickup_location_x': 279, 'pickup_location_y': 226, 'dropoff_point_id': 66815, 'dropoff_from': 959, 'dropoff_to': 1049, 'dropoff_location_x': 163, 'dropoff_location_y': 121, 'payment': 500},
#        {'order_id': 11338, 'pickup_point_id': 41338, 'pickup_from': 411, 'pickup_to': 840, 'pickup_location_x': 200, 'pickup_location_y': 154, 'dropoff_point_id': 61338, 'dropoff_from': 411, 'dropoff_to': 870, 'dropoff_location_x': 219, 'dropoff_location_y': 98, 'payment': 277},
#        {'order_id': 16826, 'pickup_point_id': 46826, 'pickup_from': 420, 'pickup_to': 930, 'pickup_location_x': 265, 'pickup_location_y': 71, 'dropoff_point_id': 66826, 'dropoff_from': 866, 'dropoff_to': 960, 'dropoff_location_x': 230, 'dropoff_location_y': 134, 'payment': 285},
#        {'order_id': 16830, 'pickup_point_id': 46830, 'pickup_from': 360, 'pickup_to': 1020, 'pickup_location_x': 139, 'pickup_location_y': 138, 'dropoff_point_id': 66830, 'dropoff_from': 866, 'dropoff_to': 1050, 'dropoff_location_x': 122, 'dropoff_location_y': 18, 'payment': 440},
#        {'order_id': 16320, 'pickup_point_id': 46320, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 117, 'pickup_location_y': 140, 'dropoff_point_id': 66320, 'dropoff_from': 870, 'dropoff_to': 930, 'dropoff_location_x': 247, 'dropoff_location_y': 119, 'payment': 311},
#        {'order_id': 16851, 'pickup_point_id': 46851, 'pickup_from': 360, 'pickup_to': 930, 'pickup_location_x': 274, 'pickup_location_y': 110, 'dropoff_point_id': 66851, 'dropoff_from': 871, 'dropoff_to': 990, 'dropoff_location_x': 329, 'dropoff_location_y': 53, 'payment': 324},
#        {'order_id': 15319, 'pickup_point_id': 45319, 'pickup_from': 330, 'pickup_to': 840, 'pickup_location_x': 166, 'pickup_location_y': 7, 'dropoff_point_id': 65319, 'dropoff_from': 870, 'dropoff_to': 1020, 'dropoff_location_x': 224, 'dropoff_location_y': 142, 'payment': 413},
#        {'order_id': 15832, 'pickup_point_id': 45832, 'pickup_from': 300, 'pickup_to': 780, 'pickup_location_x': 288, 'pickup_location_y': 131, 'dropoff_point_id': 65832, 'dropoff_from': 742, 'dropoff_to': 840, 'dropoff_location_x': 220, 'dropoff_location_y': 109, 'payment': 478},
#        {'order_id': 14804, 'pickup_point_id': 44804, 'pickup_from': 420, 'pickup_to': 1050, 'pickup_location_x': 261, 'pickup_location_y': 104, 'dropoff_point_id': 64804, 'dropoff_from': 1080, 'dropoff_to': 1140, 'dropoff_location_x': 133, 'dropoff_location_y': 86, 'payment': 401},
#        {'order_id': 15325, 'pickup_point_id': 45325, 'pickup_from': 360, 'pickup_to': 960, 'pickup_location_x': 114, 'pickup_location_y': 82, 'dropoff_point_id': 65325, 'dropoff_from': 840, 'dropoff_to': 1050, 'dropoff_location_x': 218, 'dropoff_location_y': 117, 'payment': 585},
#        {'order_id': 16352, 'pickup_point_id': 46352, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 270, 'pickup_location_y': 69, 'dropoff_point_id': 66352, 'dropoff_from': 840, 'dropoff_to': 974, 'dropoff_location_x': 188, 'dropoff_location_y': 159, 'payment': 304},
#        {'order_id': 15842, 'pickup_point_id': 45842, 'pickup_from': 330, 'pickup_to': 960, 'pickup_location_x': 200, 'pickup_location_y': 74, 'dropoff_point_id': 65842, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 137, 'dropoff_location_y': 279, 'payment': 613},
#        {'order_id': 15844, 'pickup_point_id': 45844, 'pickup_from': 420, 'pickup_to': 1170, 'pickup_location_x': 94, 'pickup_location_y': 77, 'dropoff_point_id': 65844, 'dropoff_from': 1110, 'dropoff_to': 1200, 'dropoff_location_x': 228, 'dropoff_location_y': 81, 'payment': 467},
#        {'order_id': 16363, 'pickup_point_id': 46363, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 195, 'pickup_location_y': 183, 'dropoff_point_id': 66363, 'dropoff_from': 900, 'dropoff_to': 930, 'dropoff_location_x': 205, 'dropoff_location_y': 98, 'payment': 306},
#        {'order_id': 16876, 'pickup_point_id': 46876, 'pickup_from': 300, 'pickup_to': 930, 'pickup_location_x': 218, 'pickup_location_y': 146, 'dropoff_point_id': 66876, 'dropoff_from': 930, 'dropoff_to': 990, 'dropoff_location_x': 121, 'dropoff_location_y': 79, 'payment': 337},
#        {'order_id': 16882, 'pickup_point_id': 46882, 'pickup_from': 300, 'pickup_to': 930, 'pickup_location_x': 218, 'pickup_location_y': 155, 'dropoff_point_id': 66882, 'dropoff_from': 878, 'dropoff_to': 960, 'dropoff_location_x': 211, 'dropoff_location_y': 78, 'payment': 338},
#        {'order_id': 13998, 'pickup_point_id': 43998, 'pickup_from': 300, 'pickup_to': 1020, 'pickup_location_x': 344, 'pickup_location_y': 65, 'dropoff_point_id': 63998, 'dropoff_from': 720, 'dropoff_to': 1050, 'dropoff_location_x': 211, 'dropoff_location_y': 108, 'payment': 306},
#        {'order_id': 15350, 'pickup_point_id': 45350, 'pickup_from': 330, 'pickup_to': 990, 'pickup_location_x': 225, 'pickup_location_y': 114, 'dropoff_point_id': 65350, 'dropoff_from': 960, 'dropoff_to': 1020, 'dropoff_location_x': 265, 'dropoff_location_y': 70, 'payment': 494},
#        {'order_id': 15869, 'pickup_point_id': 45869, 'pickup_from': 330, 'pickup_to': 1050, 'pickup_location_x': 229, 'pickup_location_y': 125, 'dropoff_point_id': 65869, 'dropoff_from': 990, 'dropoff_to': 1080, 'dropoff_location_x': 105, 'dropoff_location_y': 111, 'payment': 368},
#        {'order_id': 16384, 'pickup_point_id': 46384, 'pickup_from': 360, 'pickup_to': 930, 'pickup_location_x': 202, 'pickup_location_y': 130, 'dropoff_point_id': 66384, 'dropoff_from': 798, 'dropoff_to': 960, 'dropoff_location_x': 345, 'dropoff_location_y': 58, 'payment': 440},
#        {'order_id': 16385, 'pickup_point_id': 46385, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 226, 'pickup_location_y': 117, 'dropoff_point_id': 66385, 'dropoff_from': 798, 'dropoff_to': 900, 'dropoff_location_x': 74, 'dropoff_location_y': 119, 'payment': 375},
#        {'order_id': 16898, 'pickup_point_id': 46898, 'pickup_from': 360, 'pickup_to': 960, 'pickup_location_x': 276, 'pickup_location_y': 54, 'dropoff_point_id': 66898, 'dropoff_from': 930, 'dropoff_to': 1067, 'dropoff_location_x': 147, 'dropoff_location_y': 122, 'payment': 337},
#        {'order_id': 16910, 'pickup_point_id': 46910, 'pickup_from': 360, 'pickup_to': 930, 'pickup_location_x': 279, 'pickup_location_y': 229, 'dropoff_point_id': 66910, 'dropoff_from': 1050, 'dropoff_to': 1080, 'dropoff_location_x': 274, 'dropoff_location_y': 9, 'payment': 706},
#        {'order_id': 12347, 'pickup_point_id': 42347, 'pickup_from': 390, 'pickup_to': 870, 'pickup_location_x': 82, 'pickup_location_y': 22, 'dropoff_point_id': 62347, 'dropoff_from': 870, 'dropoff_to': 960, 'dropoff_location_x': 183, 'dropoff_location_y': 102, 'payment': 290},
#        {'order_id': 14869, 'pickup_point_id': 44869, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 117, 'pickup_location_y': 193, 'dropoff_point_id': 64869, 'dropoff_from': 664, 'dropoff_to': 900, 'dropoff_location_x': 192, 'dropoff_location_y': 181, 'payment': 533},
#        {'order_id': 10591, 'pickup_point_id': 40591, 'pickup_from': 360, 'pickup_to': 1110, 'pickup_location_x': 230, 'pickup_location_y': 1, 'dropoff_point_id': 60591, 'dropoff_from': 1140, 'dropoff_to': 1200, 'dropoff_location_x': 287, 'dropoff_location_y': 113, 'payment': 449},
#        {'order_id': 16416, 'pickup_point_id': 46416, 'pickup_from': 330, 'pickup_to': 870, 'pickup_location_x': 251, 'pickup_location_y': 63, 'dropoff_point_id': 66416, 'dropoff_from': 870, 'dropoff_to': 930, 'dropoff_location_x': 196, 'dropoff_location_y': 190, 'payment': 583},
#        {'order_id': 16930, 'pickup_point_id': 46930, 'pickup_from': 300, 'pickup_to': 960, 'pickup_location_x': 257, 'pickup_location_y': 247, 'dropoff_point_id': 66930, 'dropoff_from': 930, 'dropoff_to': 1020, 'dropoff_location_x': 253, 'dropoff_location_y': 71, 'payment': 429},
#        {'order_id': 16933, 'pickup_point_id': 46933, 'pickup_from': 300, 'pickup_to': 990, 'pickup_location_x': 165, 'pickup_location_y': 153, 'dropoff_point_id': 66933, 'dropoff_from': 890, 'dropoff_to': 1020, 'dropoff_location_x': 253, 'dropoff_location_y': 100, 'payment': 323},
#        {'order_id': 16421, 'pickup_point_id': 46421, 'pickup_from': 300, 'pickup_to': 990, 'pickup_location_x': 211, 'pickup_location_y': 80, 'dropoff_point_id': 66421, 'dropoff_from': 803, 'dropoff_to': 1020, 'dropoff_location_x': 364, 'dropoff_location_y': 158, 'payment': 365},
#        {'order_id': 16936, 'pickup_point_id': 46936, 'pickup_from': 390, 'pickup_to': 1050, 'pickup_location_x': 275, 'pickup_location_y': 2, 'dropoff_point_id': 66936, 'dropoff_from': 1050, 'dropoff_to': 1200, 'dropoff_location_x': 122, 'dropoff_location_y': 127, 'payment': 413},
#        {'order_id': 16938, 'pickup_point_id': 46938, 'pickup_from': 420, 'pickup_to': 1020, 'pickup_location_x': 244, 'pickup_location_y': 122, 'dropoff_point_id': 66938, 'dropoff_from': 892, 'dropoff_to': 1050, 'dropoff_location_x': 368, 'dropoff_location_y': 110, 'payment': 332},
#        {'order_id': 16942, 'pickup_point_id': 46942, 'pickup_from': 360, 'pickup_to': 990, 'pickup_location_x': 91, 'pickup_location_y': 119, 'dropoff_point_id': 66942, 'dropoff_from': 960, 'dropoff_to': 1146, 'dropoff_location_x': 268, 'dropoff_location_y': 73, 'payment': 443},
#        {'order_id': 11542, 'pickup_point_id': 41542, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 173, 'pickup_location_y': 216, 'dropoff_point_id': 61542, 'dropoff_from': 780, 'dropoff_to': 960, 'dropoff_location_x': 240, 'dropoff_location_y': 144, 'payment': 373},
#        {'order_id': 16951, 'pickup_point_id': 46951, 'pickup_from': 420, 'pickup_to': 990, 'pickup_location_x': 197, 'pickup_location_y': 139, 'dropoff_point_id': 66951, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 216, 'dropoff_location_y': 243, 'payment': 383},
#        {'order_id': 15416, 'pickup_point_id': 45416, 'pickup_from': 420, 'pickup_to': 1020, 'pickup_location_x': 165, 'pickup_location_y': 133, 'dropoff_point_id': 65416, 'dropoff_from': 840, 'dropoff_to': 1020, 'dropoff_location_x': 189, 'dropoff_location_y': 139, 'payment': 250},
#        {'order_id': 15930, 'pickup_point_id': 45930, 'pickup_from': 330, 'pickup_to': 840, 'pickup_location_x': 276, 'pickup_location_y': 99, 'dropoff_point_id': 65930, 'dropoff_from': 753, 'dropoff_to': 960, 'dropoff_location_x': 128, 'dropoff_location_y': 163, 'payment': 386},
#        {'order_id': 15421, 'pickup_point_id': 45421, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 165, 'pickup_location_y': 12, 'dropoff_point_id': 65421, 'dropoff_from': 810, 'dropoff_to': 1093, 'dropoff_location_x': 17, 'dropoff_location_y': 148, 'payment': 488},
#        {'order_id': 15424, 'pickup_point_id': 45424, 'pickup_from': 300, 'pickup_to': 780, 'pickup_location_x': 185, 'pickup_location_y': 44, 'dropoff_point_id': 65424, 'dropoff_from': 706, 'dropoff_to': 810, 'dropoff_location_x': 194, 'dropoff_location_y': 134, 'payment': 312},
#        {'order_id': 16456, 'pickup_point_id': 46456, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 127, 'pickup_location_y': 132, 'dropoff_point_id': 66456, 'dropoff_from': 870, 'dropoff_to': 930, 'dropoff_location_x': 214, 'dropoff_location_y': 85, 'payment': 329},
#        {'order_id': 15434, 'pickup_point_id': 45434, 'pickup_from': 390, 'pickup_to': 1200, 'pickup_location_x': 130, 'pickup_location_y': 211, 'dropoff_point_id': 65434, 'dropoff_from': 707, 'dropoff_to': 1230, 'dropoff_location_x': 291, 'dropoff_location_y': 190, 'payment': 435},
#        {'order_id': 10670, 'pickup_point_id': 40670, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 139, 'pickup_location_y': 46, 'dropoff_point_id': 60670, 'dropoff_from': 900, 'dropoff_to': 960, 'dropoff_location_x': 179, 'dropoff_location_y': 99, 'payment': 304},
#        {'order_id': 16975, 'pickup_point_id': 46975, 'pickup_from': 330, 'pickup_to': 960, 'pickup_location_x': 201, 'pickup_location_y': 150, 'dropoff_point_id': 66975, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 2, 'dropoff_location_y': 93, 'payment': 442},
#        {'order_id': 16989, 'pickup_point_id': 46989, 'pickup_from': 360, 'pickup_to': 1050, 'pickup_location_x': 254, 'pickup_location_y': 168, 'dropoff_point_id': 66989, 'dropoff_from': 906, 'dropoff_to': 1080, 'dropoff_location_x': 32, 'dropoff_location_y': 154, 'payment': 509},
#        {'order_id': 16990, 'pickup_point_id': 46990, 'pickup_from': 360, 'pickup_to': 1020, 'pickup_location_x': 354, 'pickup_location_y': 81, 'dropoff_point_id': 66990, 'dropoff_from': 1080, 'dropoff_to': 1140, 'dropoff_location_x': 215, 'dropoff_location_y': 249, 'payment': 459},
#        {'order_id': 10716, 'pickup_point_id': 40716, 'pickup_from': 330, 'pickup_to': 1050, 'pickup_location_x': 370, 'pickup_location_y': 110, 'dropoff_point_id': 60716, 'dropoff_from': 990, 'dropoff_to': 1140, 'dropoff_location_x': 14, 'dropoff_location_y': 94, 'payment': 540},
#        {'order_id': 15976, 'pickup_point_id': 45976, 'pickup_from': 330, 'pickup_to': 1020, 'pickup_location_x': 199, 'pickup_location_y': 101, 'dropoff_point_id': 65976, 'dropoff_from': 757, 'dropoff_to': 1050, 'dropoff_location_x': 159, 'dropoff_location_y': 271, 'payment': 333},
#        {'order_id': 16497, 'pickup_point_id': 46497, 'pickup_from': 390, 'pickup_to': 900, 'pickup_location_x': 82, 'pickup_location_y': 22, 'dropoff_point_id': 66497, 'dropoff_from': 812, 'dropoff_to': 960, 'dropoff_location_x': 183, 'dropoff_location_y': 102, 'payment': 290},
#        {'order_id': 17011, 'pickup_point_id': 47011, 'pickup_from': 360, 'pickup_to': 990, 'pickup_location_x': 266, 'pickup_location_y': 180, 'dropoff_point_id': 67011, 'dropoff_from': 913, 'dropoff_to': 1080, 'dropoff_location_x': 92, 'dropoff_location_y': 224, 'payment': 480},
#        {'order_id': 17014, 'pickup_point_id': 47014, 'pickup_from': 360, 'pickup_to': 990, 'pickup_location_x': 202, 'pickup_location_y': 62, 'dropoff_point_id': 67014, 'dropoff_from': 1020, 'dropoff_to': 1140, 'dropoff_location_x': 368, 'dropoff_location_y': 113, 'payment': 493},
#        {'order_id': 17027, 'pickup_point_id': 47027, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 230, 'pickup_location_y': 132, 'dropoff_point_id': 67027, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 281, 'dropoff_location_y': 266, 'payment': 406},
#        {'order_id': 17040, 'pickup_point_id': 47040, 'pickup_from': 420, 'pickup_to': 990, 'pickup_location_x': 252, 'pickup_location_y': 209, 'dropoff_point_id': 67040, 'dropoff_from': 920, 'dropoff_to': 1050, 'dropoff_location_x': 171, 'dropoff_location_y': 176, 'payment': 291},
#        {'order_id': 15517, 'pickup_point_id': 45517, 'pickup_from': 330, 'pickup_to': 810, 'pickup_location_x': 325, 'pickup_location_y': 52, 'dropoff_point_id': 65517, 'dropoff_from': 714, 'dropoff_to': 870, 'dropoff_location_x': 231, 'dropoff_location_y': 92, 'payment': 430}],
#       dtype=object)

# %%
for i in ords:
    cour_x = couriers[0]['location_x']
    cour_y = couriers[0]['location_y']
    
    dist_to_order = abs(cour_x - i['pickup_location_x']) + abs(cour_y - i['pickup_location_y'])
    dist_to_deliver = abs(i['dropoff_location_x'] - i['pickup_location_x']) + abs(i['dropoff_location_y'] - i['pickup_location_y'])
    
    print(f'start time: {360} need pick: [{i["pickup_from"]}, {i["pickup_to"]}] need deliver: [{i["dropoff_from"]}, {i["dropoff_to"]}]')
    print(f'start time: {360} can pick: {360 + dist_to_order} can deliver: {360 + dist_to_order + 10 + dist_to_deliver}')
# Out:
# start time: 360 need pick: [390, 1110] need deliver: [1140, 1200]
# start time: 360 can pick: 518 can deliver: 806
# start time: 360 need pick: [300, 900] need deliver: [819, 960]
# start time: 360 can pick: 618 can deliver: 804
# start time: 360 need pick: [300, 900] need deliver: [763, 930]
# start time: 360 can pick: 487 can deliver: 721
# start time: 360 need pick: [360, 870] need deliver: [820, 900]
# start time: 360 can pick: 591 can deliver: 715
# start time: 360 need pick: [300, 840] need deliver: [764, 900]
# start time: 360 can pick: 556 can deliver: 719
# start time: 360 need pick: [360, 900] need deliver: [930, 960]
# start time: 360 can pick: 679 can deliver: 794
# start time: 360 need pick: [390, 810] need deliver: [765, 810]
# start time: 360 can pick: 608 can deliver: 627
# start time: 360 need pick: [330, 870] need deliver: [900, 960]
# start time: 360 can pick: 628 can deliver: 843
# start time: 360 need pick: [330, 1110] need deliver: [1110, 1140]
# start time: 360 can pick: 600 can deliver: 775
# start time: 360 need pick: [390, 1020] need deliver: [1050, 1110]
# start time: 360 can pick: 636 can deliver: 864
# start time: 360 need pick: [390, 1020] need deliver: [934, 1110]
# start time: 360 can pick: 589 can deliver: 853
# start time: 360 need pick: [420, 900] need deliver: [825, 930]
# start time: 360 can pick: 649 can deliver: 761
# start time: 360 need pick: [420, 1080] need deliver: [826, 930]
# start time: 360 can pick: 620 can deliver: 714
# start time: 360 need pick: [360, 1140] need deliver: [1170, 1200]
# start time: 360 can pick: 582 can deliver: 755
# start time: 360 need pick: [420, 1020] need deliver: [943, 1080]
# start time: 360 can pick: 636 can deliver: 852
# start time: 360 need pick: [360, 870] need deliver: [930, 990]
# start time: 360 can pick: 575 can deliver: 825
# start time: 360 need pick: [454, 900] need deliver: [454, 930]
# start time: 360 can pick: 566 can deliver: 670
# start time: 360 need pick: [390, 1050] need deliver: [949, 1140]
# start time: 360 can pick: 518 can deliver: 856
# start time: 360 need pick: [390, 1110] need deliver: [953, 1140]
# start time: 360 can pick: 586 can deliver: 896
# start time: 360 need pick: [300, 1200] need deliver: [953, 1230]
# start time: 360 can pick: 607 can deliver: 753
# start time: 360 need pick: [330, 960] need deliver: [990, 1020]
# start time: 360 can pick: 639 can deliver: 846
# start time: 360 need pick: [360, 1200] need deliver: [990, 1140]
# start time: 360 can pick: 716 can deliver: 841
# start time: 360 need pick: [330, 930] need deliver: [723, 960]
# start time: 360 can pick: 541 can deliver: 705
# start time: 360 need pick: [300, 900] need deliver: [835, 990]
# start time: 360 can pick: 447 can deliver: 705
# start time: 360 need pick: [330, 1230] need deliver: [990, 1230]
# start time: 360 can pick: 626 can deliver: 876
# start time: 360 need pick: [330, 900] need deliver: [900, 1020]
# start time: 360 can pick: 600 can deliver: 898
# start time: 360 need pick: [330, 1230] need deliver: [977, 1230]
# start time: 360 can pick: 620 can deliver: 1055
# start time: 360 need pick: [330, 1080] need deliver: [690, 1230]
# start time: 360 can pick: 571 can deliver: 785
# start time: 360 need pick: [420, 900] need deliver: [900, 960]
# start time: 360 can pick: 591 can deliver: 729
# start time: 360 need pick: [470, 1020] need deliver: [840, 1020]
# start time: 360 can pick: 592 can deliver: 626
# start time: 360 need pick: [420, 960] need deliver: [838, 990]
# start time: 360 can pick: 531 can deliver: 637
# start time: 360 need pick: [390, 1020] need deliver: [982, 1080]
# start time: 360 can pick: 567 can deliver: 681
# start time: 360 need pick: [360, 900] need deliver: [842, 960]
# start time: 360 can pick: 691 can deliver: 816
# start time: 360 need pick: [420, 870] need deliver: [727, 1020]
# start time: 360 can pick: 604 can deliver: 801
# start time: 360 need pick: [330, 1140] need deliver: [1025, 1170]
# start time: 360 can pick: 553 can deliver: 744
# start time: 360 need pick: [420, 1200] need deliver: [1026, 1230]
# start time: 360 can pick: 707 can deliver: 885
# start time: 360 need pick: [390, 1200] need deliver: [1030, 1230]
# start time: 360 can pick: 610 can deliver: 798
# start time: 360 need pick: [300, 1110] need deliver: [1140, 1200]
# start time: 360 can pick: 467 can deliver: 620
# start time: 360 need pick: [300, 1110] need deliver: [1140, 1170]
# start time: 360 can pick: 635 can deliver: 816
# start time: 360 need pick: [390, 1140] need deliver: [1140, 1230]
# start time: 360 can pick: 434 can deliver: 777
# start time: 360 need pick: [420, 1200] need deliver: [1080, 1230]
# start time: 360 can pick: 510 can deliver: 752
# start time: 360 need pick: [390, 930] need deliver: [853, 960]
# start time: 360 can pick: 641 can deliver: 726
# start time: 360 need pick: [390, 990] need deliver: [733, 1050]
# start time: 360 can pick: 565 can deliver: 805
# start time: 360 need pick: [360, 1140] need deliver: [1058, 1170]
# start time: 360 can pick: 484 can deliver: 713
# start time: 360 need pick: [390, 1170] need deliver: [1170, 1200]
# start time: 360 can pick: 724 can deliver: 1082
# start time: 360 need pick: [420, 1140] need deliver: [1074, 1200]
# start time: 360 can pick: 453 can deliver: 700
# start time: 360 need pick: [330, 900] need deliver: [786, 960]
# start time: 360 can pick: 573 can deliver: 736
# start time: 360 need pick: [401, 1110] need deliver: [480, 1140]
# start time: 360 can pick: 614 can deliver: 835
# start time: 360 need pick: [300, 990] need deliver: [900, 1020]
# start time: 360 can pick: 600 can deliver: 761
# start time: 360 need pick: [300, 1170] need deliver: [1103, 1200]
# start time: 360 can pick: 466 can deliver: 520
# start time: 360 need pick: [360, 1170] need deliver: [1105, 1200]
# start time: 360 can pick: 422 can deliver: 476
# start time: 360 need pick: [330, 1170] need deliver: [1200, 1230]
# start time: 360 can pick: 602 can deliver: 784
# start time: 360 need pick: [330, 959] need deliver: [959, 1049]
# start time: 360 can pick: 749 can deliver: 980
# start time: 360 need pick: [411, 840] need deliver: [411, 870]
# start time: 360 can pick: 598 can deliver: 683
# start time: 360 need pick: [420, 930] need deliver: [866, 960]
# start time: 360 can pick: 580 can deliver: 688
# start time: 360 need pick: [360, 1020] need deliver: [866, 1050]
# start time: 360 can pick: 521 can deliver: 668
# start time: 360 need pick: [360, 870] need deliver: [870, 930]
# start time: 360 can pick: 501 can deliver: 662
# start time: 360 need pick: [360, 930] need deliver: [871, 990]
# start time: 360 can pick: 628 can deliver: 750
# start time: 360 need pick: [330, 840] need deliver: [870, 1020]
# start time: 360 can pick: 417 can deliver: 620
# start time: 360 need pick: [300, 780] need deliver: [742, 840]
# start time: 360 can pick: 663 can deliver: 763
# start time: 360 need pick: [420, 1050] need deliver: [1080, 1140]
# start time: 360 can pick: 609 can deliver: 765
# start time: 360 need pick: [360, 960] need deliver: [840, 1050]
# start time: 360 can pick: 440 can deliver: 589
# start time: 360 need pick: [360, 870] need deliver: [840, 974]
# start time: 360 can pick: 583 can deliver: 765
# start time: 360 need pick: [330, 960] need deliver: [1020, 1050]
# start time: 360 can pick: 518 can deliver: 796
# start time: 360 need pick: [420, 1170] need deliver: [1110, 1200]
# start time: 360 can pick: 449 can deliver: 597
# start time: 360 need pick: [360, 870] need deliver: [900, 930]
# start time: 360 can pick: 622 can deliver: 727
# start time: 360 need pick: [300, 930] need deliver: [930, 990]
# start time: 360 can pick: 608 can deliver: 782
# start time: 360 need pick: [300, 930] need deliver: [878, 960]
# start time: 360 can pick: 617 can deliver: 711
# start time: 360 need pick: [300, 1020] need deliver: [720, 1050]
# start time: 360 can pick: 653 can deliver: 839
# start time: 360 need pick: [330, 990] need deliver: [960, 1020]
# start time: 360 can pick: 583 can deliver: 677
# start time: 360 need pick: [330, 1050] need deliver: [990, 1080]
# start time: 360 can pick: 598 can deliver: 746
# start time: 360 need pick: [360, 930] need deliver: [798, 960]
# start time: 360 can pick: 576 can deliver: 801
# start time: 360 need pick: [360, 870] need deliver: [798, 900]
# start time: 360 can pick: 587 can deliver: 751
# start time: 360 need pick: [360, 960] need deliver: [930, 1067]
# start time: 360 can pick: 574 can deliver: 781
# start time: 360 need pick: [360, 930] need deliver: [1050, 1080]
# start time: 360 can pick: 752 can deliver: 987
# start time: 360 need pick: [390, 870] need deliver: [870, 960]
# start time: 360 can pick: 406 can deliver: 597
# start time: 360 need pick: [300, 870] need deliver: [664, 900]
# start time: 360 can pick: 554 can deliver: 651
# start time: 360 need pick: [360, 1110] need deliver: [1140, 1200]
# start time: 360 can pick: 483 can deliver: 662
# start time: 360 need pick: [330, 870] need deliver: [870, 930]
# start time: 360 can pick: 558 can deliver: 750
# start time: 360 need pick: [300, 960] need deliver: [930, 1020]
# start time: 360 can pick: 748 can deliver: 938
# start time: 360 need pick: [300, 990] need deliver: [890, 1020]
# start time: 360 can pick: 562 can deliver: 713
# start time: 360 need pick: [300, 990] need deliver: [803, 1020]
# start time: 360 can pick: 535 can deliver: 776
# start time: 360 need pick: [390, 1050] need deliver: [1050, 1200]
# start time: 360 can pick: 527 can deliver: 815
# start time: 360 need pick: [420, 1020] need deliver: [892, 1050]
# start time: 360 can pick: 610 can deliver: 756
# start time: 360 need pick: [360, 990] need deliver: [960, 1146]
# start time: 360 can pick: 494 can deliver: 727
# start time: 360 need pick: [360, 900] need deliver: [780, 960]
# start time: 360 can pick: 633 can deliver: 782
# start time: 360 need pick: [420, 990] need deliver: [1020, 1050]
# start time: 360 can pick: 580 can deliver: 713
# start time: 360 need pick: [420, 1020] need deliver: [840, 1020]
# start time: 360 can pick: 542 can deliver: 582
# start time: 360 need pick: [330, 840] need deliver: [753, 960]
# start time: 360 can pick: 619 can deliver: 841
# start time: 360 need pick: [300, 870] need deliver: [810, 1093]
# start time: 360 can pick: 421 can deliver: 715
# start time: 360 need pick: [300, 780] need deliver: [706, 810]
# start time: 360 can pick: 473 can deliver: 582
# start time: 360 need pick: [300, 870] need deliver: [870, 930]
# start time: 360 can pick: 503 can deliver: 647
# start time: 360 need pick: [390, 1200] need deliver: [707, 1230]
# start time: 360 can pick: 585 can deliver: 777
# start time: 360 need pick: [360, 900] need deliver: [900, 960]
# start time: 360 can pick: 429 can deliver: 532
# start time: 360 need pick: [330, 960] need deliver: [1020, 1050]
# start time: 360 can pick: 595 can deliver: 861
# start time: 360 need pick: [360, 1050] need deliver: [906, 1080]
# start time: 360 can pick: 666 can deliver: 912
# start time: 360 need pick: [360, 1020] need deliver: [1080, 1140]
# start time: 360 can pick: 679 can deliver: 996
# start time: 360 need pick: [330, 1050] need deliver: [990, 1140]
# start time: 360 can pick: 724 can deliver: 1106
# start time: 360 need pick: [330, 1020] need deliver: [757, 1050]
# start time: 360 can pick: 544 can deliver: 764
# start time: 360 need pick: [390, 900] need deliver: [812, 960]
# start time: 360 can pick: 406 can deliver: 597
# start time: 360 need pick: [360, 990] need deliver: [913, 1080]
# start time: 360 can pick: 690 can deliver: 918
# start time: 360 need pick: [360, 990] need deliver: [1020, 1140]
# start time: 360 can pick: 508 can deliver: 735
# start time: 360 need pick: [390, 1020] need deliver: [1020, 1050]
# start time: 360 can pick: 606 can deliver: 801
# start time: 360 need pick: [420, 990] need deliver: [920, 1050]
# start time: 360 can pick: 705 can deliver: 829
# start time: 360 need pick: [330, 810] need deliver: [714, 870]
# start time: 360 can pick: 621 can deliver: 765

# %%
ff = list(set(results[0][2]))

# %%
np.array(list(orders.values()))[ff]
# Out:
# array([{'order_id': 16543, 'pickup_point_id': 46543, 'pickup_from': 330, 'pickup_to': 870, 'pickup_location_x': 263, 'pickup_location_y': 146, 'dropoff_point_id': 66543, 'dropoff_from': 818, 'dropoff_to': 930, 'dropoff_location_x': 115, 'dropoff_location_y': 226, 'payment': 511},
#        {'order_id': 16035, 'pickup_point_id': 46035, 'pickup_from': 390, 'pickup_to': 1110, 'pickup_location_x': 74, 'pickup_location_y': 126, 'dropoff_point_id': 66035, 'dropoff_from': 1140, 'dropoff_to': 1200, 'dropoff_location_x': 289, 'dropoff_location_y': 63, 'payment': 439},
#        {'order_id': 15525, 'pickup_point_id': 45525, 'pickup_from': 360, 'pickup_to': 750, 'pickup_location_x': 288, 'pickup_location_y': 155, 'dropoff_point_id': 65525, 'dropoff_from': 715, 'dropoff_to': 840, 'dropoff_location_x': 11, 'dropoff_location_y': 105, 'payment': 490},
#        {'order_id': 16037, 'pickup_point_id': 46037, 'pickup_from': 390, 'pickup_to': 810, 'pickup_location_x': 272, 'pickup_location_y': 104, 'dropoff_point_id': 66037, 'dropoff_from': 763, 'dropoff_to': 840, 'dropoff_location_x': 198, 'dropoff_location_y': 116, 'payment': 292},
#        {'order_id': 16551, 'pickup_point_id': 46551, 'pickup_from': 300, 'pickup_to': 900, 'pickup_location_x': 175, 'pickup_location_y': 199, 'dropoff_point_id': 66551, 'dropoff_from': 819, 'dropoff_to': 960, 'dropoff_location_x': 229, 'dropoff_location_y': 77, 'payment': 398},
#        {'order_id': 16042, 'pickup_point_id': 46042, 'pickup_from': 300, 'pickup_to': 900, 'pickup_location_x': 148, 'pickup_location_y': 95, 'dropoff_point_id': 66042, 'dropoff_from': 763, 'dropoff_to': 930, 'dropoff_location_x': 212, 'dropoff_location_y': 255, 'payment': 314},
#        {'order_id': 12620, 'pickup_point_id': 42620, 'pickup_from': 509, 'pickup_to': 870, 'pickup_location_x': 266, 'pickup_location_y': 122, 'dropoff_point_id': 62620, 'dropoff_from': 509, 'dropoff_to': 900, 'dropoff_location_x': 273, 'dropoff_location_y': 228, 'payment': 390},
#        {'order_id': 16557, 'pickup_point_id': 46557, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 232, 'pickup_location_y': 115, 'dropoff_point_id': 66557, 'dropoff_from': 820, 'dropoff_to': 900, 'dropoff_location_x': 297, 'dropoff_location_y': 66, 'payment': 366},
#        {'order_id': 16045, 'pickup_point_id': 46045, 'pickup_from': 300, 'pickup_to': 840, 'pickup_location_x': 89, 'pickup_location_y': 179, 'dropoff_point_id': 66045, 'dropoff_from': 764, 'dropoff_to': 900, 'dropoff_location_x': 242, 'dropoff_location_y': 179, 'payment': 413},
#        {'order_id': 15534, 'pickup_point_id': 45534, 'pickup_from': 420, 'pickup_to': 780, 'pickup_location_x': 157, 'pickup_location_y': 113, 'dropoff_point_id': 65534, 'dropoff_from': 716, 'dropoff_to': 810, 'dropoff_location_x': 162, 'dropoff_location_y': 149, 'payment': 280},
#        {'order_id': 15536, 'pickup_point_id': 45536, 'pickup_from': 330, 'pickup_to': 780, 'pickup_location_x': 160, 'pickup_location_y': 129, 'dropoff_point_id': 65536, 'dropoff_from': 716, 'dropoff_to': 840, 'dropoff_location_x': 349, 'dropoff_location_y': 171, 'payment': 542},
#        {'order_id': 12625, 'pickup_point_id': 42625, 'pickup_from': 509, 'pickup_to': 780, 'pickup_location_x': 241, 'pickup_location_y': 75, 'dropoff_point_id': 62625, 'dropoff_from': 509, 'dropoff_to': 780, 'dropoff_location_x': 210, 'dropoff_location_y': 161, 'payment': 331},
#        {'order_id': 15538, 'pickup_point_id': 45538, 'pickup_from': 390, 'pickup_to': 810, 'pickup_location_x': 242, 'pickup_location_y': 101, 'dropoff_point_id': 65538, 'dropoff_from': 716, 'dropoff_to': 870, 'dropoff_location_x': 144, 'dropoff_location_y': 167, 'payment': 437},
#        {'order_id': 16568, 'pickup_point_id': 46568, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 285, 'pickup_location_y': 150, 'dropoff_point_id': 66568, 'dropoff_from': 930, 'dropoff_to': 960, 'dropoff_location_x': 182, 'dropoff_location_y': 152, 'payment': 431},
#        {'order_id': 16056, 'pickup_point_id': 46056, 'pickup_from': 390, 'pickup_to': 810, 'pickup_location_x': 244, 'pickup_location_y': 120, 'dropoff_point_id': 66056, 'dropoff_from': 765, 'dropoff_to': 810, 'dropoff_location_x': 238, 'dropoff_location_y': 123, 'payment': 177},
#        {'order_id': 15545, 'pickup_point_id': 45545, 'pickup_from': 420, 'pickup_to': 780, 'pickup_location_x': 222, 'pickup_location_y': 102, 'dropoff_point_id': 65545, 'dropoff_from': 780, 'dropoff_to': 900, 'dropoff_location_x': 132, 'dropoff_location_y': 223, 'payment': 351},
#        {'order_id': 16574, 'pickup_point_id': 46574, 'pickup_from': 330, 'pickup_to': 870, 'pickup_location_x': 274, 'pickup_location_y': 110, 'dropoff_point_id': 66574, 'dropoff_from': 900, 'dropoff_to': 960, 'dropoff_location_x': 95, 'dropoff_location_y': 84, 'payment': 402},
#        {'order_id': 16576, 'pickup_point_id': 46576, 'pickup_from': 330, 'pickup_to': 1110, 'pickup_location_x': 176, 'pickup_location_y': 180, 'dropoff_point_id': 66576, 'dropoff_from': 1110, 'dropoff_to': 1140, 'dropoff_location_x': 133, 'dropoff_location_y': 58, 'payment': 405},
#        {'order_id': 15558, 'pickup_point_id': 45558, 'pickup_from': 390, 'pickup_to': 780, 'pickup_location_x': 192, 'pickup_location_y': 116, 'dropoff_point_id': 65558, 'dropoff_from': 718, 'dropoff_to': 840, 'dropoff_location_x': 227, 'dropoff_location_y': 168, 'payment': 305},
#        {'order_id': 17096, 'pickup_point_id': 47096, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 278, 'pickup_location_y': 114, 'dropoff_point_id': 67096, 'dropoff_from': 1050, 'dropoff_to': 1110, 'dropoff_location_x': 117, 'dropoff_location_y': 57, 'payment': 475},
#        {'order_id': 17097, 'pickup_point_id': 47097, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 260, 'pickup_location_y': 85, 'dropoff_point_id': 67097, 'dropoff_from': 934, 'dropoff_to': 1110, 'dropoff_location_x': 213, 'dropoff_location_y': 292, 'payment': 488},
#        {'order_id': 16595, 'pickup_point_id': 46595, 'pickup_from': 420, 'pickup_to': 900, 'pickup_location_x': 264, 'pickup_location_y': 141, 'dropoff_point_id': 66595, 'dropoff_from': 825, 'dropoff_to': 930, 'dropoff_location_x': 258, 'dropoff_location_y': 237, 'payment': 351},
#        {'order_id': 16599, 'pickup_point_id': 46599, 'pickup_from': 420, 'pickup_to': 1080, 'pickup_location_x': 197, 'pickup_location_y': 179, 'dropoff_point_id': 66599, 'dropoff_from': 826, 'dropoff_to': 930, 'dropoff_location_x': 225, 'dropoff_location_y': 123, 'payment': 264},
#        {'order_id': 10937, 'pickup_point_id': 40937, 'pickup_from': 360, 'pickup_to': 1140, 'pickup_location_x': 137, 'pickup_location_y': 201, 'dropoff_point_id': 60937, 'dropoff_from': 1170, 'dropoff_to': 1200, 'dropoff_location_x': 28, 'dropoff_location_y': 147, 'payment': 439},
#        {'order_id': 13555, 'pickup_point_id': 43555, 'pickup_from': 569, 'pickup_to': 720, 'pickup_location_x': 204, 'pickup_location_y': 206, 'dropoff_point_id': 63555, 'dropoff_from': 569, 'dropoff_to': 870, 'dropoff_location_x': 272, 'dropoff_location_y': 70, 'payment': 466},
#        {'order_id': 17126, 'pickup_point_id': 47126, 'pickup_from': 420, 'pickup_to': 1020, 'pickup_location_x': 278, 'pickup_location_y': 114, 'dropoff_point_id': 67126, 'dropoff_from': 943, 'dropoff_to': 1080, 'dropoff_location_x': 118, 'dropoff_location_y': 68, 'payment': 475},
#        {'order_id': 16614, 'pickup_point_id': 46614, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 223, 'pickup_location_y': 108, 'dropoff_point_id': 66614, 'dropoff_from': 930, 'dropoff_to': 990, 'dropoff_location_x': 24, 'dropoff_location_y': 67, 'payment': 500},
#        {'order_id': 16104, 'pickup_point_id': 46104, 'pickup_from': 420, 'pickup_to': 810, 'pickup_location_x': 162, 'pickup_location_y': 149, 'dropoff_point_id': 66104, 'dropoff_from': 769, 'dropoff_to': 900, 'dropoff_location_x': 332, 'dropoff_location_y': 125, 'payment': 808},
#        {'order_id': 11863, 'pickup_point_id': 41863, 'pickup_from': 454, 'pickup_to': 900, 'pickup_location_x': 174, 'pickup_location_y': 148, 'dropoff_point_id': 61863, 'dropoff_from': 454, 'dropoff_to': 930, 'dropoff_location_x': 176, 'dropoff_location_y': 240, 'payment': 233},
#        {'order_id': 17140, 'pickup_point_id': 47140, 'pickup_from': 390, 'pickup_to': 1050, 'pickup_location_x': 25, 'pickup_location_y': 77, 'dropoff_point_id': 67140, 'dropoff_from': 949, 'dropoff_to': 1140, 'dropoff_location_x': 290, 'dropoff_location_y': 14, 'payment': 622},
#        {'order_id': 16632, 'pickup_point_id': 46632, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 285, 'pickup_location_y': 242, 'dropoff_point_id': 66632, 'dropoff_from': 831, 'dropoff_to': 960, 'dropoff_location_x': 239, 'dropoff_location_y': 61, 'payment': 390},
#        {'order_id': 17145, 'pickup_point_id': 47145, 'pickup_from': 390, 'pickup_to': 1110, 'pickup_location_x': 42, 'pickup_location_y': 162, 'dropoff_point_id': 67145, 'dropoff_from': 953, 'dropoff_to': 1140, 'dropoff_location_x': 185, 'dropoff_location_y': 5, 'payment': 544},
#        {'order_id': 17147, 'pickup_point_id': 47147, 'pickup_from': 300, 'pickup_to': 1200, 'pickup_location_x': 52, 'pickup_location_y': 193, 'dropoff_point_id': 67147, 'dropoff_from': 953, 'dropoff_to': 1230, 'dropoff_location_x': 158, 'dropoff_location_y': 163, 'payment': 235},
#        {'order_id': 16640, 'pickup_point_id': 46640, 'pickup_from': 330, 'pickup_to': 960, 'pickup_location_x': 244, 'pickup_location_y': 151, 'dropoff_point_id': 66640, 'dropoff_from': 990, 'dropoff_to': 1020, 'dropoff_location_x': 157, 'dropoff_location_y': 261, 'payment': 440},
#        {'order_id': 15620, 'pickup_point_id': 45620, 'pickup_from': 390, 'pickup_to': 840, 'pickup_location_x': 322, 'pickup_location_y': 121, 'dropoff_point_id': 65620, 'dropoff_from': 723, 'dropoff_to': 870, 'dropoff_location_x': 203, 'dropoff_location_y': 45, 'payment': 392},
#        {'order_id': 14438, 'pickup_point_id': 44438, 'pickup_from': 390, 'pickup_to': 720, 'pickup_location_x': 239, 'pickup_location_y': 163, 'dropoff_point_id': 64438, 'dropoff_from': 690, 'dropoff_to': 839, 'dropoff_location_x': 195, 'dropoff_location_y': 2, 'payment': 367},
#        {'order_id': 13604, 'pickup_point_id': 43604, 'pickup_from': 360, 'pickup_to': 1200, 'pickup_location_x': 218, 'pickup_location_y': 254, 'dropoff_point_id': 63604, 'dropoff_from': 990, 'dropoff_to': 1140, 'dropoff_location_x': 132, 'dropoff_location_y': 225, 'payment': 936},
#        {'order_id': 15623, 'pickup_point_id': 45623, 'pickup_from': 330, 'pickup_to': 930, 'pickup_location_x': 203, 'pickup_location_y': 94, 'dropoff_point_id': 65623, 'dropoff_from': 723, 'dropoff_to': 960, 'dropoff_location_x': 345, 'dropoff_location_y': 82, 'payment': 370},
#        {'order_id': 11021, 'pickup_point_id': 41021, 'pickup_from': 361, 'pickup_to': 870, 'pickup_location_x': 218, 'pickup_location_y': 162, 'dropoff_point_id': 61021, 'dropoff_from': 361, 'dropoff_to': 900, 'dropoff_location_x': 284, 'dropoff_location_y': 65, 'payment': 358},
#        {'order_id': 15629, 'pickup_point_id': 45629, 'pickup_from': 360, 'pickup_to': 810, 'pickup_location_x': 314, 'pickup_location_y': 73, 'dropoff_point_id': 65629, 'dropoff_from': 724, 'dropoff_to': 840, 'dropoff_location_x': 261, 'dropoff_location_y': 143, 'payment': 347},
#        {'order_id': 16654, 'pickup_point_id': 46654, 'pickup_from': 300, 'pickup_to': 900, 'pickup_location_x': 185, 'pickup_location_y': 18, 'dropoff_point_id': 66654, 'dropoff_from': 835, 'dropoff_to': 990, 'dropoff_location_x': 38, 'dropoff_location_y': 119, 'payment': 473},
#        {'order_id': 17170, 'pickup_point_id': 47170, 'pickup_from': 330, 'pickup_to': 1230, 'pickup_location_x': 263, 'pickup_location_y': 119, 'dropoff_point_id': 67170, 'dropoff_from': 990, 'dropoff_to': 1230, 'dropoff_location_x': 130, 'dropoff_location_y': 226, 'payment': 346},
#        {'order_id': 11918, 'pickup_point_id': 41918, 'pickup_from': 330, 'pickup_to': 900, 'pickup_location_x': 138, 'pickup_location_y': 218, 'dropoff_point_id': 61918, 'dropoff_from': 900, 'dropoff_to': 1020, 'dropoff_location_x': 260, 'dropoff_location_y': 52, 'payment': 465},
#        {'order_id': 17176, 'pickup_point_id': 47176, 'pickup_from': 330, 'pickup_to': 1230, 'pickup_location_x': 44, 'pickup_location_y': 198, 'dropoff_point_id': 67176, 'dropoff_from': 977, 'dropoff_to': 1230, 'dropoff_location_x': 322, 'dropoff_location_y': 51, 'payment': 431},
#        {'order_id': 16030, 'pickup_point_id': 46030, 'pickup_from': 360, 'pickup_to': 840, 'pickup_location_x': 201, 'pickup_location_y': 132, 'dropoff_point_id': 66030, 'dropoff_from': 762, 'dropoff_to': 900, 'dropoff_location_x': 283, 'dropoff_location_y': 265, 'payment': 436},
#        {'order_id': 14475, 'pickup_point_id': 44475, 'pickup_from': 330, 'pickup_to': 1080, 'pickup_location_x': 257, 'pickup_location_y': 70, 'dropoff_point_id': 64475, 'dropoff_from': 690, 'dropoff_to': 1230, 'dropoff_location_x': 78, 'dropoff_location_y': 45, 'payment': 579},
#        {'order_id': 11936, 'pickup_point_id': 41936, 'pickup_from': 470, 'pickup_to': 840, 'pickup_location_x': 288, 'pickup_location_y': 103, 'dropoff_point_id': 61936, 'dropoff_from': 660, 'dropoff_to': 840, 'dropoff_location_x': 318, 'dropoff_location_y': 106, 'payment': 290},
#        {'order_id': 16667, 'pickup_point_id': 46667, 'pickup_from': 420, 'pickup_to': 900, 'pickup_location_x': 232, 'pickup_location_y': 115, 'dropoff_point_id': 66667, 'dropoff_from': 900, 'dropoff_to': 960, 'dropoff_location_x': 130, 'dropoff_location_y': 141, 'payment': 343},
#        {'order_id': 11935, 'pickup_point_id': 41935, 'pickup_from': 470, 'pickup_to': 1020, 'pickup_location_x': 100, 'pickup_location_y': 226, 'dropoff_point_id': 61935, 'dropoff_from': 840, 'dropoff_to': 1020, 'dropoff_location_x': 116, 'dropoff_location_y': 218, 'payment': 290},
#        {'order_id': 16673, 'pickup_point_id': 46673, 'pickup_from': 420, 'pickup_to': 960, 'pickup_location_x': 195, 'pickup_location_y': 92, 'dropoff_point_id': 66673, 'dropoff_from': 838, 'dropoff_to': 990, 'dropoff_location_x': 263, 'dropoff_location_y': 64, 'payment': 378},
#        {'order_id': 17186, 'pickup_point_id': 47186, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 250, 'pickup_location_y': 73, 'dropoff_point_id': 67186, 'dropoff_from': 982, 'dropoff_to': 1080, 'dropoff_location_x': 207, 'dropoff_location_y': 134, 'payment': 290},
#        {'order_id': 11971, 'pickup_point_id': 41971, 'pickup_from': 510, 'pickup_to': 750, 'pickup_location_x': 211, 'pickup_location_y': 80, 'dropoff_point_id': 61971, 'dropoff_from': 463, 'dropoff_to': 750, 'dropoff_location_x': 173, 'dropoff_location_y': 71, 'payment': 274},
#        {'order_id': 16692, 'pickup_point_id': 46692, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 325, 'pickup_location_y': 122, 'dropoff_point_id': 66692, 'dropoff_from': 842, 'dropoff_to': 960, 'dropoff_location_x': 247, 'dropoff_location_y': 85, 'payment': 417},
#        {'order_id': 15671, 'pickup_point_id': 45671, 'pickup_from': 420, 'pickup_to': 780, 'pickup_location_x': 303, 'pickup_location_y': 26, 'dropoff_point_id': 65671, 'dropoff_from': 727, 'dropoff_to': 840, 'dropoff_location_x': 207, 'dropoff_location_y': 171, 'payment': 411},
#        {'order_id': 15674, 'pickup_point_id': 45674, 'pickup_from': 420, 'pickup_to': 870, 'pickup_location_x': 162, 'pickup_location_y': 198, 'dropoff_point_id': 65674, 'dropoff_from': 727, 'dropoff_to': 1020, 'dropoff_location_x': 205, 'dropoff_location_y': 54, 'payment': 487},
#        {'order_id': 15677, 'pickup_point_id': 45677, 'pickup_from': 390, 'pickup_to': 810, 'pickup_location_x': 193, 'pickup_location_y': 257, 'dropoff_point_id': 65677, 'dropoff_from': 810, 'dropoff_to': 900, 'dropoff_location_x': 134, 'dropoff_location_y': 79, 'payment': 508},
#        {'order_id': 16206, 'pickup_point_id': 46206, 'pickup_from': 330, 'pickup_to': 870, 'pickup_location_x': 226, 'pickup_location_y': 129, 'dropoff_point_id': 66206, 'dropoff_from': 780, 'dropoff_to': 900, 'dropoff_location_x': 372, 'dropoff_location_y': 77, 'payment': 372},
#        {'order_id': 16210, 'pickup_point_id': 46210, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 183, 'pickup_location_y': 182, 'dropoff_point_id': 66210, 'dropoff_from': 780, 'dropoff_to': 900, 'dropoff_location_x': 131, 'dropoff_location_y': 37, 'payment': 463},
#        {'order_id': 17236, 'pickup_point_id': 47236, 'pickup_from': 330, 'pickup_to': 1140, 'pickup_location_x': 178, 'pickup_location_y': 131, 'dropoff_point_id': 67236, 'dropoff_from': 1025, 'dropoff_to': 1170, 'dropoff_location_x': 81, 'dropoff_location_y': 47, 'payment': 466},
#        {'order_id': 17237, 'pickup_point_id': 47237, 'pickup_from': 420, 'pickup_to': 1200, 'pickup_location_x': 371, 'pickup_location_y': 92, 'dropoff_point_id': 67237, 'dropoff_from': 1026, 'dropoff_to': 1230, 'dropoff_location_x': 286, 'dropoff_location_y': 9, 'payment': 472},
#        {'order_id': 16215, 'pickup_point_id': 46215, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 54, 'pickup_location_y': 203, 'dropoff_point_id': 66215, 'dropoff_from': 780, 'dropoff_to': 900, 'dropoff_location_x': 230, 'dropoff_location_y': 152, 'payment': 492},
#        {'order_id': 17241, 'pickup_point_id': 47241, 'pickup_from': 390, 'pickup_to': 1200, 'pickup_location_x': 158, 'pickup_location_y': 208, 'dropoff_point_id': 67241, 'dropoff_from': 1030, 'dropoff_to': 1230, 'dropoff_location_x': 19, 'dropoff_location_y': 169, 'payment': 431},
#        {'order_id': 17244, 'pickup_point_id': 47244, 'pickup_from': 300, 'pickup_to': 1110, 'pickup_location_x': 100, 'pickup_location_y': 101, 'dropoff_point_id': 67244, 'dropoff_from': 1140, 'dropoff_to': 1200, 'dropoff_location_x': 242, 'dropoff_location_y': 102, 'payment': 391},
#        {'order_id': 17249, 'pickup_point_id': 47249, 'pickup_from': 300, 'pickup_to': 1110, 'pickup_location_x': 288, 'pickup_location_y': 103, 'dropoff_point_id': 67249, 'dropoff_from': 1140, 'dropoff_to': 1170, 'dropoff_location_x': 130, 'dropoff_location_y': 90, 'payment': 389},
#        {'order_id': 17254, 'pickup_point_id': 47254, 'pickup_from': 390, 'pickup_to': 1140, 'pickup_location_x': 130, 'pickup_location_y': 60, 'dropoff_point_id': 67254, 'dropoff_from': 1140, 'dropoff_to': 1230, 'dropoff_location_x': 269, 'dropoff_location_y': 254, 'payment': 441},
#        {'order_id': 16231, 'pickup_point_id': 46231, 'pickup_from': 390, 'pickup_to': 870, 'pickup_location_x': 221, 'pickup_location_y': 154, 'dropoff_point_id': 66231, 'dropoff_from': 783, 'dropoff_to': 900, 'dropoff_location_x': 357, 'dropoff_location_y': 99, 'payment': 389},
#        {'order_id': 17261, 'pickup_point_id': 47261, 'pickup_from': 420, 'pickup_to': 1200, 'pickup_location_x': 35, 'pickup_location_y': 79, 'dropoff_point_id': 67261, 'dropoff_from': 1080, 'dropoff_to': 1230, 'dropoff_location_x': 246, 'dropoff_location_y': 100, 'payment': 456},
#        {'order_id': 14611, 'pickup_point_id': 44611, 'pickup_from': 644, 'pickup_to': 720, 'pickup_location_x': 230, 'pickup_location_y': 112, 'dropoff_point_id': 64611, 'dropoff_from': 644, 'dropoff_to': 780, 'dropoff_location_x': 165, 'dropoff_location_y': 105, 'payment': 382},
#        {'order_id': 16755, 'pickup_point_id': 46755, 'pickup_from': 390, 'pickup_to': 930, 'pickup_location_x': 210, 'pickup_location_y': 187, 'dropoff_point_id': 66755, 'dropoff_from': 853, 'dropoff_to': 960, 'dropoff_location_x': 230, 'dropoff_location_y': 132, 'payment': 310},
#        {'order_id': 15732, 'pickup_point_id': 45732, 'pickup_from': 390, 'pickup_to': 990, 'pickup_location_x': 214, 'pickup_location_y': 107, 'dropoff_point_id': 65732, 'dropoff_from': 733, 'dropoff_to': 1050, 'dropoff_location_x': 20, 'dropoff_location_y': 71, 'payment': 522},
#        {'order_id': 12969, 'pickup_point_id': 42969, 'pickup_from': 570, 'pickup_to': 810, 'pickup_location_x': 281, 'pickup_location_y': 140, 'dropoff_point_id': 62969, 'dropoff_from': 570, 'dropoff_to': 810, 'dropoff_location_x': 227, 'dropoff_location_y': 130, 'payment': 220},
#        {'order_id': 17274, 'pickup_point_id': 47274, 'pickup_from': 360, 'pickup_to': 1140, 'pickup_location_x': 110, 'pickup_location_y': 128, 'dropoff_point_id': 67274, 'dropoff_from': 1058, 'dropoff_to': 1170, 'dropoff_location_x': 208, 'dropoff_location_y': 7, 'payment': 426},
#        {'order_id': 17280, 'pickup_point_id': 47280, 'pickup_from': 390, 'pickup_to': 1170, 'pickup_location_x': 219, 'pickup_location_y': 261, 'dropoff_point_id': 67280, 'dropoff_from': 1170, 'dropoff_to': 1200, 'dropoff_location_x': 311, 'dropoff_location_y': 5, 'payment': 510},
#        {'order_id': 17284, 'pickup_point_id': 47284, 'pickup_from': 420, 'pickup_to': 1140, 'pickup_location_x': 104, 'pickup_location_y': 91, 'dropoff_point_id': 67284, 'dropoff_from': 1074, 'dropoff_to': 1200, 'dropoff_location_x': 280, 'dropoff_location_y': 152, 'payment': 419},
#        {'order_id': 16262, 'pickup_point_id': 46262, 'pickup_from': 330, 'pickup_to': 900, 'pickup_location_x': 211, 'pickup_location_y': 118, 'dropoff_point_id': 66262, 'dropoff_from': 786, 'dropoff_to': 960, 'dropoff_location_x': 88, 'dropoff_location_y': 148, 'payment': 457},
#        {'order_id': 15752, 'pickup_point_id': 45752, 'pickup_from': 300, 'pickup_to': 810, 'pickup_location_x': 342, 'pickup_location_y': 134, 'dropoff_point_id': 65752, 'dropoff_from': 735, 'dropoff_to': 870, 'dropoff_location_x': 180, 'dropoff_location_y': 131, 'payment': 439},
#        {'order_id': 11263, 'pickup_point_id': 41263, 'pickup_from': 401, 'pickup_to': 1110, 'pickup_location_x': 18, 'pickup_location_y': 166, 'dropoff_point_id': 61263, 'dropoff_from': 480, 'dropoff_to': 1140, 'dropoff_location_x': 103, 'dropoff_location_y': 40, 'payment': 326},
#        {'order_id': 13820, 'pickup_point_id': 43820, 'pickup_from': 630, 'pickup_to': 870, 'pickup_location_x': 223, 'pickup_location_y': 215, 'dropoff_point_id': 63820, 'dropoff_from': 630, 'dropoff_to': 870, 'dropoff_location_x': 231, 'dropoff_location_y': 54, 'payment': 382},
#        {'order_id': 16266, 'pickup_point_id': 46266, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 138, 'pickup_location_y': 80, 'dropoff_point_id': 66266, 'dropoff_from': 786, 'dropoff_to': 900, 'dropoff_location_x': 332, 'dropoff_location_y': 166, 'payment': 463},
#        {'order_id': 16782, 'pickup_point_id': 46782, 'pickup_from': 300, 'pickup_to': 990, 'pickup_location_x': 198, 'pickup_location_y': 158, 'dropoff_point_id': 66782, 'dropoff_from': 900, 'dropoff_to': 1020, 'dropoff_location_x': 106, 'dropoff_location_y': 99, 'payment': 327},
#        {'order_id': 17296, 'pickup_point_id': 47296, 'pickup_from': 300, 'pickup_to': 1170, 'pickup_location_x': 101, 'pickup_location_y': 101, 'dropoff_point_id': 67296, 'dropoff_from': 1103, 'dropoff_to': 1200, 'dropoff_location_x': 110, 'dropoff_location_y': 66, 'payment': 224},
#        {'order_id': 17297, 'pickup_point_id': 47297, 'pickup_from': 360, 'pickup_to': 1170, 'pickup_location_x': 110, 'pickup_location_y': 66, 'dropoff_point_id': 67297, 'dropoff_from': 1105, 'dropoff_to': 1200, 'dropoff_location_x': 101, 'dropoff_location_y': 101, 'payment': 236},
#        {'order_id': 15251, 'pickup_point_id': 45251, 'pickup_from': 360, 'pickup_to': 780, 'pickup_location_x': 225, 'pickup_location_y': 134, 'dropoff_point_id': 65251, 'dropoff_from': 694, 'dropoff_to': 840, 'dropoff_location_x': 131, 'dropoff_location_y': 184, 'payment': 399},
#        {'order_id': 17303, 'pickup_point_id': 47303, 'pickup_from': 330, 'pickup_to': 1170, 'pickup_location_x': 243, 'pickup_location_y': 115, 'dropoff_point_id': 67303, 'dropoff_from': 1200, 'dropoff_to': 1230, 'dropoff_location_x': 135, 'dropoff_location_y': 51, 'payment': 359},
#        {'order_id': 16286, 'pickup_point_id': 46286, 'pickup_from': 420, 'pickup_to': 900, 'pickup_location_x': 104, 'pickup_location_y': 2, 'dropoff_point_id': 66286, 'dropoff_from': 788, 'dropoff_to': 930, 'dropoff_location_x': 233, 'dropoff_location_y': 136, 'payment': 428},
#        {'order_id': 12169, 'pickup_point_id': 42169, 'pickup_from': 477, 'pickup_to': 690, 'pickup_location_x': 247, 'pickup_location_y': 109, 'dropoff_point_id': 62169, 'dropoff_from': 477, 'dropoff_to': 720, 'dropoff_location_x': 230, 'dropoff_location_y': 17, 'payment': 648},
#        {'order_id': 15783, 'pickup_point_id': 45783, 'pickup_from': 420, 'pickup_to': 810, 'pickup_location_x': 138, 'pickup_location_y': 133, 'dropoff_point_id': 65783, 'dropoff_from': 738, 'dropoff_to': 870, 'dropoff_location_x': 267, 'dropoff_location_y': 144, 'payment': 404},
#        {'order_id': 15277, 'pickup_point_id': 45277, 'pickup_from': 390, 'pickup_to': 780, 'pickup_location_x': 146, 'pickup_location_y': 94, 'dropoff_point_id': 65277, 'dropoff_from': 695, 'dropoff_to': 810, 'dropoff_location_x': 206, 'dropoff_location_y': 117, 'payment': 313},
#        {'order_id': 16815, 'pickup_point_id': 46815, 'pickup_from': 330, 'pickup_to': 959, 'pickup_location_x': 279, 'pickup_location_y': 226, 'dropoff_point_id': 66815, 'dropoff_from': 959, 'dropoff_to': 1049, 'dropoff_location_x': 163, 'dropoff_location_y': 121, 'payment': 500},
#        {'order_id': 11338, 'pickup_point_id': 41338, 'pickup_from': 411, 'pickup_to': 840, 'pickup_location_x': 200, 'pickup_location_y': 154, 'dropoff_point_id': 61338, 'dropoff_from': 411, 'dropoff_to': 870, 'dropoff_location_x': 219, 'dropoff_location_y': 98, 'payment': 277},
#        {'order_id': 12210, 'pickup_point_id': 42210, 'pickup_from': 480, 'pickup_to': 720, 'pickup_location_x': 216, 'pickup_location_y': 156, 'dropoff_point_id': 62210, 'dropoff_from': 480, 'dropoff_to': 780, 'dropoff_location_x': 296, 'dropoff_location_y': 56, 'payment': 344},
#        {'order_id': 16826, 'pickup_point_id': 46826, 'pickup_from': 420, 'pickup_to': 930, 'pickup_location_x': 265, 'pickup_location_y': 71, 'dropoff_point_id': 66826, 'dropoff_from': 866, 'dropoff_to': 960, 'dropoff_location_x': 230, 'dropoff_location_y': 134, 'payment': 285},
#        {'order_id': 15292, 'pickup_point_id': 45292, 'pickup_from': 390, 'pickup_to': 750, 'pickup_location_x': 169, 'pickup_location_y': 154, 'dropoff_point_id': 65292, 'dropoff_from': 696, 'dropoff_to': 840, 'dropoff_location_x': 213, 'dropoff_location_y': 6, 'payment': 411},
#        {'order_id': 16830, 'pickup_point_id': 46830, 'pickup_from': 360, 'pickup_to': 1020, 'pickup_location_x': 139, 'pickup_location_y': 138, 'dropoff_point_id': 66830, 'dropoff_from': 866, 'dropoff_to': 1050, 'dropoff_location_x': 122, 'dropoff_location_y': 18, 'payment': 440},
#        {'order_id': 16318, 'pickup_point_id': 46318, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 240, 'pickup_location_y': 70, 'dropoff_point_id': 66318, 'dropoff_from': 792, 'dropoff_to': 900, 'dropoff_location_x': 181, 'dropoff_location_y': 185, 'payment': 395},
#        {'order_id': 16320, 'pickup_point_id': 46320, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 117, 'pickup_location_y': 140, 'dropoff_point_id': 66320, 'dropoff_from': 870, 'dropoff_to': 930, 'dropoff_location_x': 247, 'dropoff_location_y': 119, 'payment': 311},
#        {'order_id': 14773, 'pickup_point_id': 44773, 'pickup_from': 657, 'pickup_to': 870, 'pickup_location_x': 185, 'pickup_location_y': 139, 'dropoff_point_id': 64773, 'dropoff_from': 657, 'dropoff_to': 930, 'dropoff_location_x': 216, 'dropoff_location_y': 159, 'payment': 295},
#        {'order_id': 16851, 'pickup_point_id': 46851, 'pickup_from': 360, 'pickup_to': 930, 'pickup_location_x': 274, 'pickup_location_y': 110, 'dropoff_point_id': 66851, 'dropoff_from': 871, 'dropoff_to': 990, 'dropoff_location_x': 329, 'dropoff_location_y': 53, 'payment': 324},
#        {'order_id': 15319, 'pickup_point_id': 45319, 'pickup_from': 330, 'pickup_to': 840, 'pickup_location_x': 166, 'pickup_location_y': 7, 'dropoff_point_id': 65319, 'dropoff_from': 870, 'dropoff_to': 1020, 'dropoff_location_x': 224, 'dropoff_location_y': 142, 'payment': 413},
#        {'order_id': 15832, 'pickup_point_id': 45832, 'pickup_from': 300, 'pickup_to': 780, 'pickup_location_x': 288, 'pickup_location_y': 131, 'dropoff_point_id': 65832, 'dropoff_from': 742, 'dropoff_to': 840, 'dropoff_location_x': 220, 'dropoff_location_y': 109, 'payment': 478},
#        {'order_id': 16346, 'pickup_point_id': 46346, 'pickup_from': 420, 'pickup_to': 870, 'pickup_location_x': 151, 'pickup_location_y': 213, 'dropoff_point_id': 66346, 'dropoff_from': 840, 'dropoff_to': 960, 'dropoff_location_x': 200, 'dropoff_location_y': 57, 'payment': 454},
#        {'order_id': 14804, 'pickup_point_id': 44804, 'pickup_from': 420, 'pickup_to': 1050, 'pickup_location_x': 261, 'pickup_location_y': 104, 'dropoff_point_id': 64804, 'dropoff_from': 1080, 'dropoff_to': 1140, 'dropoff_location_x': 133, 'dropoff_location_y': 86, 'payment': 401},
#        {'order_id': 15325, 'pickup_point_id': 45325, 'pickup_from': 360, 'pickup_to': 960, 'pickup_location_x': 114, 'pickup_location_y': 82, 'dropoff_point_id': 65325, 'dropoff_from': 840, 'dropoff_to': 1050, 'dropoff_location_x': 218, 'dropoff_location_y': 117, 'payment': 585},
#        {'order_id': 15326, 'pickup_point_id': 45326, 'pickup_from': 390, 'pickup_to': 840, 'pickup_location_x': 351, 'pickup_location_y': 161, 'dropoff_point_id': 65326, 'dropoff_from': 870, 'dropoff_to': 1080, 'dropoff_location_x': 50, 'dropoff_location_y': 158, 'payment': 523},
#        {'order_id': 16352, 'pickup_point_id': 46352, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 270, 'pickup_location_y': 69, 'dropoff_point_id': 66352, 'dropoff_from': 840, 'dropoff_to': 974, 'dropoff_location_x': 188, 'dropoff_location_y': 159, 'payment': 304},
#        {'order_id': 15842, 'pickup_point_id': 45842, 'pickup_from': 330, 'pickup_to': 960, 'pickup_location_x': 200, 'pickup_location_y': 74, 'dropoff_point_id': 65842, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 137, 'dropoff_location_y': 279, 'payment': 613},
#        {'order_id': 15844, 'pickup_point_id': 45844, 'pickup_from': 420, 'pickup_to': 1170, 'pickup_location_x': 94, 'pickup_location_y': 77, 'dropoff_point_id': 65844, 'dropoff_from': 1110, 'dropoff_to': 1200, 'dropoff_location_x': 228, 'dropoff_location_y': 81, 'payment': 467},
#        {'order_id': 15333, 'pickup_point_id': 45333, 'pickup_from': 360, 'pickup_to': 780, 'pickup_location_x': 322, 'pickup_location_y': 168, 'dropoff_point_id': 65333, 'dropoff_from': 780, 'dropoff_to': 840, 'dropoff_location_x': 252, 'dropoff_location_y': 197, 'payment': 484},
#        {'order_id': 16356, 'pickup_point_id': 46356, 'pickup_from': 390, 'pickup_to': 900, 'pickup_location_x': 202, 'pickup_location_y': 105, 'dropoff_point_id': 66356, 'dropoff_from': 840, 'dropoff_to': 900, 'dropoff_location_x': 292, 'dropoff_location_y': 149, 'payment': 412},
#        {'order_id': 11414, 'pickup_point_id': 41414, 'pickup_from': 420, 'pickup_to': 870, 'pickup_location_x': 243, 'pickup_location_y': 111, 'dropoff_point_id': 61414, 'dropoff_from': 900, 'dropoff_to': 930, 'dropoff_location_x': 61, 'dropoff_location_y': 212, 'payment': 397},
#        {'order_id': 16363, 'pickup_point_id': 46363, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 195, 'pickup_location_y': 183, 'dropoff_point_id': 66363, 'dropoff_from': 900, 'dropoff_to': 930, 'dropoff_location_x': 205, 'dropoff_location_y': 98, 'payment': 306},
#        {'order_id': 16876, 'pickup_point_id': 46876, 'pickup_from': 300, 'pickup_to': 930, 'pickup_location_x': 218, 'pickup_location_y': 146, 'dropoff_point_id': 66876, 'dropoff_from': 930, 'dropoff_to': 990, 'dropoff_location_x': 121, 'dropoff_location_y': 79, 'payment': 337},
#        {'order_id': 15854, 'pickup_point_id': 45854, 'pickup_from': 390, 'pickup_to': 810, 'pickup_location_x': 248, 'pickup_location_y': 199, 'dropoff_point_id': 65854, 'dropoff_from': 780, 'dropoff_to': 900, 'dropoff_location_x': 140, 'dropoff_location_y': 102, 'payment': 333},
#        {'order_id': 16882, 'pickup_point_id': 46882, 'pickup_from': 300, 'pickup_to': 930, 'pickup_location_x': 218, 'pickup_location_y': 155, 'dropoff_point_id': 66882, 'dropoff_from': 878, 'dropoff_to': 960, 'dropoff_location_x': 211, 'dropoff_location_y': 78, 'payment': 338},
#        {'order_id': 14835, 'pickup_point_id': 44835, 'pickup_from': 360, 'pickup_to': 720, 'pickup_location_x': 224, 'pickup_location_y': 141, 'dropoff_point_id': 64835, 'dropoff_from': 661, 'dropoff_to': 840, 'dropoff_location_x': 346, 'dropoff_location_y': 79, 'payment': 336},
#        {'order_id': 13177, 'pickup_point_id': 43177, 'pickup_from': 545, 'pickup_to': 990, 'pickup_location_x': 180, 'pickup_location_y': 39, 'dropoff_point_id': 63177, 'dropoff_from': 545, 'dropoff_to': 1020, 'dropoff_location_x': 91, 'dropoff_location_y': 146, 'payment': 322},
#        {'order_id': 13178, 'pickup_point_id': 43178, 'pickup_from': 545, 'pickup_to': 660, 'pickup_location_x': 75, 'pickup_location_y': 132, 'dropoff_point_id': 63178, 'dropoff_from': 545, 'dropoff_to': 840, 'dropoff_location_x': 224, 'dropoff_location_y': 172, 'payment': 451},
#        {'order_id': 13998, 'pickup_point_id': 43998, 'pickup_from': 300, 'pickup_to': 1020, 'pickup_location_x': 344, 'pickup_location_y': 65, 'dropoff_point_id': 63998, 'dropoff_from': 720, 'dropoff_to': 1050, 'dropoff_location_x': 211, 'dropoff_location_y': 108, 'payment': 306},
#        {'order_id': 15350, 'pickup_point_id': 45350, 'pickup_from': 330, 'pickup_to': 990, 'pickup_location_x': 225, 'pickup_location_y': 114, 'dropoff_point_id': 65350, 'dropoff_from': 960, 'dropoff_to': 1020, 'dropoff_location_x': 265, 'dropoff_location_y': 70, 'payment': 494},
#        {'order_id': 13183, 'pickup_point_id': 43183, 'pickup_from': 545, 'pickup_to': 780, 'pickup_location_x': 107, 'pickup_location_y': 55, 'dropoff_point_id': 63183, 'dropoff_from': 600, 'dropoff_to': 900, 'dropoff_location_x': 224, 'dropoff_location_y': 140, 'payment': 326},
#        {'order_id': 13187, 'pickup_point_id': 43187, 'pickup_from': 545, 'pickup_to': 750, 'pickup_location_x': 167, 'pickup_location_y': 114, 'dropoff_point_id': 63187, 'dropoff_from': 545, 'dropoff_to': 780, 'dropoff_location_x': 223, 'dropoff_location_y': 60, 'payment': 377},
#        {'order_id': 14845, 'pickup_point_id': 44845, 'pickup_from': 420, 'pickup_to': 720, 'pickup_location_x': 261, 'pickup_location_y': 84, 'dropoff_point_id': 64845, 'dropoff_from': 662, 'dropoff_to': 810, 'dropoff_location_x': 156, 'dropoff_location_y': 130, 'payment': 459},
#        {'order_id': 12312, 'pickup_point_id': 42312, 'pickup_from': 487, 'pickup_to': 780, 'pickup_location_x': 248, 'pickup_location_y': 192, 'dropoff_point_id': 62312, 'dropoff_from': 487, 'dropoff_to': 840, 'dropoff_location_x': 207, 'dropoff_location_y': 86, 'payment': 369},
#        {'order_id': 15869, 'pickup_point_id': 45869, 'pickup_from': 330, 'pickup_to': 1050, 'pickup_location_x': 229, 'pickup_location_y': 125, 'dropoff_point_id': 65869, 'dropoff_from': 990, 'dropoff_to': 1080, 'dropoff_location_x': 105, 'dropoff_location_y': 111, 'payment': 368},
#        {'order_id': 16384, 'pickup_point_id': 46384, 'pickup_from': 360, 'pickup_to': 930, 'pickup_location_x': 202, 'pickup_location_y': 130, 'dropoff_point_id': 66384, 'dropoff_from': 798, 'dropoff_to': 960, 'dropoff_location_x': 345, 'dropoff_location_y': 58, 'payment': 440},
#        {'order_id': 16385, 'pickup_point_id': 46385, 'pickup_from': 360, 'pickup_to': 870, 'pickup_location_x': 226, 'pickup_location_y': 117, 'dropoff_point_id': 66385, 'dropoff_from': 798, 'dropoff_to': 900, 'dropoff_location_x': 74, 'dropoff_location_y': 119, 'payment': 375},
#        {'order_id': 16898, 'pickup_point_id': 46898, 'pickup_from': 360, 'pickup_to': 960, 'pickup_location_x': 276, 'pickup_location_y': 54, 'dropoff_point_id': 66898, 'dropoff_from': 930, 'dropoff_to': 1067, 'dropoff_location_x': 147, 'dropoff_location_y': 122, 'payment': 337},
#        {'order_id': 14017, 'pickup_point_id': 44017, 'pickup_from': 420, 'pickup_to': 750, 'pickup_location_x': 336, 'pickup_location_y': 156, 'dropoff_point_id': 64017, 'dropoff_from': 900, 'dropoff_to': 960, 'dropoff_location_x': 188, 'dropoff_location_y': 0, 'payment': 479},
#        {'order_id': 16393, 'pickup_point_id': 46393, 'pickup_from': 360, 'pickup_to': 840, 'pickup_location_x': 225, 'pickup_location_y': 97, 'dropoff_point_id': 66393, 'dropoff_from': 840, 'dropoff_to': 900, 'dropoff_location_x': 111, 'dropoff_location_y': 51, 'payment': 500},
#        {'order_id': 14862, 'pickup_point_id': 44862, 'pickup_from': 390, 'pickup_to': 780, 'pickup_location_x': 272, 'pickup_location_y': 70, 'dropoff_point_id': 64862, 'dropoff_from': 664, 'dropoff_to': 900, 'dropoff_location_x': 201, 'dropoff_location_y': 142, 'payment': 349},
#        {'order_id': 16910, 'pickup_point_id': 46910, 'pickup_from': 360, 'pickup_to': 930, 'pickup_location_x': 279, 'pickup_location_y': 229, 'dropoff_point_id': 66910, 'dropoff_from': 1050, 'dropoff_to': 1080, 'dropoff_location_x': 274, 'dropoff_location_y': 9, 'payment': 706},
#        {'order_id': 14864, 'pickup_point_id': 44864, 'pickup_from': 420, 'pickup_to': 960, 'pickup_location_x': 81, 'pickup_location_y': 20, 'dropoff_point_id': 64864, 'dropoff_from': 720, 'dropoff_to': 960, 'dropoff_location_x': 380, 'dropoff_location_y': 99, 'payment': 409},
#        {'order_id': 12347, 'pickup_point_id': 42347, 'pickup_from': 390, 'pickup_to': 870, 'pickup_location_x': 82, 'pickup_location_y': 22, 'dropoff_point_id': 62347, 'dropoff_from': 870, 'dropoff_to': 960, 'dropoff_location_x': 183, 'dropoff_location_y': 102, 'payment': 290},
#        {'order_id': 14869, 'pickup_point_id': 44869, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 117, 'pickup_location_y': 193, 'dropoff_point_id': 64869, 'dropoff_from': 664, 'dropoff_to': 900, 'dropoff_location_x': 192, 'dropoff_location_y': 181, 'payment': 533},
#        {'order_id': 10591, 'pickup_point_id': 40591, 'pickup_from': 360, 'pickup_to': 1110, 'pickup_location_x': 230, 'pickup_location_y': 1, 'dropoff_point_id': 60591, 'dropoff_from': 1140, 'dropoff_to': 1200, 'dropoff_location_x': 287, 'dropoff_location_y': 113, 'payment': 449},
#        {'order_id': 16416, 'pickup_point_id': 46416, 'pickup_from': 330, 'pickup_to': 870, 'pickup_location_x': 251, 'pickup_location_y': 63, 'dropoff_point_id': 66416, 'dropoff_from': 870, 'dropoff_to': 930, 'dropoff_location_x': 196, 'dropoff_location_y': 190, 'payment': 583},
#        {'order_id': 16930, 'pickup_point_id': 46930, 'pickup_from': 300, 'pickup_to': 960, 'pickup_location_x': 257, 'pickup_location_y': 247, 'dropoff_point_id': 66930, 'dropoff_from': 930, 'dropoff_to': 1020, 'dropoff_location_x': 253, 'dropoff_location_y': 71, 'payment': 429},
#        {'order_id': 16419, 'pickup_point_id': 46419, 'pickup_from': 300, 'pickup_to': 840, 'pickup_location_x': 354, 'pickup_location_y': 45, 'dropoff_point_id': 66419, 'dropoff_from': 840, 'dropoff_to': 930, 'dropoff_location_x': 70, 'dropoff_location_y': 9, 'payment': 565},
#        {'order_id': 10600, 'pickup_point_id': 40600, 'pickup_from': 420, 'pickup_to': 1020, 'pickup_location_x': 140, 'pickup_location_y': 282, 'dropoff_point_id': 60600, 'dropoff_from': 1020, 'dropoff_to': 1080, 'dropoff_location_x': 321, 'dropoff_location_y': 144, 'payment': 415},
#        {'order_id': 16933, 'pickup_point_id': 46933, 'pickup_from': 300, 'pickup_to': 990, 'pickup_location_x': 165, 'pickup_location_y': 153, 'dropoff_point_id': 66933, 'dropoff_from': 890, 'dropoff_to': 1020, 'dropoff_location_x': 253, 'dropoff_location_y': 100, 'payment': 323},
#        {'order_id': 16421, 'pickup_point_id': 46421, 'pickup_from': 300, 'pickup_to': 990, 'pickup_location_x': 211, 'pickup_location_y': 80, 'dropoff_point_id': 66421, 'dropoff_from': 803, 'dropoff_to': 1020, 'dropoff_location_x': 364, 'dropoff_location_y': 158, 'payment': 365},
#        {'order_id': 16936, 'pickup_point_id': 46936, 'pickup_from': 390, 'pickup_to': 1050, 'pickup_location_x': 275, 'pickup_location_y': 2, 'dropoff_point_id': 66936, 'dropoff_from': 1050, 'dropoff_to': 1200, 'dropoff_location_x': 122, 'dropoff_location_y': 127, 'payment': 413},
#        {'order_id': 16938, 'pickup_point_id': 46938, 'pickup_from': 420, 'pickup_to': 1020, 'pickup_location_x': 244, 'pickup_location_y': 122, 'dropoff_point_id': 66938, 'dropoff_from': 892, 'dropoff_to': 1050, 'dropoff_location_x': 368, 'dropoff_location_y': 110, 'payment': 332},
#        {'order_id': 15403, 'pickup_point_id': 45403, 'pickup_from': 390, 'pickup_to': 750, 'pickup_location_x': 356, 'pickup_location_y': 77, 'dropoff_point_id': 65403, 'dropoff_from': 705, 'dropoff_to': 810, 'dropoff_location_x': 193, 'dropoff_location_y': 100, 'payment': 496},
#        {'order_id': 16942, 'pickup_point_id': 46942, 'pickup_from': 360, 'pickup_to': 990, 'pickup_location_x': 91, 'pickup_location_y': 119, 'dropoff_point_id': 66942, 'dropoff_from': 960, 'dropoff_to': 1146, 'dropoff_location_x': 268, 'dropoff_location_y': 73, 'payment': 443},
#        {'order_id': 11542, 'pickup_point_id': 41542, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 173, 'pickup_location_y': 216, 'dropoff_point_id': 61542, 'dropoff_from': 780, 'dropoff_to': 960, 'dropoff_location_x': 240, 'dropoff_location_y': 144, 'payment': 373},
#        {'order_id': 16951, 'pickup_point_id': 46951, 'pickup_from': 420, 'pickup_to': 990, 'pickup_location_x': 197, 'pickup_location_y': 139, 'dropoff_point_id': 66951, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 216, 'dropoff_location_y': 243, 'payment': 383},
#        {'order_id': 15416, 'pickup_point_id': 45416, 'pickup_from': 420, 'pickup_to': 1020, 'pickup_location_x': 165, 'pickup_location_y': 133, 'dropoff_point_id': 65416, 'dropoff_from': 840, 'dropoff_to': 1020, 'dropoff_location_x': 189, 'dropoff_location_y': 139, 'payment': 250},
#        {'order_id': 15930, 'pickup_point_id': 45930, 'pickup_from': 330, 'pickup_to': 840, 'pickup_location_x': 276, 'pickup_location_y': 99, 'dropoff_point_id': 65930, 'dropoff_from': 753, 'dropoff_to': 960, 'dropoff_location_x': 128, 'dropoff_location_y': 163, 'payment': 386},
#        {'order_id': 15421, 'pickup_point_id': 45421, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 165, 'pickup_location_y': 12, 'dropoff_point_id': 65421, 'dropoff_from': 810, 'dropoff_to': 1093, 'dropoff_location_x': 17, 'dropoff_location_y': 148, 'payment': 488},
#        {'order_id': 13291, 'pickup_point_id': 43291, 'pickup_from': 551, 'pickup_to': 720, 'pickup_location_x': 276, 'pickup_location_y': 138, 'dropoff_point_id': 63291, 'dropoff_from': 551, 'dropoff_to': 780, 'dropoff_location_x': 201, 'dropoff_location_y': 77, 'payment': 614},
#        {'order_id': 11560, 'pickup_point_id': 41560, 'pickup_from': 432, 'pickup_to': 870, 'pickup_location_x': 326, 'pickup_location_y': 99, 'dropoff_point_id': 61560, 'dropoff_from': 432, 'dropoff_to': 870, 'dropoff_location_x': 219, 'dropoff_location_y': 60, 'payment': 306},
#        {'order_id': 15424, 'pickup_point_id': 45424, 'pickup_from': 300, 'pickup_to': 780, 'pickup_location_x': 185, 'pickup_location_y': 44, 'dropoff_point_id': 65424, 'dropoff_from': 706, 'dropoff_to': 810, 'dropoff_location_x': 194, 'dropoff_location_y': 134, 'payment': 312},
#        {'order_id': 16445, 'pickup_point_id': 46445, 'pickup_from': 420, 'pickup_to': 840, 'pickup_location_x': 333, 'pickup_location_y': 89, 'dropoff_point_id': 66445, 'dropoff_from': 805, 'dropoff_to': 930, 'dropoff_location_x': 192, 'dropoff_location_y': 189, 'payment': 448},
#        {'order_id': 16456, 'pickup_point_id': 46456, 'pickup_from': 300, 'pickup_to': 870, 'pickup_location_x': 127, 'pickup_location_y': 132, 'dropoff_point_id': 66456, 'dropoff_from': 870, 'dropoff_to': 930, 'dropoff_location_x': 214, 'dropoff_location_y': 85, 'payment': 329},
#        {'order_id': 10669, 'pickup_point_id': 40669, 'pickup_from': 480, 'pickup_to': 840, 'pickup_location_x': 285, 'pickup_location_y': 198, 'dropoff_point_id': 60669, 'dropoff_from': 480, 'dropoff_to': 1080, 'dropoff_location_x': 161, 'dropoff_location_y': 55, 'payment': 343},
#        {'order_id': 15434, 'pickup_point_id': 45434, 'pickup_from': 390, 'pickup_to': 1200, 'pickup_location_x': 130, 'pickup_location_y': 211, 'dropoff_point_id': 65434, 'dropoff_from': 707, 'dropoff_to': 1230, 'dropoff_location_x': 291, 'dropoff_location_y': 190, 'payment': 435},
#        {'order_id': 15435, 'pickup_point_id': 45435, 'pickup_from': 420, 'pickup_to': 750, 'pickup_location_x': 316, 'pickup_location_y': 17, 'dropoff_point_id': 65435, 'dropoff_from': 707, 'dropoff_to': 900, 'dropoff_location_x': 14, 'dropoff_location_y': 125, 'payment': 586},
#        {'order_id': 10670, 'pickup_point_id': 40670, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 139, 'pickup_location_y': 46, 'dropoff_point_id': 60670, 'dropoff_from': 900, 'dropoff_to': 960, 'dropoff_location_x': 179, 'dropoff_location_y': 99, 'payment': 304},
#        {'order_id': 15437, 'pickup_point_id': 45437, 'pickup_from': 360, 'pickup_to': 810, 'pickup_location_x': 90, 'pickup_location_y': 156, 'dropoff_point_id': 65437, 'dropoff_from': 707, 'dropoff_to': 840, 'dropoff_location_x': 330, 'dropoff_location_y': 75, 'payment': 382},
#        {'order_id': 15438, 'pickup_point_id': 45438, 'pickup_from': 360, 'pickup_to': 750, 'pickup_location_x': 190, 'pickup_location_y': 227, 'dropoff_point_id': 65438, 'dropoff_from': 707, 'dropoff_to': 900, 'dropoff_location_x': 363, 'dropoff_location_y': 67, 'payment': 507},
#        {'order_id': 14139, 'pickup_point_id': 44139, 'pickup_from': 609, 'pickup_to': 780, 'pickup_location_x': 225, 'pickup_location_y': 91, 'dropoff_point_id': 64139, 'dropoff_from': 609, 'dropoff_to': 840, 'dropoff_location_x': 335, 'dropoff_location_y': 164, 'payment': 398},
#        {'order_id': 16975, 'pickup_point_id': 46975, 'pickup_from': 330, 'pickup_to': 960, 'pickup_location_x': 201, 'pickup_location_y': 150, 'dropoff_point_id': 66975, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 2, 'dropoff_location_y': 93, 'payment': 442},
#        {'order_id': 15441, 'pickup_point_id': 45441, 'pickup_from': 360, 'pickup_to': 780, 'pickup_location_x': 167, 'pickup_location_y': 249, 'dropoff_point_id': 65441, 'dropoff_from': 750, 'dropoff_to': 840, 'dropoff_location_x': 245, 'dropoff_location_y': 25, 'payment': 434},
#        {'order_id': 15443, 'pickup_point_id': 45443, 'pickup_from': 420, 'pickup_to': 780, 'pickup_location_x': 206, 'pickup_location_y': 186, 'dropoff_point_id': 65443, 'dropoff_from': 708, 'dropoff_to': 840, 'dropoff_location_x': 238, 'dropoff_location_y': 33, 'payment': 425},
#        {'order_id': 15444, 'pickup_point_id': 45444, 'pickup_from': 420, 'pickup_to': 780, 'pickup_location_x': 195, 'pickup_location_y': 183, 'dropoff_point_id': 65444, 'dropoff_from': 810, 'dropoff_to': 870, 'dropoff_location_x': 59, 'dropoff_location_y': 123, 'payment': 366},
#        {'order_id': 15445, 'pickup_point_id': 45445, 'pickup_from': 420, 'pickup_to': 780, 'pickup_location_x': 213, 'pickup_location_y': 217, 'dropoff_point_id': 65445, 'dropoff_from': 708, 'dropoff_to': 840, 'dropoff_location_x': 274, 'dropoff_location_y': 65, 'payment': 361},
#        {'order_id': 15447, 'pickup_point_id': 45447, 'pickup_from': 360, 'pickup_to': 780, 'pickup_location_x': 279, 'pickup_location_y': 229, 'dropoff_point_id': 65447, 'dropoff_from': 750, 'dropoff_to': 840, 'dropoff_location_x': 368, 'dropoff_location_y': 122, 'payment': 582},
#        {'order_id': 15448, 'pickup_point_id': 45448, 'pickup_from': 360, 'pickup_to': 840, 'pickup_location_x': 179, 'pickup_location_y': 229, 'dropoff_point_id': 65448, 'dropoff_from': 720, 'dropoff_to': 900, 'dropoff_location_x': 332, 'dropoff_location_y': 90, 'payment': 551},
#        {'order_id': 12480, 'pickup_point_id': 42480, 'pickup_from': 499, 'pickup_to': 840, 'pickup_location_x': 169, 'pickup_location_y': 172, 'dropoff_point_id': 62480, 'dropoff_from': 499, 'dropoff_to': 870, 'dropoff_location_x': 373, 'dropoff_location_y': 72, 'payment': 620},
#        {'order_id': 16989, 'pickup_point_id': 46989, 'pickup_from': 360, 'pickup_to': 1050, 'pickup_location_x': 254, 'pickup_location_y': 168, 'dropoff_point_id': 66989, 'dropoff_from': 906, 'dropoff_to': 1080, 'dropoff_location_x': 32, 'dropoff_location_y': 154, 'payment': 509},
#        {'order_id': 15454, 'pickup_point_id': 45454, 'pickup_from': 330, 'pickup_to': 750, 'pickup_location_x': 193, 'pickup_location_y': 192, 'dropoff_point_id': 65454, 'dropoff_from': 709, 'dropoff_to': 840, 'dropoff_location_x': 259, 'dropoff_location_y': 118, 'payment': 393},
#        {'order_id': 16990, 'pickup_point_id': 46990, 'pickup_from': 360, 'pickup_to': 1020, 'pickup_location_x': 354, 'pickup_location_y': 81, 'dropoff_point_id': 66990, 'dropoff_from': 1080, 'dropoff_to': 1140, 'dropoff_location_x': 215, 'dropoff_location_y': 249, 'payment': 459},
#        {'order_id': 15458, 'pickup_point_id': 45458, 'pickup_from': 300, 'pickup_to': 900, 'pickup_location_x': 345, 'pickup_location_y': 54, 'dropoff_point_id': 65458, 'dropoff_from': 709, 'dropoff_to': 1020, 'dropoff_location_x': 50, 'dropoff_location_y': 158, 'payment': 551},
#        {'order_id': 10716, 'pickup_point_id': 40716, 'pickup_from': 330, 'pickup_to': 1050, 'pickup_location_x': 370, 'pickup_location_y': 110, 'dropoff_point_id': 60716, 'dropoff_from': 990, 'dropoff_to': 1140, 'dropoff_location_x': 14, 'dropoff_location_y': 94, 'payment': 540},
#        {'order_id': 15976, 'pickup_point_id': 45976, 'pickup_from': 330, 'pickup_to': 1020, 'pickup_location_x': 199, 'pickup_location_y': 101, 'dropoff_point_id': 65976, 'dropoff_from': 757, 'dropoff_to': 1050, 'dropoff_location_x': 159, 'dropoff_location_y': 271, 'payment': 333},
#        {'order_id': 16497, 'pickup_point_id': 46497, 'pickup_from': 390, 'pickup_to': 900, 'pickup_location_x': 82, 'pickup_location_y': 22, 'dropoff_point_id': 66497, 'dropoff_from': 812, 'dropoff_to': 960, 'dropoff_location_x': 183, 'dropoff_location_y': 102, 'payment': 290},
#        {'order_id': 17011, 'pickup_point_id': 47011, 'pickup_from': 360, 'pickup_to': 990, 'pickup_location_x': 266, 'pickup_location_y': 180, 'dropoff_point_id': 67011, 'dropoff_from': 913, 'dropoff_to': 1080, 'dropoff_location_x': 92, 'dropoff_location_y': 224, 'payment': 480},
#        {'order_id': 17014, 'pickup_point_id': 47014, 'pickup_from': 360, 'pickup_to': 990, 'pickup_location_x': 202, 'pickup_location_y': 62, 'dropoff_point_id': 67014, 'dropoff_from': 1020, 'dropoff_to': 1140, 'dropoff_location_x': 368, 'dropoff_location_y': 113, 'payment': 493},
#        {'order_id': 15990, 'pickup_point_id': 45990, 'pickup_from': 420, 'pickup_to': 840, 'pickup_location_x': 139, 'pickup_location_y': 180, 'dropoff_point_id': 65990, 'dropoff_from': 758, 'dropoff_to': 960, 'dropoff_location_x': 308, 'dropoff_location_y': 90, 'payment': 563},
#        {'order_id': 11660, 'pickup_point_id': 41660, 'pickup_from': 660, 'pickup_to': 810, 'pickup_location_x': 200, 'pickup_location_y': 141, 'dropoff_point_id': 61660, 'dropoff_from': 780, 'dropoff_to': 900, 'dropoff_location_x': 271, 'dropoff_location_y': 216, 'payment': 343},
#        {'order_id': 15997, 'pickup_point_id': 45997, 'pickup_from': 390, 'pickup_to': 840, 'pickup_location_x': 246, 'pickup_location_y': 26, 'dropoff_point_id': 65997, 'dropoff_from': 759, 'dropoff_to': 870, 'dropoff_location_x': 190, 'dropoff_location_y': 128, 'payment': 333},
#        {'order_id': 11670, 'pickup_point_id': 41670, 'pickup_from': 450, 'pickup_to': 840, 'pickup_location_x': 167, 'pickup_location_y': 226, 'dropoff_point_id': 61670, 'dropoff_from': 660, 'dropoff_to': 840, 'dropoff_location_x': 176, 'dropoff_location_y': 212, 'payment': 250},
#        {'order_id': 17027, 'pickup_point_id': 47027, 'pickup_from': 390, 'pickup_to': 1020, 'pickup_location_x': 230, 'pickup_location_y': 132, 'dropoff_point_id': 67027, 'dropoff_from': 1020, 'dropoff_to': 1050, 'dropoff_location_x': 281, 'dropoff_location_y': 266, 'payment': 406},
#        {'order_id': 17040, 'pickup_point_id': 47040, 'pickup_from': 420, 'pickup_to': 990, 'pickup_location_x': 252, 'pickup_location_y': 209, 'dropoff_point_id': 67040, 'dropoff_from': 920, 'dropoff_to': 1050, 'dropoff_location_x': 171, 'dropoff_location_y': 176, 'payment': 291},
#        {'order_id': 15507, 'pickup_point_id': 45507, 'pickup_from': 360, 'pickup_to': 900, 'pickup_location_x': 168, 'pickup_location_y': 147, 'dropoff_point_id': 65507, 'dropoff_from': 714, 'dropoff_to': 930, 'dropoff_location_x': 330, 'dropoff_location_y': 75, 'payment': 441},
#        {'order_id': 14270, 'pickup_point_id': 44270, 'pickup_from': 618, 'pickup_to': 810, 'pickup_location_x': 153, 'pickup_location_y': 135, 'dropoff_point_id': 64270, 'dropoff_from': 660, 'dropoff_to': 840, 'dropoff_location_x': 217, 'dropoff_location_y': 163, 'payment': 397},
#        {'order_id': 15004, 'pickup_point_id': 45004, 'pickup_from': 330, 'pickup_to': 750, 'pickup_location_x': 276, 'pickup_location_y': 81, 'dropoff_point_id': 65004, 'dropoff_from': 674, 'dropoff_to': 780, 'dropoff_location_x': 225, 'dropoff_location_y': 123, 'payment': 327},
#        {'order_id': 15517, 'pickup_point_id': 45517, 'pickup_from': 330, 'pickup_to': 810, 'pickup_location_x': 325, 'pickup_location_y': 52, 'dropoff_point_id': 65517, 'dropoff_from': 714, 'dropoff_to': 870, 'dropoff_location_x': 231, 'dropoff_location_y': 92, 'payment': 430},
#        {'order_id': 16542, 'pickup_point_id': 46542, 'pickup_from': 420, 'pickup_to': 900, 'pickup_location_x': 169, 'pickup_location_y': 173, 'dropoff_point_id': 66542, 'dropoff_from': 818, 'dropoff_to': 960, 'dropoff_location_x': 297, 'dropoff_location_y': 13, 'payment': 461}],
#       dtype=object)

# %%
orders_drop_times[2992]
# Out:
# array([669, 780])

# %%
is_used = np.zeros(len(orders))
single_step(111, 5, is_used)
# Out:
# array([3817, 3500, 3502, 3503, 1885, 3506, 3510, 1881])

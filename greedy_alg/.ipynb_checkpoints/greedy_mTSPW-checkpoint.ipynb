# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from tqdm import tqdm_notebook
# %matplotlib inline

# %%
def load_data(file):
    """Загрузка входных данных из файла"""
    with open(file, 'r') as f:
        input_data = json.load(f)
    couriers = {}
    orders = {}
    points = {}
    for depotData in input_data['depots']:
        points[depotData['point_id']] = {
            'location': [depotData['location_x'], depotData['location_y']],
            'timewindow': [0, 1439],
        }
    for courierData in input_data['couriers']:
        couriers[courierData['courier_id']] = {
            'location': [courierData['location_x'], courierData['location_y']],
            'time': 360,
        }
    for orderData in input_data['orders']:
        points[orderData['pickup_point_id']] = {
            'location': [orderData['pickup_location_x'], orderData['pickup_location_y']],
            'timewindow': [orderData['pickup_from'], orderData['pickup_to']],
            'order_time': {orderData['order_id']: orderData['pickup_from']}
        }
        points[orderData['dropoff_point_id']] = {
            'location': [orderData['dropoff_location_x'], orderData['dropoff_location_y']],
            'timewindow': [orderData['dropoff_from'], orderData['dropoff_to']],
        }
        orders[orderData['order_id']] = orderData
    return couriers, orders, points

# %%
data = load_data("data/contest_input.json")

# %%
data
# Out:
# ({1: {'location': [111, 5], 'time': 360},
#   2: {'location': [260, 112], 'time': 360},
#   3: {'location': [207, 66], 'time': 360},
#   4: {'location': [288, 55], 'time': 360},
#   5: {'location': [253, 234], 'time': 360},
#   6: {'location': [210, 109], 'time': 360},
#   7: {'location': [200, 46], 'time': 360},
#   8: {'location': [270, 211], 'time': 360},
#   9: {'location': [221, 157], 'time': 360},
#   10: {'location': [328, 42], 'time': 360},
#   11: {'location': [125, 126], 'time': 360},
#   12: {'location': [218, 157], 'time': 360},
#   13: {'location': [13, 91], 'time': 360},
#   14: {'location': [223, 105], 'time': 360},
#   15: {'location': [0, 37], 'time': 360},
#   16: {'location': [308, 103], 'time': 360},
#   17: {'location': [245, 161], 'time': 360},
#   18: {'location': [57, 195], 'time': 360},
#   19: {'location': [219, 73], 'time': 360},
#   20: {'location': [145, 217], 'time': 360},
#   21: {'location': [164, 111], 'time': 360},
#   22: {'location': [209, 77], 'time': 360},
#   23: {'location': [84, 155], 'time': 360},
#   24: {'location': [222, 137], 'time': 360},
#   25: {'location': [218, 140], 'time': 360},
#   26: {'location': [210, 81], 'time': 360},
#   27: {'location': [295, 15], 'time': 360},
#   28: {'location': [364, 158], 'time': 360},
#   29: {'location': [201, 137], 'time': 360},
#   30: {'location': [220, 214], 'time': 360},
#   31: {'location': [162, 158], 'time': 360},
#   32: {'location': [98, 25], 'time': 360},
#   33: {'location': [267, 77], 'time': 360},
#   34: {'location': [229, 143], 'time': 360},
#   35: {'location': [115, 46], 'time': 360},
#   36: {'location': [201, 4], 'time': 360},
#   37: {'location': [170, 169], 'time': 360},
#   38: {'location': [216, 141], 'time': 360},
#   39: {'location': [199, 87], 'time': 360},
#   40: {'location': [295, 53], 'time': 360},
#   41: {'location': [229, 125], 'time': 360},
#   42: {'location': [10, 31], 'time': 360},
#   43: {'location': [106, 150], 'time': 360},
#   44: {'location': [220, 130], 'time': 360},
#   45: {'location': [288, 106], 'time': 360},
#   46: {'location': [292, 112], 'time': 360},
#   47: {'location': [164, 156], 'time': 360},
#   48: {'location': [57, 195], 'time': 360},
#   49: {'location': [328, 42], 'time': 360},
#   50: {'location': [147, 77], 'time': 360},
#   51: {'location': [125, 126], 'time': 360},
#   52: {'location': [204, 98], 'time': 360},
#   53: {'location': [59, 179], 'time': 360},
#   54: {'location': [69, 125], 'time': 360},
#   55: {'location': [288, 106], 'time': 360},
#   56: {'location': [336, 16], 'time': 360},
#   57: {'location': [58, 211], 'time': 360},
#   58: {'location': [104, 132], 'time': 360},
#   59: {'location': [162, 224], 'time': 360},
#   60: {'location': [163, 111], 'time': 360},
#   61: {'location': [82, 69], 'time': 360},
#   62: {'location': [254, 215], 'time': 360},
#   63: {'location': [142, 103], 'time': 360},
#   64: {'location': [337, 122], 'time': 360},
#   65: {'location': [165, 309], 'time': 360},
#   66: {'location': [176, 168], 'time': 360},
#   67: {'location': [58, 211], 'time': 360},
#   68: {'location': [147, 200], 'time': 360},
#   69: {'location': [361, 121], 'time': 360},
#   70: {'location': [237, 170], 'time': 360},
#   71: {'location': [247, 184], 'time': 360},
#   72: {'location': [328, 95], 'time': 360},
#   73: {'location': [291, 114], 'time': 360},
#   74: {'location': [190, 200], 'time': 360},
#   75: {'location': [205, 55], 'time': 360},
#   76: {'location': [277, 244], 'time': 360},
#   77: {'location': [291, 125], 'time': 360},
#   78: {'location': [266, 56], 'time': 360},
#   79: {'location': [99, 210], 'time': 360},
#   80: {'location': [206, 120], 'time': 360},
#   81: {'location': [190, 22], 'time': 360},
#   82: {'location': [247, 184], 'time': 360},
#   83: {'location': [181, 97], 'time': 360},
#   84: {'location': [187, 135], 'time': 360},
#   85: {'location': [200, 153], 'time': 360},
#   86: {'location': [190, 127], 'time': 360},
#   87: {'location': [145, 123], 'time': 360},
#   88: {'location': [299, 148], 'time': 360},
#   89: {'location': [342, 86], 'time': 360},
#   90: {'location': [328, 42], 'time': 360},
#   91: {'location': [218, 157], 'time': 360},
#   92: {'location': [241, 155], 'time': 360},
#   93: {'location': [328, 42], 'time': 360},
#   94: {'location': [254, 210], 'time': 360},
#   95: {'location': [198, 131], 'time': 360},
#   96: {'location': [240, 155], 'time': 360},
#   97: {'location': [165, 134], 'time': 360},
#   98: {'location': [291, 114], 'time': 360},
#   99: {'location': [162, 158], 'time': 360},
#   100: {'location': [319, 113], 'time': 360},
#   101: {'location': [354, 45], 'time': 360},
#   102: {'location': [204, 99], 'time': 360},
#   103: {'location': [274, 108], 'time': 360},
#   104: {'location': [219, 1], 'time': 360},
#   105: {'location': [200, 46], 'time': 360},
#   106: {'location': [69, 210], 'time': 360},
#   107: {'location': [205, 55], 'time': 360},
#   108: {'location': [190, 23], 'time': 360},
#   109: {'location': [57, 195], 'time': 360},
#   110: {'location': [220, 130], 'time': 360},
#   111: {'location': [216, 141], 'time': 360},
#   112: {'location': [137, 134], 'time': 360},
#   113: {'location': [160, 278], 'time': 360},
#   114: {'location': [291, 136], 'time': 360},
#   115: {'location': [316, 104], 'time': 360},
#   116: {'location': [111, 214], 'time': 360},
#   117: {'location': [200, 78], 'time': 360},
#   118: {'location': [176, 168], 'time': 360},
#   119: {'location': [219, 1], 'time': 360},
#   120: {'location': [81, 224], 'time': 360},
#   121: {'location': [311, 48], 'time': 360},
#   122: {'location': [336, 16], 'time': 360},
#   123: {'location': [240, 155], 'time': 360},
#   124: {'location': [213, 237], 'time': 360},
#   125: {'location': [201, 155], 'time': 360},
#   126: {'location': [201, 155], 'time': 360},
#   127: {'location': [201, 136], 'time': 360},
#   128: {'location': [229, 143], 'time': 360},
#   129: {'location': [292, 112], 'time': 360},
#   130: {'location': [82, 47], 'time': 360},
#   131: {'location': [129, 221], 'time': 360},
#   132: {'location': [218, 157], 'time': 360},
#   133: {'location': [291, 114], 'time': 360},
#   134: {'location': [271, 5], 'time': 360},
#   135: {'location': [318, 145], 'time': 360},
#   136: {'location': [324, 18], 'time': 360},
#   137: {'location': [238, 86], 'time': 360},
#   138: {'location': [376, 111], 'time': 360},
#   139: {'location': [200, 46], 'time': 360},
#   140: {'location': [218, 157], 'time': 360},
#   141: {'location': [311, 69], 'time': 360},
#   142: {'location': [259, 142], 'time': 360},
#   143: {'location': [69, 9], 'time': 360},
#   144: {'location': [340, 41], 'time': 360},
#   145: {'location': [142, 103], 'time': 360},
#   146: {'location': [266, 56], 'time': 360},
#   147: {'location': [261, 245], 'time': 360},
#   148: {'location': [266, 56], 'time': 360},
#   149: {'location': [247, 128], 'time': 360},
#   150: {'location': [209, 77], 'time': 360},
#   151: {'location': [189, 144], 'time': 360},
#   152: {'location': [223, 108], 'time': 360},
#   153: {'location': [125, 126], 'time': 360},
#   154: {'location': [311, 163], 'time': 360},
#   155: {'location': [223, 105], 'time': 360},
#   156: {'location': [232, 151], 'time': 360},
#   157: {'location': [219, 72], 'time': 360},
#   158: {'location': [205, 55], 'time': 360},
#   159: {'location': [272, 66], 'time': 360},
#   160: {'location': [58, 211], 'time': 360},
#   161: {'location': [337, 122], 'time': 360},
#   162: {'location': [255, 170], 'time': 360},
#   163: {'location': [241, 61], 'time': 360},
#   164: {'location': [165, 309], 'time': 360},
#   165: {'location': [25, 117], 'time': 360},
#   166: {'location': [190, 22], 'time': 360},
#   167: {'location': [283, 204], 'time': 360},
#   168: {'location': [196, 36], 'time': 360},
#   169: {'location': [158, 277], 'time': 360},
#   170: {'location': [255, 170], 'time': 360},
#   171: {'location': [220, 214], 'time': 360},
#   172: {'location': [0, 37], 'time': 360},
#   173: {'location': [164, 156], 'time': 360},
#   174: {'location': [219, 1], 'time': 360},
#   175: {'location': [218, 140], 'time': 360},
#   176: {'location': [221, 157], 'time': 360},
#   177: {'location': [254, 215], 'time': 360},
#   178: {'location': [24, 67], 'time': 360},
#   179: {'location': [39, 121], 'time': 360},
#   180: {'location': [304, 103], 'time': 360},
#   181: {'location': [247, 140], 'time': 360},
#   182: {'location': [151, 53], 'time': 360},
#   183: {'location': [299, 148], 'time': 360},
#   184: {'location': [241, 109], 'time': 360},
#   185: {'location': [127, 282], 'time': 360},
#   186: {'location': [106, 150], 'time': 360},
#   187: {'location': [176, 124], 'time': 360},
#   188: {'location': [162, 224], 'time': 360},
#   189: {'location': [219, 73], 'time': 360},
#   190: {'location': [174, 241], 'time': 360},
#   191: {'location': [361, 121], 'time': 360},
#   192: {'location': [166, 201], 'time': 360},
#   193: {'location': [163, 111], 'time': 360},
#   194: {'location': [170, 169], 'time': 360},
#   195: {'location': [46, 91], 'time': 360},
#   196: {'location': [209, 77], 'time': 360},
#   197: {'location': [260, 130], 'time': 360},
#   198: {'location': [130, 60], 'time': 360},
#   199: {'location': [190, 22], 'time': 360},
#   200: {'location': [282, 121], 'time': 360},
#   201: {'location': [285, 206], 'time': 360},
#   202: {'location': [223, 136], 'time': 360},
#   203: {'location': [247, 140], 'time': 360},
#   204: {'location': [99, 210], 'time': 360},
#   205: {'location': [162, 158], 'time': 360},
#   206: {'location': [201, 138], 'time': 360},
#   207: {'location': [104, 132], 'time': 360},
#   208: {'location': [210, 109], 'time': 360},
#   209: {'location': [292, 112], 'time': 360},
#   210: {'location': [131, 160], 'time': 360},
#   211: {'location': [69, 9], 'time': 360},
#   212: {'location': [84, 155], 'time': 360},
#   213: {'location': [29, 15], 'time': 360},
#   214: {'location': [84, 155], 'time': 360},
#   215: {'location': [144, 46], 'time': 360},
#   216: {'location': [184, 174], 'time': 360},
#   217: {'location': [270, 211], 'time': 360},
#   218: {'location': [106, 150], 'time': 360},
#   219: {'location': [44, 92], 'time': 360},
#   220: {'location': [167, 295], 'time': 360},
#   221: {'location': [145, 217], 'time': 360},
#   222: {'location': [247, 128], 'time': 360},
#   223: {'location': [201, 155], 'time': 360},
#   224: {'location': [144, 131], 'time': 360},
#   225: {'location': [69, 9], 'time': 360},
#   226: {'location': [207, 66], 'time': 360},
#   227: {'location': [241, 70], 'time': 360},
#   228: {'location': [229, 143], 'time': 360},
#   229: {'location': [242, 108], 'time': 360},
#   230: {'location': [200, 46], 'time': 360},
#   231: {'location': [254, 210], 'time': 360},
#   232: {'location': [308, 103], 'time': 360},
#   233: {'location': [287, 16], 'time': 360},
#   234: {'location': [256, 93], 'time': 360},
#   235: {'location': [104, 132], 'time': 360},
#   236: {'location': [277, 34], 'time': 360},
#   237: {'location': [167, 295], 'time': 360},
#   238: {'location': [106, 150], 'time': 360},
#   239: {'location': [235, 132], 'time': 360},
#   240: {'location': [231, 133], 'time': 360},
#   241: {'location': [200, 46], 'time': 360},
#   242: {'location': [308, 103], 'time': 360},
#   243: {'location': [207, 171], 'time': 360},
#   244: {'location': [11, 104], 'time': 360},
#   245: {'location': [311, 163], 'time': 360},
#   246: {'location': [340, 41], 'time': 360},
#   247: {'location': [89, 34], 'time': 360},
#   248: {'location': [167, 94], 'time': 360},
#   249: {'location': [189, 144], 'time': 360},
#   250: {'location': [240, 155], 'time': 360},
#   251: {'location': [59, 179], 'time': 360},
#   252: {'location': [277, 244], 'time': 360},
#   253: {'location': [190, 142], 'time': 360},
#   254: {'location': [206, 286], 'time': 360},
#   255: {'location': [260, 112], 'time': 360},
#   256: {'location': [127, 282], 'time': 360},
#   257: {'location': [261, 245], 'time': 360},
#   258: {'location': [206, 120], 'time': 360},
#   259: {'location': [247, 128], 'time': 360},
#   260: {'location': [271, 5], 'time': 360},
#   261: {'location': [44, 92], 'time': 360},
#   262: {'location': [259, 142], 'time': 360},
#   263: {'location': [123, 25], 'time': 360},
#   264: {'location': [210, 81], 'time': 360},
#   265: {'location': [81, 224], 'time': 360},
#   266: {'location': [364, 158], 'time': 360},
#   267: {'location': [256, 93], 'time': 360},
#   268: {'location': [69, 9], 'time': 360},
#   269: {'location': [137, 134], 'time': 360},
#   270: {'location': [195, 116], 'time': 360},
#   271: {'location': [292, 146], 'time': 360},
#   272: {'location': [267, 77], 'time': 360},
#   273: {'location': [319, 113], 'time': 360},
#   274: {'location': [206, 286], 'time': 360},
#   275: {'location': [238, 86], 'time': 360},
#   276: {'location': [235, 116], 'time': 360},
#   277: {'location': [282, 121], 'time': 360},
#   278: {'location': [283, 204], 'time': 360},
#   279: {'location': [210, 81], 'time': 360},
#   280: {'location': [255, 170], 'time': 360},
#   281: {'location': [131, 160], 'time': 360},
#   282: {'location': [255, 59], 'time': 360},
#   283: {'location': [319, 113], 'time': 360},
#   284: {'location': [228, 95], 'time': 360},
#   285: {'location': [96, 39], 'time': 360},
#   286: {'location': [51, 77], 'time': 360},
#   287: {'location': [199, 87], 'time': 360},
#   288: {'location': [191, 161], 'time': 360},
#   289: {'location': [81, 20], 'time': 360},
#   290: {'location': [207, 66], 'time': 360},
#   291: {'location': [233, 117], 'time': 360},
#   292: {'location': [241, 155], 'time': 360},
#   293: {'location': [220, 131], 'time': 360},
#   294: {'location': [102, 119], 'time': 360},
#   295: {'location': [258, 93], 'time': 360},
#   296: {'location': [266, 56], 'time': 360},
#   297: {'location': [214, 124], 'time': 360},
#   298: {'location': [229, 143], 'time': 360},
#   299: {'location': [106, 150], 'time': 360},
#   300: {'location': [220, 131], 'time': 360}},
#  {10001: {'order_id': 10001,
#    'pickup_point_id': 40001,
#    'pickup_from': 480,
#    'pickup_to': 570,
#    'pickup_location_x': 284,
#    'pickup_location_y': 235,
#    'dropoff_point_id': 60001,
#    'dropoff_from': 600,
#    'dropoff_to': 960,
#    'dropoff_location_x': 252,
#    'dropoff_location_y': 197,
#    'payment': 313},
#   10002: {'order_id': 10002,
#    'pickup_point_id': 40002,
#    'pickup_from': 420,
#    'pickup_to': 450,
#    'pickup_location_x': 244,
#    'pickup_location_y': 262,
#    'dropoff_point_id': 60002,
#    'dropoff_from': 630,
#    'dropoff_to': 660,
#    'dropoff_location_x': 24,
#    'dropoff_location_y': 105,
#    'payment': 519},
#   10003: {'order_id': 10003,
#    'pickup_point_id': 40003,
#    'pickup_from': 390,
#    'pickup_to': 1020,
#    'pickup_location_x': 225,
#    'pickup_location_y': 141,
#    'dropoff_point_id': 60003,
#    'dropoff_from': 1050,
#    'dropoff_to': 1080,
#    'dropoff_location_x': 115,
#    'dropoff_location_y': 38,
#    'payment': 380},
#   10004: {'order_id': 10004,
#    'pickup_point_id': 40004,
#    'pickup_from': 300,
#    'pickup_to': 330,
#    'pickup_location_x': 233,
#    'pickup_location_y': 108,
#    'dropoff_point_id': 60004,
#    'dropoff_from': 420,
#    'dropoff_to': 450,
#    'dropoff_location_x': 236,
#    'dropoff_location_y': 165,
#    'payment': 302},
#   10005: {'order_id': 10005,
#    'pickup_point_id': 40005,
#    'pickup_from': 300,
#    'pickup_to': 780,
#    'pickup_location_x': 233,
#    'pickup_location_y': 108,
#    'dropoff_point_id': 60005,
#    'dropoff_from': 840,
#    'dropoff_to': 870,
#    'dropoff_location_x': 12,
#    'dropoff_location_y': 101,
#    'payment': 482},
#   10006: {'order_id': 10006,
#    'pickup_point_id': 40006,
#    'pickup_from': 240,
#    'pickup_to': 270,
#    'pickup_location_x': 233,
#    'pickup_location_y': 108,
#    'dropoff_point_id': 60006,
#    'dropoff_from': 330,
#    'dropoff_to': 360,
#    'dropoff_location_x': 179,
#    'dropoff_location_y': 128,
#    'payment': 298},
#   10007: {'order_id': 10007,
#    'pickup_point_id': 40007,
#    'pickup_from': 480,
#    'pickup_to': 540,
#    'pickup_location_x': 47,
#    'pickup_location_y': 78,
#    'dropoff_point_id': 60007,
#    'dropoff_from': 600,
#    'dropoff_to': 660,
#    'dropoff_location_x': 280,
#    'dropoff_location_y': 142,
#    'payment': 521},
#   10008: {'order_id': 10008,
#    'pickup_point_id': 40008,
#    'pickup_from': 360,
#    'pickup_to': 480,
#    'pickup_location_x': 241,
#    'pickup_location_y': 203,
#    'dropoff_point_id': 60008,
#    'dropoff_from': 420,
#    'dropoff_to': 780,
#    'dropoff_location_x': 193,
#    'dropoff_location_y': 112,
#    'payment': 337},
#   10009: {'order_id': 10009,
#    'pickup_point_id': 40009,
#    'pickup_from': 600,
#    'pickup_to': 630,
#    'pickup_location_x': 244,
#    'pickup_location_y': 262,
#    'dropoff_point_id': 60009,
#    'dropoff_from': 690,
#    'dropoff_to': 720,
#    'dropoff_location_x': 332,
#    'dropoff_location_y': 97,
#    'payment': 440},
#   10010: {'order_id': 10010,
#    'pickup_point_id': 40010,
#    'pickup_from': 420,
#    'pickup_to': 660,
#    'pickup_location_x': 114,
#    'pickup_location_y': 48,
#    'dropoff_point_id': 60010,
#    'dropoff_from': 480,
#    'dropoff_to': 960,
#    'dropoff_location_x': 293,
#    'dropoff_location_y': 70,
#    'payment': 500},
#   10011: {'order_id': 10011,
#    'pickup_point_id': 40011,
#    'pickup_from': 600,
#    'pickup_to': 840,
#    'pickup_location_x': 317,
#    'pickup_location_y': 143,
#    'dropoff_point_id': 60011,
#    'dropoff_from': 600,
#    'dropoff_to': 840,
#    'dropoff_location_x': 136,
#    'dropoff_location_y': 135,
#    'payment': 310},
#   10012: {'order_id': 10012,
#    'pickup_point_id': 40012,
#    'pickup_from': 480,
#    'pickup_to': 540,
#    'pickup_location_x': 217,
#    'pickup_location_y': 145,
#    'dropoff_point_id': 60012,
#    'dropoff_from': 480,
#    'dropoff_to': 720,
#    'dropoff_location_x': 209,
#    'dropoff_location_y': 10,
#    'payment': 372},
#   10013: {'order_id': 10013,
#    'pickup_point_id': 40013,
#    'pickup_from': 480,
#    'pickup_to': 540,
#    'pickup_location_x': 217,
#    'pickup_location_y': 145,
#    'dropoff_point_id': 60013,
#    'dropoff_from': 660,
#    'dropoff_to': 720,
#    'dropoff_location_x': 220,
#    'dropoff_location_y': 119,
#    'payment': 244},
#   10014: {'order_id': 10014,
#    'pickup_point_id': 40014,
#    'pickup_from': 480,
#    'pickup_to': 840,
#    'pickup_location_x': 161,
#    'pickup_location_y': 153,
#    'dropoff_point_id': 60014,
#    'dropoff_from': 750,
#    'dropoff_to': 930,
#    'dropoff_location_x': 167,
#    'dropoff_location_y': 155,
#    'payment': 155},
#   10015: {'order_id': 10015,
#    'pickup_point_id': 40015,
#    'pickup_from': 540,
#    'pickup_to': 570,
#    'pickup_location_x': 160,
#    'pickup_location_y': 136,
#    'dropoff_point_id': 60015,
#    'dropoff_from': 600,
#    'dropoff_to': 780,
#    'dropoff_location_x': 268,
#    'dropoff_location_y': 91,
#    'payment': 352},
#   10016: {'order_id': 10016,
#    'pickup_point_id': 40016,
#    'pickup_from': 450,
#    'pickup_to': 510,
#    'pickup_location_x': 211,
#    'pickup_location_y': 118,
#    'dropoff_point_id': 60016,
#    'dropoff_from': 510,
#    'dropoff_to': 570,
#    'dropoff_location_x': 199,
#    'dropoff_location_y': 128,
#    'payment': 284},
#   10017: {'order_id': 10017,
#    'pickup_point_id': 40017,
#    'pickup_from': 420,
#    'pickup_to': 660,
#    'pickup_location_x': 208,
#    'pickup_location_y': 284,
#    'dropoff_point_id': 60017,
#    'dropoff_from': 420,
#    'dropoff_to': 660,
#    'dropoff_location_x': 202,
#    'dropoff_location_y': 208,
#    'payment': 260},
#   10018: {'order_id': 10018,
#    'pickup_point_id': 40018,
#    'pickup_from': 420,
#    'pickup_to': 540,
#    'pickup_location_x': 222,
#    'pickup_location_y': 210,
#    'dropoff_point_id': 60018,
#    'dropoff_from': 480,
#    'dropoff_to': 720,
#    'dropoff_location_x': 120,
#    'dropoff_location_y': 232,
#    'payment': 370},
#   10019: {'order_id': 10019,
#    'pickup_point_id': 40019,
#    'pickup_from': 360,
#    'pickup_to': 420,
#    'pickup_location_x': 177,
#    'pickup_location_y': 188,
#    'dropoff_point_id': 60019,
#    'dropoff_from': 660,
#    'dropoff_to': 780,
#    'dropoff_location_x': 211,
#    'dropoff_location_y': 229,
#    'payment': 431},
#   10020: {'order_id': 10020,
#    'pickup_point_id': 40020,
#    'pickup_from': 420,
#    'pickup_to': 600,
#    'pickup_location_x': 266,
#    'pickup_location_y': 75,
#    'dropoff_point_id': 60020,
#    'dropoff_from': 420,
#    'dropoff_to': 840,
#    'dropoff_location_x': 150,
#    'dropoff_location_y': 159,
#    'payment': 291},
#   10021: {'order_id': 10021,
#    'pickup_point_id': 40021,
#    'pickup_from': 570,
#    'pickup_to': 600,
#    'pickup_location_x': 201,
#    'pickup_location_y': 143,
#    'dropoff_point_id': 60021,
#    'dropoff_from': 660,
#    'dropoff_to': 810,
#    'dropoff_location_x': 236,
#    'dropoff_location_y': 126,
#    'payment': 342},
#   10022: {'order_id': 10022,
#    'pickup_point_id': 40022,
#    'pickup_from': 540,
#    'pickup_to': 780,
#    'pickup_location_x': 343,
#    'pickup_location_y': 109,
#    'dropoff_point_id': 60022,
#    'dropoff_from': 540,
#    'dropoff_to': 780,
#    'dropoff_location_x': 273,
#    'dropoff_location_y': 113,
#    'payment': 302},
#   10023: {'order_id': 10023,
#    'pickup_point_id': 40023,
#    'pickup_from': 480,
#    'pickup_to': 720,
#    'pickup_location_x': 237,
#    'pickup_location_y': 137,
#    'dropoff_point_id': 60023,
#    'dropoff_from': 480,
#    'dropoff_to': 720,
#    'dropoff_location_x': 256,
#    'dropoff_location_y': 110,
#    'payment': 321},
#   10024: {'order_id': 10024,
#    'pickup_point_id': 40024,
#    'pickup_from': 390,
#    'pickup_to': 750,
#    'pickup_location_x': 82,
#    'pickup_location_y': 14,
#    'dropoff_point_id': 60024,
#    'dropoff_from': 720,
#    'dropoff_to': 840,
#    'dropoff_location_x': 274,
#    'dropoff_location_y': 110,
#    'payment': 513},
#   10025: {'order_id': 10025,
#    'pickup_point_id': 40025,
#    'pickup_from': 660,
#    'pickup_to': 900,
#    'pickup_location_x': 199,
#    'pickup_location_y': 149,
#    'dropoff_point_id': 60025,
#    'dropoff_from': 660,
#    'dropoff_to': 900,
#    'dropoff_location_x': 275,
#    'dropoff_location_y': 110,
#    'payment': 294},
#   10026: {'order_id': 10026,
#    'pickup_point_id': 40026,
#    'pickup_from': 300,
#    'pickup_to': 360,
#    'pickup_location_x': 138,
#    'pickup_location_y': 217,
#    'dropoff_point_id': 60026,
#    'dropoff_from': 869,
#    'dropoff_to': 420,
#    'dropoff_location_x': 227,
#    'dropoff_location_y': 150,
#    'payment': 410},
#   10027: {'order_id': 10027,
#    'pickup_point_id': 40027,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 164,
#    'pickup_location_y': 16,
#    'dropoff_point_id': 60027,
#    'dropoff_from': 480,
#    'dropoff_to': 600,
#    'dropoff_location_x': 317,
#    'dropoff_location_y': 57,
#    'payment': 468},
#   10028: {'order_id': 10028,
#    'pickup_point_id': 40028,
#    'pickup_from': 360,
#    'pickup_to': 600,
#    'pickup_location_x': 130,
#    'pickup_location_y': 131,
#    'dropoff_point_id': 60028,
#    'dropoff_from': 420,
#    'dropoff_to': 840,
#    'dropoff_location_x': 26,
#    'dropoff_location_y': 138,
#    'payment': 650},
#   10029: {'order_id': 10029,
#    'pickup_point_id': 40029,
#    'pickup_from': 390,
#    'pickup_to': 420,
#    'pickup_location_x': 172,
#    'pickup_location_y': 100,
#    'dropoff_point_id': 60029,
#    'dropoff_from': 420,
#    'dropoff_to': 480,
#    'dropoff_location_x': 280,
#    'dropoff_location_y': 256,
#    'payment': 480},
#   10030: {'order_id': 10030,
#    'pickup_point_id': 40030,
#    'pickup_from': 420,
#    'pickup_to': 450,
#    'pickup_location_x': 167,
#    'pickup_location_y': 111,
#    'dropoff_point_id': 60030,
#    'dropoff_from': 450,
#    'dropoff_to': 540,
#    'dropoff_location_x': 149,
#    'dropoff_location_y': 75,
#    'payment': 346},
#   10031: {'order_id': 10031,
#    'pickup_point_id': 40031,
#    'pickup_from': 330,
#    'pickup_to': 840,
#    'pickup_location_x': 207,
#    'pickup_location_y': 245,
#    'dropoff_point_id': 60031,
#    'dropoff_from': 960,
#    'dropoff_to': 1020,
#    'dropoff_location_x': 295,
#    'dropoff_location_y': 97,
#    'payment': 524},
#   10032: {'order_id': 10032,
#    'pickup_point_id': 40032,
#    'pickup_from': 300,
#    'pickup_to': 330,
#    'pickup_location_x': 233,
#    'pickup_location_y': 108,
#    'dropoff_point_id': 60032,
#    'dropoff_from': 360,
#    'dropoff_to': 390,
#    'dropoff_location_x': 360,
#    'dropoff_location_y': 117,
#    'payment': 413},
#   10033: {'order_id': 10033,
#    'pickup_point_id': 40033,
#    'pickup_from': 420,
#    'pickup_to': 660,
#    'pickup_location_x': 170,
#    'pickup_location_y': 131,
#    'dropoff_point_id': 60033,
#    'dropoff_from': 540,
#    'dropoff_to': 780,
#    'dropoff_location_x': 146,
#    'dropoff_location_y': 55,
#    'payment': 293},
#   10034: {'order_id': 10034,
#    'pickup_point_id': 40034,
#    'pickup_from': 510,
#    'pickup_to': 660,
#    'pickup_location_x': 136,
#    'pickup_location_y': 168,
#    'dropoff_point_id': 60034,
#    'dropoff_from': 510,
#    'dropoff_to': 810,
#    'dropoff_location_x': 229,
#    'dropoff_location_y': 77,
#    'payment': 385},
#   10035: {'order_id': 10035,
#    'pickup_point_id': 40035,
#    'pickup_from': 240,
#    'pickup_to': 270,
#    'pickup_location_x': 233,
#    'pickup_location_y': 108,
#    'dropoff_point_id': 60035,
#    'dropoff_from': 300,
#    'dropoff_to': 330,
#    'dropoff_location_x': 229,
#    'dropoff_location_y': 146,
#    'payment': 368},
#   10036: {'order_id': 10036,
#    'pickup_point_id': 40036,
#    'pickup_from': 450,
#    'pickup_to': 480,
#    'pickup_location_x': 195,
#    'pickup_location_y': 115,
#    'dropoff_point_id': 60036,
#    'dropoff_from': 540,
#    'dropoff_to': 600,
#    'dropoff_location_x': 182,
#    'dropoff_location_y': 88,
#    'payment': 242},
#   10037: {'order_id': 10037,
#    'pickup_point_id': 40037,
#    'pickup_from': 450,
#    'pickup_to': 480,
#    'pickup_location_x': 268,
#    'pickup_location_y': 185,
#    'dropoff_point_id': 60037,
#    'dropoff_from': 480,
#    'dropoff_to': 720,
#    'dropoff_location_x': 218,
#    'dropoff_location_y': 121,
#    'payment': 317},
#   10038: {'order_id': 10038,
#    'pickup_point_id': 40038,
#    'pickup_from': 570,
#    'pickup_to': 600,
#    'pickup_location_x': 201,
#    'pickup_location_y': 143,
#    'dropoff_point_id': 60038,
#    'dropoff_from': 660,
#    'dropoff_to': 810,
#    'dropoff_location_x': 236,
#    'dropoff_location_y': 126,
#    'payment': 342},
#   10039: {'order_id': 10039,
#    'pickup_point_id': 40039,
#    'pickup_from': 420,
#    'pickup_to': 960,
#    'pickup_location_x': 173,
#    'pickup_location_y': 171,
#    'dropoff_point_id': 60039,
#    'dropoff_from': 480,
#    'dropoff_to': 960,
#    'dropoff_location_x': 140,
#    'dropoff_location_y': 102,
#    'payment': 287},
#   10040: {'order_id': 10040,
#    'pickup_point_id': 40040,
#    'pickup_from': 360,
#    'pickup_to': 480,
#    'pickup_location_x': 108,
#    'pickup_location_y': 54,
#    'dropoff_point_id': 60040,
#    'dropoff_from': 390,
#    'dropoff_to': 510,
#    'dropoff_location_x': 187,
#    'dropoff_location_y': 141,
#    'payment': 408},
#   10041: {'order_id': 10041,
#    'pickup_point_id': 40041,
#    'pickup_from': 360,
#    'pickup_to': 420,
#    'pickup_location_x': 243,
#    'pickup_location_y': 171,
#    'dropoff_point_id': 60041,
#    'dropoff_from': 420,
#    'dropoff_to': 480,
#    'dropoff_location_x': 331,
#    'dropoff_location_y': 96,
#    'payment': 376},
#   10042: {'order_id': 10042,
#    'pickup_point_id': 40042,
#    'pickup_from': 390,
#    'pickup_to': 720,
#    'pickup_location_x': 195,
#    'pickup_location_y': 115,
#    'dropoff_point_id': 60042,
#    'dropoff_from': 780,
#    'dropoff_to': 900,
#    'dropoff_location_x': 307,
#    'dropoff_location_y': 72,
#    'payment': 348},
#   10043: {'order_id': 10043,
#    'pickup_point_id': 40043,
#    'pickup_from': 330,
#    'pickup_to': 570,
#    'pickup_location_x': 247,
#    'pickup_location_y': 124,
#    'dropoff_point_id': 60043,
#    'dropoff_from': 600,
#    'dropoff_to': 840,
#    'dropoff_location_x': 308,
#    'dropoff_location_y': 27,
#    'payment': 309},
#   10044: {'order_id': 10044,
#    'pickup_point_id': 40044,
#    'pickup_from': 360,
#    'pickup_to': 390,
#    'pickup_location_x': 184,
#    'pickup_location_y': 10,
#    'dropoff_point_id': 60044,
#    'dropoff_from': 360,
#    'dropoff_to': 540,
#    'dropoff_location_x': 351,
#    'dropoff_location_y': 23,
#    'payment': 374},
#   10045: {'order_id': 10045,
#    'pickup_point_id': 40045,
#    'pickup_from': 420,
#    'pickup_to': 720,
#    'pickup_location_x': 223,
#    'pickup_location_y': 143,
#    'dropoff_point_id': 60045,
#    'dropoff_from': 420,
#    'dropoff_to': 900,
#    'dropoff_location_x': 242,
#    'dropoff_location_y': 119,
#    'payment': 242},
#   10046: {'order_id': 10046,
#    'pickup_point_id': 40046,
#    'pickup_from': 450,
#    'pickup_to': 690,
#    'pickup_location_x': 223,
#    'pickup_location_y': 160,
#    'dropoff_point_id': 60046,
#    'dropoff_from': 660,
#    'dropoff_to': 900,
#    'dropoff_location_x': 155,
#    'dropoff_location_y': 136,
#    'payment': 238},
#   10047: {'order_id': 10047,
#    'pickup_point_id': 40047,
#    'pickup_from': 390,
#    'pickup_to': 450,
#    'pickup_location_x': 206,
#    'pickup_location_y': 246,
#    'dropoff_point_id': 60047,
#    'dropoff_from': 540,
#    'dropoff_to': 570,
#    'dropoff_location_x': 241,
#    'dropoff_location_y': 134,
#    'payment': 426},
#   10048: {'order_id': 10048,
#    'pickup_point_id': 40048,
#    'pickup_from': 420,
#    'pickup_to': 810,
#    'pickup_location_x': 180,
#    'pickup_location_y': 129,
#    'dropoff_point_id': 60048,
#    'dropoff_from': 420,
#    'dropoff_to': 840,
#    'dropoff_location_x': 207,
#    'dropoff_location_y': 80,
#    'payment': 224},
#   10049: {'order_id': 10049,
#    'pickup_point_id': 40049,
#    'pickup_from': 420,
#    'pickup_to': 600,
#    'pickup_location_x': 229,
#    'pickup_location_y': 126,
#    'dropoff_point_id': 60049,
#    'dropoff_from': 420,
#    'dropoff_to': 720,
#    'dropoff_location_x': 187,
#    'dropoff_location_y': 141,
#    'payment': 287},
#   10050: {'order_id': 10050,
#    'pickup_point_id': 40050,
#    'pickup_from': 630,
#    'pickup_to': 660,
#    'pickup_location_x': 225,
#    'pickup_location_y': 141,
#    'dropoff_point_id': 60050,
#    'dropoff_from': 690,
#    'dropoff_to': 720,
#    'dropoff_location_x': 234,
#    'dropoff_location_y': 192,
#    'payment': 380},
#   10051: {'order_id': 10051,
#    'pickup_point_id': 40051,
#    'pickup_from': 390,
#    'pickup_to': 510,
#    'pickup_location_x': 305,
#    'pickup_location_y': 1,
#    'dropoff_point_id': 60051,
#    'dropoff_from': 390,
#    'dropoff_to': 690,
#    'dropoff_location_x': 164,
#    'dropoff_location_y': 120,
#    'payment': 547},
#   10052: {'order_id': 10052,
#    'pickup_point_id': 40052,
#    'pickup_from': 480,
#    'pickup_to': 540,
#    'pickup_location_x': 320,
#    'pickup_location_y': 60,
#    'dropoff_point_id': 60052,
#    'dropoff_from': 660,
#    'dropoff_to': 720,
#    'dropoff_location_x': 190,
#    'dropoff_location_y': 205,
#    'payment': 510},
#   10053: {'order_id': 10053,
#    'pickup_point_id': 40053,
#    'pickup_from': 360,
#    'pickup_to': 390,
#    'pickup_location_x': 225,
#    'pickup_location_y': 141,
#    'dropoff_point_id': 60053,
#    'dropoff_from': 420,
#    'dropoff_to': 450,
#    'dropoff_location_x': 207,
#    'dropoff_location_y': 80,
#    'payment': 380},
#   10054: {'order_id': 10054,
#    'pickup_point_id': 40054,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 229,
#    'pickup_location_y': 77,
#    'dropoff_point_id': 60054,
#    'dropoff_from': 480,
#    'dropoff_to': 540,
#    'dropoff_location_x': 172,
#    'dropoff_location_y': 241,
#    'payment': 381},
#   10055: {'order_id': 10055,
#    'pickup_point_id': 40055,
#    'pickup_from': 420,
#    'pickup_to': 600,
#    'pickup_location_x': 141,
#    'pickup_location_y': 19,
#    'dropoff_point_id': 60055,
#    'dropoff_from': 600,
#    'dropoff_to': 1140,
#    'dropoff_location_x': 274,
#    'dropoff_location_y': 222,
#    'payment': 520},
#   10056: {'order_id': 10056,
#    'pickup_point_id': 40056,
#    'pickup_from': 390,
#    'pickup_to': 450,
#    'pickup_location_x': 49,
#    'pickup_location_y': 59,
#    'dropoff_point_id': 60056,
#    'dropoff_from': 540,
#    'dropoff_to': 600,
#    'dropoff_location_x': 259,
#    'dropoff_location_y': 74,
#    'payment': 545},
#   10057: {'order_id': 10057,
#    'pickup_point_id': 40057,
#    'pickup_from': 540,
#    'pickup_to': 840,
#    'pickup_location_x': 188,
#    'pickup_location_y': 136,
#    'dropoff_point_id': 60057,
#    'dropoff_from': 540,
#    'dropoff_to': 840,
#    'dropoff_location_x': 231,
#    'dropoff_location_y': 120,
#    'payment': 188},
#   10058: {'order_id': 10058,
#    'pickup_point_id': 40058,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 246,
#    'pickup_location_y': 63,
#    'dropoff_point_id': 60058,
#    'dropoff_from': 540,
#    'dropoff_to': 720,
#    'dropoff_location_x': 44,
#    'dropoff_location_y': 119,
#    'payment': 448},
#   10059: {'order_id': 10059,
#    'pickup_point_id': 40059,
#    'pickup_from': 450,
#    'pickup_to': 510,
#    'pickup_location_x': 171,
#    'pickup_location_y': 177,
#    'dropoff_point_id': 60059,
#    'dropoff_from': 480,
#    'dropoff_to': 540,
#    'dropoff_location_x': 207,
#    'dropoff_location_y': 162,
#    'payment': 403},
#   10060: {'order_id': 10060,
#    'pickup_point_id': 40060,
#    'pickup_from': 420,
#    'pickup_to': 720,
#    'pickup_location_x': 186,
#    'pickup_location_y': 125,
#    'dropoff_point_id': 60060,
#    'dropoff_from': 420,
#    'dropoff_to': 870,
#    'dropoff_location_x': 262,
#    'dropoff_location_y': 4,
#    'payment': 353},
#   10061: {'order_id': 10061,
#    'pickup_point_id': 40061,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 234,
#    'pickup_location_y': 137,
#    'dropoff_point_id': 60061,
#    'dropoff_from': 450,
#    'dropoff_to': 810,
#    'dropoff_location_x': 180,
#    'dropoff_location_y': 143,
#    'payment': 354},
#   10062: {'order_id': 10062,
#    'pickup_point_id': 40062,
#    'pickup_from': 390,
#    'pickup_to': 630,
#    'pickup_location_x': 127,
#    'pickup_location_y': 16,
#    'dropoff_point_id': 60062,
#    'dropoff_from': 480,
#    'dropoff_to': 720,
#    'dropoff_location_x': 268,
#    'dropoff_location_y': 109,
#    'payment': 483},
#   10063: {'order_id': 10063,
#    'pickup_point_id': 40063,
#    'pickup_from': 510,
#    'pickup_to': 570,
#    'pickup_location_x': 243,
#    'pickup_location_y': 178,
#    'dropoff_point_id': 60063,
#    'dropoff_from': 570,
#    'dropoff_to': 660,
#    'dropoff_location_x': 236,
#    'dropoff_location_y': 150,
#    'payment': 262},
#   10064: {'order_id': 10064,
#    'pickup_point_id': 40064,
#    'pickup_from': 420,
#    'pickup_to': 450,
#    'pickup_location_x': 185,
#    'pickup_location_y': 144,
#    'dropoff_point_id': 60064,
#    'dropoff_from': 420,
#    'dropoff_to': 510,
#    'dropoff_location_x': 214,
#    'dropoff_location_y': 85,
#    'payment': 363},
#   10065: {'order_id': 10065,
#    'pickup_point_id': 40065,
#    'pickup_from': 300,
#    'pickup_to': 540,
#    'pickup_location_x': 315,
#    'pickup_location_y': 108,
#    'dropoff_point_id': 60065,
#    'dropoff_from': 300,
#    'dropoff_to': 780,
#    'dropoff_location_x': 289,
#    'dropoff_location_y': 116,
#    'payment': 181},
#   10066: {'order_id': 10066,
#    'pickup_point_id': 40066,
#    'pickup_from': 510,
#    'pickup_to': 750,
#    'pickup_location_x': 274,
#    'pickup_location_y': 112,
#    'dropoff_point_id': 60066,
#    'dropoff_from': 660,
#    'dropoff_to': 900,
#    'dropoff_location_x': 275,
#    'dropoff_location_y': 139,
#    'payment': 271},
#   10067: {'order_id': 10067,
#    'pickup_point_id': 40067,
#    'pickup_from': 450,
#    'pickup_to': 510,
#    'pickup_location_x': 171,
#    'pickup_location_y': 177,
#    'dropoff_point_id': 60067,
#    'dropoff_from': 480,
#    'dropoff_to': 540,
#    'dropoff_location_x': 207,
#    'dropoff_location_y': 162,
#    'payment': 403},
#   10068: {'order_id': 10068,
#    'pickup_point_id': 40068,
#    'pickup_from': 450,
#    'pickup_to': 480,
#    'pickup_location_x': 325,
#    'pickup_location_y': 122,
#    'dropoff_point_id': 60068,
#    'dropoff_from': 510,
#    'dropoff_to': 570,
#    'dropoff_location_x': 262,
#    'dropoff_location_y': 45,
#    'payment': 343},
#   10069: {'order_id': 10069,
#    'pickup_point_id': 40069,
#    'pickup_from': 420,
#    'pickup_to': 960,
#    'pickup_location_x': 16,
#    'pickup_location_y': 98,
#    'dropoff_point_id': 60069,
#    'dropoff_from': 960,
#    'dropoff_to': 1050,
#    'dropoff_location_x': 127,
#    'dropoff_location_y': 96,
#    'payment': 400},
#   10070: {'order_id': 10070,
#    'pickup_point_id': 40070,
#    'pickup_from': 450,
#    'pickup_to': 780,
#    'pickup_location_x': 201,
#    'pickup_location_y': 105,
#    'dropoff_point_id': 60070,
#    'dropoff_from': 480,
#    'dropoff_to': 900,
#    'dropoff_location_x': 195,
#    'dropoff_location_y': 146,
#    'payment': 225},
#   10071: {'order_id': 10071,
#    'pickup_point_id': 40071,
#    'pickup_from': 450,
#    'pickup_to': 600,
#    'pickup_location_x': 122,
#    'pickup_location_y': 210,
#    'dropoff_point_id': 60071,
#    'dropoff_from': 480,
#    'dropoff_to': 840,
#    'dropoff_location_x': 344,
#    'dropoff_location_y': 148,
#    'payment': 553},
#   10072: {'order_id': 10072,
#    'pickup_point_id': 40072,
#    'pickup_from': 390,
#    'pickup_to': 480,
#    'pickup_location_x': 298,
#    'pickup_location_y': 19,
#    'dropoff_point_id': 60072,
#    'dropoff_from': 420,
#    'dropoff_to': 660,
#    'dropoff_location_x': 231,
#    'dropoff_location_y': 103,
#    'payment': 318},
#   10073: {'order_id': 10073,
#    'pickup_point_id': 40073,
#    'pickup_from': 360,
#    'pickup_to': 600,
#    'pickup_location_x': 249,
#    'pickup_location_y': 94,
#    'dropoff_point_id': 60073,
#    'dropoff_from': 360,
#    'dropoff_to': 840,
#    'dropoff_location_x': 176,
#    'dropoff_location_y': 168,
#    'payment': 231},
#   10074: {'order_id': 10074,
#    'pickup_point_id': 40074,
#    'pickup_from': 510,
#    'pickup_to': 540,
#    'pickup_location_x': 210,
#    'pickup_location_y': 218,
#    'dropoff_point_id': 60074,
#    'dropoff_from': 540,
#    'dropoff_to': 720,
#    'dropoff_location_x': 295,
#    'dropoff_location_y': 214,
#    'payment': 352},
#   10075: {'order_id': 10075,
#    'pickup_point_id': 40075,
#    'pickup_from': 360,
#    'pickup_to': 420,
#    'pickup_location_x': 82,
#    'pickup_location_y': 22,
#    'dropoff_point_id': 60075,
#    'dropoff_from': 480,
#    'dropoff_to': 540,
#    'dropoff_location_x': 238,
#    'dropoff_location_y': 125,
#    'payment': 376},
#   10076: {'order_id': 10076,
#    'pickup_point_id': 40076,
#    'pickup_from': 420,
#    'pickup_to': 450,
#    'pickup_location_x': 253,
#    'pickup_location_y': 164,
#    'dropoff_point_id': 60076,
#    'dropoff_from': 450,
#    'dropoff_to': 600,
#    'dropoff_location_x': 332,
#    'dropoff_location_y': 144,
#    'payment': 552},
#   10077: {'order_id': 10077,
#    'pickup_point_id': 40077,
#    'pickup_from': 330,
#    'pickup_to': 390,
#    'pickup_location_x': 26,
#    'pickup_location_y': 152,
#    'dropoff_point_id': 60077,
#    'dropoff_from': 450,
#    'dropoff_to': 570,
#    'dropoff_location_x': 272,
#    'dropoff_location_y': 38,
#    'payment': 519},
#   10078: {'order_id': 10078,
#    'pickup_point_id': 40078,
#    'pickup_from': 450,
#    'pickup_to': 690,
#    'pickup_location_x': 245,
#    'pickup_location_y': 141,
#    'dropoff_point_id': 60078,
#    'dropoff_from': 450,
#    'dropoff_to': 690,
#    'dropoff_location_x': 251,
#    'dropoff_location_y': 110,
#    'payment': 187},
#   10079: {'order_id': 10079,
#    'pickup_point_id': 40079,
#    'pickup_from': 480,
#    'pickup_to': 510,
#    'pickup_location_x': 156,
#    'pickup_location_y': 178,
#    'dropoff_point_id': 60079,
#    'dropoff_from': 600,
#    'dropoff_to': 630,
#    'dropoff_location_x': 98,
#    'dropoff_location_y': 58,
#    'payment': 661},
#   10080: {'order_id': 10080,
#    'pickup_point_id': 40080,
#    'pickup_from': 420,
#    'pickup_to': 540,
#    'pickup_location_x': 144,
#    'pickup_location_y': 76,
#    'dropoff_point_id': 60080,
#    'dropoff_from': 420,
#    'dropoff_to': 600,
#    'dropoff_location_x': 257,
#    'dropoff_location_y': 165,
#    'payment': 347},
#   10081: {'order_id': 10081,
#    'pickup_point_id': 40081,
#    'pickup_from': 480,
#    'pickup_to': 540,
#    'pickup_location_x': 328,
#    'pickup_location_y': 111,
#    'dropoff_point_id': 60081,
#    'dropoff_from': 480,
#    'dropoff_to': 720,
#    'dropoff_location_x': 207,
#    'dropoff_location_y': 195,
#    'payment': 447},
#   10082: {'order_id': 10082,
#    'pickup_point_id': 40082,
#    'pickup_from': 420,
#    'pickup_to': 1050,
#    'pickup_location_x': 332,
#    'pickup_location_y': 40,
#    'dropoff_point_id': 60082,
#    'dropoff_from': 960,
#    'dropoff_to': 1200,
#    'dropoff_location_x': 310,
#    'dropoff_location_y': 30,
#    'payment': 333},
#   10083: {'order_id': 10083,
#    'pickup_point_id': 40083,
#    'pickup_from': 540,
#    'pickup_to': 660,
#    'pickup_location_x': 163,
#    'pickup_location_y': 117,
#    'dropoff_point_id': 60083,
#    'dropoff_from': 540,
#    'dropoff_to': 780,
#    'dropoff_location_x': 319,
#    'dropoff_location_y': 154,
#    'payment': 470},
#   10084: {'order_id': 10084,
#    'pickup_point_id': 40084,
#    'pickup_from': 420,
#    'pickup_to': 660,
#    'pickup_location_x': 215,
#    'pickup_location_y': 107,
#    'dropoff_point_id': 60084,
#    'dropoff_from': 480,
#    'dropoff_to': 720,
#    'dropoff_location_x': 261,
#    'dropoff_location_y': 100,
#    'payment': 331},
#   10085: {'order_id': 10085,
#    'pickup_point_id': 40085,
#    'pickup_from': 480,
#    'pickup_to': 600,
#    'pickup_location_x': 5,
#    'pickup_location_y': 109,
#    'dropoff_point_id': 60085,
#    'dropoff_from': 570,
#    'dropoff_to': 720,
#    'dropoff_location_x': 346,
#    'dropoff_location_y': 151,
#    'payment': 540},
#   10086: {'order_id': 10086,
#    'pickup_point_id': 40086,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 216,
#    'pickup_location_y': 218,
#    'dropoff_point_id': 60086,
#    'dropoff_from': 510,
#    'dropoff_to': 600,
#    'dropoff_location_x': 277,
#    'dropoff_location_y': 137,
#    'payment': 376},
#   10087: {'order_id': 10087,
#    'pickup_point_id': 40087,
#    'pickup_from': 420,
#    'pickup_to': 660,
#    'pickup_location_x': 230,
#    'pickup_location_y': 110,
#    'dropoff_point_id': 60087,
#    'dropoff_from': 600,
#    'dropoff_to': 840,
#    'dropoff_location_x': 297,
#    'dropoff_location_y': 13,
#    'payment': 329},
#   10088: {'order_id': 10088,
#    'pickup_point_id': 40088,
#    'pickup_from': 390,
#    'pickup_to': 840,
#    'pickup_location_x': 286,
#    'pickup_location_y': 130,
#    'dropoff_point_id': 60088,
#    'dropoff_from': 390,
#    'dropoff_to': 900,
#    'dropoff_location_x': 220,
#    'dropoff_location_y': 139,
#    'payment': 210},
#   10089: {'order_id': 10089,
#    'pickup_point_id': 40089,
#    'pickup_from': 330,
#    'pickup_to': 360,
#    'pickup_location_x': 225,
#    'pickup_location_y': 141,
#    'dropoff_point_id': 60089,
#    'dropoff_from': 390,
#    'dropoff_to': 420,
#    'dropoff_location_x': 188,
#    'dropoff_location_y': 147,
#    'payment': 380},
#   10090: {'order_id': 10090,
#    'pickup_point_id': 40090,
#    'pickup_from': 360,
#    'pickup_to': 480,
#    'pickup_location_x': 338,
#    'pickup_location_y': 168,
#    'dropoff_point_id': 60090,
#    'dropoff_from': 480,
#    'dropoff_to': 780,
#    'dropoff_location_x': 334,
#    'dropoff_location_y': 46,
#    'payment': 501},
#   10091: {'order_id': 10091,
#    'pickup_point_id': 40091,
#    'pickup_from': 420,
#    'pickup_to': 540,
#    'pickup_location_x': 209,
#    'pickup_location_y': 166,
#    'dropoff_point_id': 60091,
#    'dropoff_from': 540,
#    'dropoff_to': 720,
#    'dropoff_location_x': 96,
#    'dropoff_location_y': 143,
#    'payment': 388},
#   10092: {'order_id': 10092,
#    'pickup_point_id': 40092,
#    'pickup_from': 450,
#    'pickup_to': 570,
#    'pickup_location_x': 250,
#    'pickup_location_y': 185,
#    'dropoff_point_id': 60092,
#    'dropoff_from': 570,
#    'dropoff_to': 720,
#    'dropoff_location_x': 96,
#    'dropoff_location_y': 143,
#    'payment': 418},
#   10093: {'order_id': 10093,
#    'pickup_point_id': 40093,
#    'pickup_from': 420,
#    'pickup_to': 540,
#    'pickup_location_x': 271,
#    'pickup_location_y': 216,
#    'dropoff_point_id': 60093,
#    'dropoff_from': 540,
#    'dropoff_to': 720,
#    'dropoff_location_x': 214,
#    'dropoff_location_y': 164,
#    'payment': 363},
#   10094: {'order_id': 10094,
#    'pickup_point_id': 40094,
#    'pickup_from': 390,
#    'pickup_to': 450,
#    'pickup_location_x': 239,
#    'pickup_location_y': 138,
#    'dropoff_point_id': 60094,
#    'dropoff_from': 420,
#    'dropoff_to': 510,
#    'dropoff_location_x': 262,
#    'dropoff_location_y': 193,
#    'payment': 247},
#   10095: {'order_id': 10095,
#    'pickup_point_id': 40095,
#    'pickup_from': 540,
#    'pickup_to': 780,
#    'pickup_location_x': 161,
#    'pickup_location_y': 177,
#    'dropoff_point_id': 60095,
#    'dropoff_from': 600,
#    'dropoff_to': 840,
#    'dropoff_location_x': 127,
#    'dropoff_location_y': 131,
#    'payment': 338},
#   10096: {'order_id': 10096,
#    'pickup_point_id': 40096,
#    'pickup_from': 390,
#    'pickup_to': 450,
#    'pickup_location_x': 100,
#    'pickup_location_y': 143,
#    'dropoff_point_id': 60096,
#    'dropoff_from': 390,
#    'dropoff_to': 720,
#    'dropoff_location_x': 133,
#    'dropoff_location_y': 135,
#    'payment': 303},
#   10097: {'order_id': 10097,
#    'pickup_point_id': 40097,
#    'pickup_from': 420,
#    'pickup_to': 660,
#    'pickup_location_x': 201,
#    'pickup_location_y': 180,
#    'dropoff_point_id': 60097,
#    'dropoff_from': 450,
#    'dropoff_to': 780,
#    'dropoff_location_x': 233,
#    'dropoff_location_y': 144,
#    'payment': 219},
#   10098: {'order_id': 10098,
#    'pickup_point_id': 40098,
#    'pickup_from': 630,
#    'pickup_to': 660,
#    'pickup_location_x': 256,
#    'pickup_location_y': 85,
#    'dropoff_point_id': 60098,
#    'dropoff_from': 720,
#    'dropoff_to': 780,
#    'dropoff_location_x': 214,
#    'dropoff_location_y': 254,
#    'payment': 528},
#   10099: {'order_id': 10099,
#    'pickup_point_id': 40099,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 221,
#    'pickup_location_y': 149,
#    'dropoff_point_id': 60099,
#    'dropoff_from': 480,
#    'dropoff_to': 540,
#    'dropoff_location_x': 232,
#    'dropoff_location_y': 152,
#    'payment': 403},
#   10100: {'order_id': 10100,
#    'pickup_point_id': 40100,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 221,
#    'pickup_location_y': 149,
#    'dropoff_point_id': 60100,
#    'dropoff_from': 480,
#    'dropoff_to': 540,
#    'dropoff_location_x': 322,
#    'dropoff_location_y': 70,
#    'payment': 403},
#   10101: {'order_id': 10101,
#    'pickup_point_id': 40101,
#    'pickup_from': 420,
#    'pickup_to': 960,
#    'pickup_location_x': 281,
#    'pickup_location_y': 152,
#    'dropoff_point_id': 60101,
#    'dropoff_from': 1020,
#    'dropoff_to': 1080,
#    'dropoff_location_x': 267,
#    'dropoff_location_y': 192,
#    'payment': 376},
#   10102: {'order_id': 10102,
#    'pickup_point_id': 40102,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 221,
#    'pickup_location_y': 149,
#    'dropoff_point_id': 60102,
#    'dropoff_from': 480,
#    'dropoff_to': 540,
#    'dropoff_location_x': 131,
#    'dropoff_location_y': 137,
#    'payment': 403},
#   10103: {'order_id': 10103,
#    'pickup_point_id': 40103,
#    'pickup_from': 420,
#    'pickup_to': 510,
#    'pickup_location_x': 110,
#    'pickup_location_y': 279,
#    'dropoff_point_id': 60103,
#    'dropoff_from': 540,
#    'dropoff_to': 840,
#    'dropoff_location_x': 211,
#    'dropoff_location_y': 200,
#    'payment': 619},
#   10104: {'order_id': 10104,
#    'pickup_point_id': 40104,
#    'pickup_from': 600,
#    'pickup_to': 660,
#    'pickup_location_x': 243,
#    'pickup_location_y': 176,
#    'dropoff_point_id': 60104,
#    'dropoff_from': 720,
#    'dropoff_to': 900,
#    'dropoff_location_x': 196,
#    'dropoff_location_y': 5,
#    'payment': 560},
#   10105: {'order_id': 10105,
#    'pickup_point_id': 40105,
#    'pickup_from': 360,
#    'pickup_to': 600,
#    'pickup_location_x': 170,
#    'pickup_location_y': 11,
#    'dropoff_point_id': 60105,
#    'dropoff_from': 540,
#    'dropoff_to': 780,
#    'dropoff_location_x': 167,
#    'dropoff_location_y': 18,
#    'payment': 183},
#   10106: {'order_id': 10106,
#    'pickup_point_id': 40106,
#    'pickup_from': 360,
#    'pickup_to': 720,
#    'pickup_location_x': 218,
#    'pickup_location_y': 168,
#    'dropoff_point_id': 60106,
#    'dropoff_from': 360,
#    'dropoff_to': 900,
#    'dropoff_location_x': 193,
#    'dropoff_location_y': 113,
#    'payment': 452},
#   10107: {'order_id': 10107,
#    'pickup_point_id': 40107,
#    'pickup_from': 420,
#    'pickup_to': 480,
#    'pickup_location_x': 179,
#    'pickup_location_y': 128,
#    'dropoff_point_id': 60107,
#    'dropoff_from': 450,
#    'dropoff_to': 540,
#    'dropoff_location_x': 137,
#    'dropoff_location_y': 135,
#    'payment': 231},
#   10108: {'order_id': 10108,
#    'pickup_point_id': 40108,
#    'pickup_from': 360,
#    'pickup_to': 720,
#    'pickup_location_x': 218,
#    'pickup_location_y': 168,
#    'dropoff_point_id': 60108,
#    'dropoff_from': 360,
#    'dropoff_to': 900,
#    'dropoff_location_x': 193,
#    'dropoff_location_y': 113,
#    'payment': 452},
#   10109: {'order_id': 10109,
#    'pickup_point_id': 40109,
#    'pickup_from': 270,
#    'pickup_to': 300,
#    'pickup_location_x': 233,
#    'pickup_location_y': 108,
#    'dropoff_point_id': 60109,
#    'dropoff_from': 330,
#    'dropoff_to': 360,
#    'dropoff_location_x': 186,
#    'dropoff_location_y': 152,
#    'payment': 316},
#   10110: {'order_id': 10110,
#    'pickup_point_id': 40110,
# ...
#   40392: {'location': [233, 138],
#    'timewindow': [450, 510],
#    'order_time': {10392: 450}},
#   60392: {'location': [218, 97], 'timewindow': [480, 600]},
#   40393: {'location': [233, 138],
#    'timewindow': [480, 540],
#    'order_time': {10393: 480}},
#   60393: {'location': [225, 96], 'timewindow': [510, 660]},
#   40394: {'location': [203, 6],
#    'timewindow': [510, 540],
#    'order_time': {10394: 510}},
#   60394: {'location': [120, 131], 'timewindow': [570, 600]},
#   40395: {'location': [272, 116],
#    'timewindow': [450, 480],
#    'order_time': {10395: 450}},
#   60395: {'location': [247, 65], 'timewindow': [480, 540]},
#   40396: {'location': [137, 88],
#    'timewindow': [420, 1080],
#    'order_time': {10396: 420}},
#   60396: {'location': [109, 121], 'timewindow': [1020, 1200]},
#   40397: {'location': [262, 110],
#    'timewindow': [450, 540],
#    'order_time': {10397: 450}},
#   60397: {'location': [21, 148], 'timewindow': [540, 720]},
#   40398: {'location': [233, 138],
#    'timewindow': [480, 540],
#    'order_time': {10398: 480}},
#   60398: {'location': [195, 177], 'timewindow': [540, 660]},
#   40399: {'location': [187, 13],
#    'timewindow': [540, 600],
#    'order_time': {10399: 540}},
#   60399: {'location': [183, 102], 'timewindow': [690, 720]},
#   40400: {'location': [30, 163],
#    'timewindow': [420, 660],
#    'order_time': {10400: 420}},
#   60400: {'location': [24, 169], 'timewindow': [480, 660]},
#   40401: {'location': [226, 14],
#    'timewindow': [360, 390],
#    'order_time': {10401: 360}},
#   60401: {'location': [201, 151], 'timewindow': [360, 480]},
#   40402: {'location': [72, 167],
#    'timewindow': [420, 450],
#    'order_time': {10402: 420}},
#   60402: {'location': [288, 58], 'timewindow': [420, 540]},
#   40403: {'location': [197, 102],
#    'timewindow': [360, 540],
#    'order_time': {10403: 360}},
#   60403: {'location': [147, 82], 'timewindow': [600, 900]},
#   40404: {'location': [222, 0],
#    'timewindow': [420, 780],
#    'order_time': {10404: 420}},
#   60404: {'location': [202, 5], 'timewindow': [660, 960]},
#   40405: {'location': [72, 167],
#    'timewindow': [420, 450],
#    'order_time': {10405: 420}},
#   60405: {'location': [260, 115], 'timewindow': [420, 660]},
#   40406: {'location': [203, 73],
#    'timewindow': [330, 1080],
#    'order_time': {10406: 330}},
#   60406: {'location': [145, 91], 'timewindow': [1080, 1140]},
#   40407: {'location': [72, 167],
#    'timewindow': [420, 450],
#    'order_time': {10407: 420}},
#   60407: {'location': [203, 196], 'timewindow': [420, 600]},
#   40408: {'location': [251, 47],
#    'timewindow': [450, 660],
#    'order_time': {10408: 450}},
#   60408: {'location': [156, 75], 'timewindow': [540, 900]},
#   40409: {'location': [214, 161],
#    'timewindow': [450, 480],
#    'order_time': {10409: 450}},
#   60409: {'location': [188, 147], 'timewindow': [480, 540]},
#   40410: {'location': [274, 110],
#    'timewindow': [360, 390],
#    'order_time': {10410: 360}},
#   60410: {'location': [231, 134], 'timewindow': [390, 420]},
#   40411: {'location': [165, 133],
#    'timewindow': [420, 660],
#    'order_time': {10411: 420}},
#   60411: {'location': [182, 133], 'timewindow': [480, 660]},
#   40412: {'location': [312, 154],
#    'timewindow': [300, 360],
#    'order_time': {10412: 300}},
#   60412: {'location': [149, 135], 'timewindow': [420, 480]},
#   40413: {'location': [312, 154],
#    'timewindow': [360, 420],
#    'order_time': {10413: 360}},
#   60413: {'location': [274, 143], 'timewindow': [420, 480]},
#   40414: {'location': [115, 45],
#    'timewindow': [390, 1140],
#    'order_time': {10414: 390}},
#   60414: {'location': [136, 29], 'timewindow': [1020, 1200]},
#   40415: {'location': [112, 92],
#    'timewindow': [540, 660],
#    'order_time': {10415: 540}},
#   60415: {'location': [245, 120], 'timewindow': [540, 780]},
#   40416: {'location': [115, 45],
#    'timewindow': [420, 600],
#    'order_time': {10416: 420}},
#   60416: {'location': [116, 28], 'timewindow': [600, 780]},
#   40417: {'location': [210, 108],
#    'timewindow': [420, 660],
#    'order_time': {10417: 420}},
#   60417: {'location': [72, 162], 'timewindow': [420, 660]},
#   40418: {'location': [204, 96],
#    'timewindow': [420, 660],
#    'order_time': {10418: 420}},
#   60418: {'location': [193, 112], 'timewindow': [480, 660]},
#   40419: {'location': [132, 64],
#    'timewindow': [420, 480],
#    'order_time': {10419: 420}},
#   60419: {'location': [159, 67], 'timewindow': [570, 780]},
#   40420: {'location': [340, 185],
#    'timewindow': [630, 720],
#    'order_time': {10420: 630}},
#   60420: {'location': [222, 138], 'timewindow': [720, 870]},
#   40421: {'location': [127, 282],
#    'timewindow': [390, 450],
#    'order_time': {10421: 390}},
#   60421: {'location': [274, 60], 'timewindow': [480, 660]},
#   40422: {'location': [274, 110],
#    'timewindow': [480, 540],
#    'order_time': {10422: 480}},
#   60422: {'location': [72, 49], 'timewindow': [540, 660]},
#   40423: {'location': [157, 8],
#    'timewindow': [420, 900],
#    'order_time': {10423: 420}},
#   60423: {'location': [28, 162], 'timewindow': [960, 1140]},
#   40424: {'location': [189, 206],
#    'timewindow': [420, 570],
#    'order_time': {10424: 420}},
#   60424: {'location': [133, 146], 'timewindow': [570, 720]},
#   40425: {'location': [233, 138],
#    'timewindow': [480, 540],
#    'order_time': {10425: 480}},
#   60425: {'location': [169, 190], 'timewindow': [540, 660]},
#   40426: {'location': [278, 65],
#    'timewindow': [450, 480],
#    'order_time': {10426: 450}},
#   60426: {'location': [201, 208], 'timewindow': [480, 540]},
#   40427: {'location': [384, 83],
#    'timewindow': [420, 450],
#    'order_time': {10427: 420}},
#   60427: {'location': [259, 165], 'timewindow': [450, 540]},
#   40428: {'location': [200, 154],
#    'timewindow': [420, 540],
#    'order_time': {10428: 420}},
#   60428: {'location': [260, 85], 'timewindow': [420, 660]},
#   40429: {'location': [217, 232],
#    'timewindow': [300, 720],
#    'order_time': {10429: 300}},
#   60429: {'location': [210, 112], 'timewindow': [720, 810]},
#   40430: {'location': [114, 82],
#    'timewindow': [660, 810],
#    'order_time': {10430: 660}},
#   60430: {'location': [136, 133], 'timewindow': [870, 900]},
#   40431: {'location': [240, 157],
#    'timewindow': [360, 660],
#    'order_time': {10431: 360}},
#   60431: {'location': [230, 159], 'timewindow': [480, 660]},
#   40432: {'location': [126, 227],
#    'timewindow': [240, 270],
#    'order_time': {10432: 240}},
#   60432: {'location': [241, 198], 'timewindow': [270, 360]},
#   40433: {'location': [243, 190],
#    'timewindow': [540, 780],
#    'order_time': {10433: 540}},
#   60433: {'location': [94, 214], 'timewindow': [660, 1080]},
#   40434: {'location': [184, 143],
#    'timewindow': [360, 390],
#    'order_time': {10434: 360}},
#   60434: {'location': [188, 149], 'timewindow': [360, 420]},
#   40435: {'location': [352, 87],
#    'timewindow': [540, 570],
#    'order_time': {10435: 540}},
#   60435: {'location': [247, 28], 'timewindow': [600, 720]},
#   40436: {'location': [200, 154],
#    'timewindow': [420, 540],
#    'order_time': {10436: 420}},
#   60436: {'location': [134, 119], 'timewindow': [420, 660]},
#   40437: {'location': [14, 125],
#    'timewindow': [390, 510],
#    'order_time': {10437: 390}},
#   60437: {'location': [20, 77], 'timewindow': [420, 540]},
#   40438: {'location': [249, 78],
#    'timewindow': [300, 540],
#    'order_time': {10438: 300}},
#   60438: {'location': [205, 142], 'timewindow': [630, 870]},
#   40439: {'location': [169, 160],
#    'timewindow': [360, 420],
#    'order_time': {10439: 360}},
#   60439: {'location': [249, 140], 'timewindow': [420, 780]},
#   40440: {'location': [184, 221],
#    'timewindow': [630, 660],
#    'order_time': {10440: 630}},
#   60440: {'location': [352, 79], 'timewindow': [720, 900]},
#   40441: {'location': [14, 125],
#    'timewindow': [420, 450],
#    'order_time': {10441: 420}},
#   60441: {'location': [325, 69], 'timewindow': [480, 570]},
#   40442: {'location': [204, 62],
#    'timewindow': [420, 600],
#    'order_time': {10442: 420}},
#   60442: {'location': [230, 48], 'timewindow': [660, 810]},
#   40443: {'location': [14, 125],
#    'timewindow': [390, 420],
#    'order_time': {10443: 390}},
#   60443: {'location': [162, 37], 'timewindow': [911, 600]},
#   40444: {'location': [384, 90],
#    'timewindow': [300, 870],
#    'order_time': {10444: 300}},
#   60444: {'location': [193, 15], 'timewindow': [330, 870]},
#   40445: {'location': [245, 141],
#    'timewindow': [300, 330],
#    'order_time': {10445: 300}},
#   60445: {'location': [254, 7], 'timewindow': [435, 465]},
#   40446: {'location': [255, 55],
#    'timewindow': [360, 390],
#    'order_time': {10446: 360}},
#   60446: {'location': [359, 88], 'timewindow': [420, 540]},
#   40447: {'location': [240, 157],
#    'timewindow': [420, 840],
#    'order_time': {10447: 420}},
#   60447: {'location': [225, 145], 'timewindow': [660, 840]},
#   40448: {'location': [200, 154],
#    'timewindow': [420, 660],
#    'order_time': {10448: 420}},
#   60448: {'location': [90, 66], 'timewindow': [420, 720]},
#   40449: {'location': [233, 138],
#    'timewindow': [480, 540],
#    'order_time': {10449: 480}},
#   60449: {'location': [217, 162], 'timewindow': [480, 600]},
#   40450: {'location': [135, 292],
#    'timewindow': [420, 1050],
#    'order_time': {10450: 420}},
#   60450: {'location': [230, 17], 'timewindow': [900, 1080]},
#   40451: {'location': [204, 62],
#    'timewindow': [540, 690],
#    'order_time': {10451: 540}},
#   60451: {'location': [121, 71], 'timewindow': [690, 840]},
#   40452: {'location': [165, 178],
#    'timewindow': [360, 390],
#    'order_time': {10452: 360}},
#   60452: {'location': [239, 83], 'timewindow': [450, 510]},
#   40453: {'location': [327, 68],
#    'timewindow': [480, 510],
#    'order_time': {10453: 480}},
#   60453: {'location': [377, 111], 'timewindow': [480, 570]},
#   40454: {'location': [165, 178],
#    'timewindow': [240, 270],
#    'order_time': {10454: 240}},
#   60454: {'location': [245, 176], 'timewindow': [300, 330]},
#   40455: {'location': [189, 204],
#    'timewindow': [390, 900],
#    'order_time': {10455: 390}},
#   60455: {'location': [309, 72], 'timewindow': [930, 990]},
#   40456: {'location': [215, 214],
#    'timewindow': [330, 360],
#    'order_time': {10456: 330}},
#   60456: {'location': [208, 136], 'timewindow': [390, 420]},
#   40457: {'location': [249, 135],
#    'timewindow': [420, 480],
#    'order_time': {10457: 420}},
#   60457: {'location': [221, 93], 'timewindow': [480, 600]},
#   40458: {'location': [240, 157],
#    'timewindow': [360, 840],
#    'order_time': {10458: 360}},
#   60458: {'location': [232, 140], 'timewindow': [660, 840]},
#   40459: {'location': [327, 68],
#    'timewindow': [540, 570],
#    'order_time': {10459: 540}},
#   60459: {'location': [207, 171], 'timewindow': [540, 660]},
#   40460: {'location': [169, 160],
#    'timewindow': [360, 660],
#    'order_time': {10460: 360}},
#   60460: {'location': [249, 140], 'timewindow': [420, 840]},
#   40461: {'location': [249, 193],
#    'timewindow': [360, 420],
#    'order_time': {10461: 360}},
#   60461: {'location': [248, 37], 'timewindow': [420, 540]},
#   40462: {'location': [211, 172],
#    'timewindow': [420, 600],
#    'order_time': {10462: 420}},
#   60462: {'location': [265, 96], 'timewindow': [660, 690]},
#   40463: {'location': [132, 64],
#    'timewindow': [420, 570],
#    'order_time': {10463: 420}},
#   60463: {'location': [161, 54], 'timewindow': [720, 870]},
#   40464: {'location': [127, 282],
#    'timewindow': [360, 390],
#    'order_time': {10464: 360}},
#   60464: {'location': [311, 19], 'timewindow': [450, 480]},
#   40465: {'location': [184, 244],
#    'timewindow': [480, 750],
#    'order_time': {10465: 480}},
#   60465: {'location': [330, 2], 'timewindow': [540, 840]},
#   40466: {'location': [244, 262],
#    'timewindow': [660, 690],
#    'order_time': {10466: 660}},
#   60466: {'location': [272, 71], 'timewindow': [750, 780]},
#   40467: {'location': [132, 234],
#    'timewindow': [360, 480],
#    'order_time': {10467: 360}},
#   60467: {'location': [109, 100], 'timewindow': [390, 540]},
#   40468: {'location': [280, 152],
#    'timewindow': [420, 450],
#    'order_time': {10468: 420}},
#   60468: {'location': [320, 47], 'timewindow': [480, 570]},
#   40469: {'location': [163, 115],
#    'timewindow': [360, 660],
#    'order_time': {10469: 360}},
#   60469: {'location': [197, 137], 'timewindow': [480, 660]},
#   40470: {'location': [142, 283],
#    'timewindow': [540, 840],
#    'order_time': {10470: 540}},
#   60470: {'location': [164, 9], 'timewindow': [660, 960]},
#   40471: {'location': [325, 79],
#    'timewindow': [300, 360],
#    'order_time': {10471: 300}},
#   60471: {'location': [58, 79], 'timewindow': [900, 960]},
#   40472: {'location': [183, 146],
#    'timewindow': [360, 390],
#    'order_time': {10472: 360}},
#   60472: {'location': [169, 210], 'timewindow': [420, 450]},
#   40473: {'location': [275, 2],
#    'timewindow': [540, 690],
#    'order_time': {10473: 540}},
#   60473: {'location': [121, 71], 'timewindow': [690, 840]},
#   40474: {'location': [313, 88],
#    'timewindow': [300, 330],
#    'order_time': {10474: 300}},
#   60474: {'location': [108, 228], 'timewindow': [360, 420]},
#   40475: {'location': [347, 36],
#    'timewindow': [300, 330],
#    'order_time': {10475: 300}},
#   60475: {'location': [232, 144], 'timewindow': [450, 510]},
#   40476: {'location': [137, 158],
#    'timewindow': [420, 450],
#    'order_time': {10476: 420}},
#   60476: {'location': [321, 132], 'timewindow': [420, 510]},
#   40477: {'location': [113, 89],
#    'timewindow': [420, 570],
#    'order_time': {10477: 420}},
#   60477: {'location': [107, 186], 'timewindow': [570, 720]},
#   40478: {'location': [274, 9],
#    'timewindow': [420, 780],
#    'order_time': {10478: 420}},
#   60478: {'location': [281, 0], 'timewindow': [660, 840]},
#   40479: {'location': [326, 172],
#    'timewindow': [540, 570],
#    'order_time': {10479: 540}},
#   60479: {'location': [128, 65], 'timewindow': [660, 720]},
#   40480: {'location': [248, 169],
#    'timewindow': [360, 390],
#    'order_time': {10480: 360}},
#   60480: {'location': [113, 93], 'timewindow': [360, 480]},
#   40481: {'location': [326, 172],
#    'timewindow': [390, 420],
#    'order_time': {10481: 390}},
#   60481: {'location': [196, 77], 'timewindow': [480, 600]},
#   40482: {'location': [147, 74],
#    'timewindow': [480, 510],
#    'order_time': {10482: 480}},
#   60482: {'location': [113, 103], 'timewindow': [480, 690]},
#   40483: {'location': [325, 107],
#    'timewindow': [510, 540],
#    'order_time': {10483: 510}},
#   60483: {'location': [91, 141], 'timewindow': [600, 660]},
#   40484: {'location': [138, 136],
#    'timewindow': [300, 360],
#    'order_time': {10484: 300}},
#   60484: {'location': [184, 129], 'timewindow': [300, 510]},
#   40485: {'location': [167, 64],
#    'timewindow': [450, 510],
#    'order_time': {10485: 450}},
#   60485: {'location': [266, 124], 'timewindow': [510, 540]},
#   40486: {'location': [254, 235],
#    'timewindow': [660, 720],
#    'order_time': {10486: 660}},
#   60486: {'location': [214, 120], 'timewindow': [690, 750]},
#   40487: {'location': [262, 116],
#    'timewindow': [420, 660],
#    'order_time': {10487: 420}},
#   60487: {'location': [264, 132], 'timewindow': [480, 660]},
#   40488: {'location': [171, 196],
#    'timewindow': [330, 360],
#    'order_time': {10488: 330}},
#   60488: {'location': [191, 136], 'timewindow': [390, 420]},
#   40489: {'location': [345, 66],
#    'timewindow': [420, 570],
#    'order_time': {10489: 420}},
#   60489: {'location': [316, 107], 'timewindow': [600, 720]},
#   40490: {'location': [225, 141],
#    'timewindow': [390, 420],
#    'order_time': {10490: 390}},
#   60490: {'location': [156, 134], 'timewindow': [450, 480]},
#   40491: {'location': [200, 154],
#    'timewindow': [420, 660],
#    'order_time': {10491: 420}},
#   60491: {'location': [274, 44], 'timewindow': [780, 1020]},
#   40492: {'location': [326, 172],
#    'timewindow': [540, 600],
#    'order_time': {10492: 540}},
#   60492: {'location': [180, 215], 'timewindow': [660, 780]},
#   40493: {'location': [110, 185],
#    'timewindow': [360, 390],
#    'order_time': {10493: 360}},
#   60493: {'location': [100, 91], 'timewindow': [420, 480]},
#   40494: {'location': [245, 141],
#    'timewindow': [270, 300],
#    'order_time': {10494: 270}},
#   60494: {'location': [180, 179], 'timewindow': [405, 435]},
#   ...})

# %%
def get_travel_duration_minutes(location1, location2):
    """Время перемещения курьера от точки location1 до точки location2 вминутах"""
    distance = abs(location1[0] - location2[0]) + abs(location1[1] - location2[1])
    return 10 + distance

# %%
def get_current_courier_reward(time, payment):
    work_payment = time * 2
    profit = orders_payment - work_payment
    return profit

# %%
len(data[1])
# Out:
# 7303

# %%
couriers_start_position = [data[0][i+1]['location'] for i in range(len(data[0]))]
points_pickup = np.array([[data[1][i+10001]['pickup_location_x'],
                           data[1][i+10001]['pickup_location_y']] for i in range(len(data[1]))])
time_pickup = np.array([[data[1][10001+i]['pickup_from'],
                         data[1][10001+i]['pickup_to']] for i in range(len(data[1]))])
time_dropoff = np.array([[data[1][10001+i]['dropoff_from'],
                          data[1][10001+i]['dropoff_to']] for i in range(len(data[1]))])    
points_dropoff = np.array([[data[1][i+10001]['dropoff_location_x'],
                            data[1][i+10001]['dropoff_location_y']] for i in range(len(data[1]))])
payments = np.array([data[1][10001+i]['payment'] for i in range(len(data[1]))])
if_visited = range(0, len(data[0]))

# %%
payments.sum()
# Out:
# 2836613

# %%
len(payments)
# Out:
# 7303

# %%
couriers_start_position[0]
# Out:
# [111, 5]

# %%
def delete_element(array, idx):
    result = []
    for i in range(len(array)):
        if not(i == idx):
            result.append(array[i])
    return result

# %%
type([1,2,3,4])
# Out:
# list

# %%
type(delete_element([1,2,3,6], 0))
# Out:
# list

# %%
payment = 0
reward = 0
stop_flag = 0
couriers_start_position = [data[0][i+1]['location'] for i in range(len(data[0]))]
points_pickup = np.array([[data[1][i+10001]['pickup_location_x'],
                           data[1][i+10001]['pickup_location_y']] for i in range(len(data[1]))])
time_pickup = np.array([[data[1][10001+i]['pickup_from'],
                         data[1][10001+i]['pickup_to']] for i in range(len(data[1]))])
time_dropoff = np.array([[data[1][10001+i]['dropoff_from'],
                          data[1][10001+i]['dropoff_to']] for i in range(len(data[1]))])    
points_dropoff = np.array([[data[1][i+10001]['dropoff_location_x'],
                            data[1][i+10001]['dropoff_location_y']] for i in range(len(data[1]))])
payments = np.array([data[1][10001+i]['payment'] for i in range(len(data[1]))])
pickup_id = np.array([data[1][10001+i]['pickup_point_id'] for i in range(len(data[1]))])
dropoff_id = np.array([data[1][10001+i]['dropoff_point_id'] for i in range(len(data[1]))])
cnt = 0
cnt_courier = 0
routes = []
for courier in tqdm_notebook(couriers_start_position):
    if stop_flag == 1:
        break 
    print('courier {} begins route at {}'.format(cnt_courier, courier))
    cnt_courier += 1
    tmp_x = [courier[0]]
    tmp_y = [courier[1]]
    print('processing courier {}..\n'.format(cnt))
    cnt += 1
    courier_position = courier
    current_time = 360
    distances = []
    routes = []
    # select avaliable pickup points
    while current_time < 1400:
        distances = []
        avaliable_pickups = []
        print("current time {}. Passing order {}\n".format(current_time, cnt))
        cnt += 1
        tmp_route = []
        for j in range(len(points_pickup)):
            tmp_route.append( {"courier_id": cnt_courier,
                              "action":"pickup", "order_id":10001+j,
                              "point_id":pickup_id[j]})
            tmp_route.append( {"courier_id": cnt_courier,
                              "action":"dropoff", "order_id":10001+j,
                              "point_id":dropoff_id[j]})
            # calculate route_time for each point from current courier position to dropoff
            route_time = get_travel_duration_minutes(points_pickup[j],points_dropoff[j]) + get_travel_duration_minutes(points_pickup[j],
                                                                                             courier_position)
            if current_time in time_pickup[j] and current_time + route_time:
                avaliable_pickups.append(points_pickup[j])       
            
        # calculate Manhattan distance to closest avaliable points
        min_dist = np.inf
        if len(avaliable_pickups) == 0:
            break
            print('сука')
        for i in range(len(avaliable_pickups)):
            dist = get_travel_duration_minutes(courier, avaliable_pickups[i])
            if not(dist == 0):
                tmp = get_travel_duration_minutes(courier, avaliable_pickups[i])
                if tmp < min_dist:
                    min_dist = tmp
                    current_order = i
                    
        # delete visited location

        print('the most far point: {}'.format(min_dist))
        courier_position = points_dropoff[j]
        print('send courier on {}'.format(courier_position))
        tmp_x.append(courier_position[0])
        tmp_y.append(courier_position[1])
        
        current_time += route_time
        payment = payments[current_order] 
        print('Payment: {}, salary: {}'.format(payments[current_order], route_time))
        
        #deleting visited elements
        points_dropoff = delete_element(points_dropoff,current_order)
        time_pickup = delete_element(time_pickup,current_order)
        points_pickup = delete_element(points_pickup, current_order)
        time_dropoff = delete_element(time_dropoff, current_order)
        payments = delete_element(payments, current_order)
    
        print("{} points left".format(len(points_pickup)))
    reward += payment   
    print(reward)
    print("-"*80)
    routes.append(tmp_route)
print('total reward: {}'.format(reward - (current_time-360)*2))
# Out:
# HBox(children=(IntProgress(value=0, max=300), HTML(value='')))
# courier 0 begins route at [111, 5]
# processing courier 0..
#
# current time 360. Passing order 1
#
# the most far point: 18
# send courier on [135  51]
# Payment: 268, salary: 434
# 7302 points left
# current time 794. Passing order 2
#
# 268
# --------------------------------------------------------------------------------
# courier 1 begins route at [260, 112]
# processing courier 3..
#
# current time 360. Passing order 4
#
# the most far point: 11
# send courier on [135  51]
# Payment: 700, salary: 212
# 7301 points left
# current time 572. Passing order 5
#
# the most far point: 40
# send courier on [135  51]
# Payment: 302, salary: 364
# 7300 points left
# current time 936. Passing order 6
#
# 570
# --------------------------------------------------------------------------------
# courier 2 begins route at [207, 66]
# processing courier 7..
#
# current time 360. Passing order 8
#
# the most far point: 17
# send courier on [135  51]
# Payment: 302, salary: 277
# 7299 points left
# current time 637. Passing order 9
#
# the most far point: 93
# send courier on [135  51]
# Payment: 519, salary: 364
# 7298 points left
# current time 1001. Passing order 10
#
# 1089
# --------------------------------------------------------------------------------
# courier 3 begins route at [288, 55]
# processing courier 11..
#
# current time 360. Passing order 12
#
# the most far point: 18
# send courier on [135  51]
# Payment: 500, salary: 297
# 7297 points left
# current time 657. Passing order 13
#
# the most far point: 102
# send courier on [135  51]
# Payment: 337, salary: 364
# 7296 points left
# current time 1021. Passing order 14
#
# 1426
# --------------------------------------------------------------------------------
# courier 4 begins route at [253, 234]
# processing courier 15..
#
# current time 360. Passing order 16
#
# the most far point: 30
# send courier on [135  51]
# Payment: 473, salary: 321
# 7295 points left
# current time 681. Passing order 17
#
# 1899
# --------------------------------------------------------------------------------
# courier 5 begins route at [210, 109]
# processing courier 18..
#
# current time 360. Passing order 19
#
# the most far point: 12
# send courier on [135  51]
# Payment: 486, salary: 231
# 7294 points left
# current time 591. Passing order 20
#
# the most far point: 24
# send courier on [135  51]
# Payment: 298, salary: 364
# 7293 points left
# current time 955. Passing order 21
#
# 2197
# --------------------------------------------------------------------------------
# courier 6 begins route at [200, 46]
# processing courier 22..
#
# current time 360. Passing order 23
#
# the most far point: 13
# send courier on [135  51]
# Payment: 309, salary: 304
# 7292 points left
# current time 664. Passing order 24
#
# 2506
# --------------------------------------------------------------------------------
# courier 7 begins route at [270, 211]
# processing courier 25..
#
# current time 360. Passing order 26
#
# the most far point: 27
# send courier on [135  51]
# Payment: 342, salary: 315
# 7291 points left
# current time 675. Passing order 27
#
# 2848
# --------------------------------------------------------------------------------
# courier 8 begins route at [221, 157]
# processing courier 28..
#
# current time 360. Passing order 29
#
# the most far point: 15
# send courier on [135  51]
# Payment: 392, salary: 256
# 7290 points left
# current time 616. Passing order 30
#
# the most far point: 52
# send courier on [135  51]
# Payment: 521, salary: 364
# 7289 points left
# current time 980. Passing order 31
#
# 3369
# --------------------------------------------------------------------------------
# courier 9 begins route at [328, 42]
# processing courier 32..
#
# current time 360. Passing order 33
#
# the most far point: 18
# send courier on [135  51]
# Payment: 405, salary: 350
# 7288 points left
# current time 710. Passing order 34
#
# the most far point: 192
# send courier on [135  51]
# Payment: 313, salary: 364
# 7287 points left
# current time 1074. Passing order 35
#
# 3682
# --------------------------------------------------------------------------------
# courier 10 begins route at [125, 126]
# processing courier 36..
#
# current time 360. Passing order 37
#
# the most far point: 15
# send courier on [135  51]
# Payment: 661, salary: 321
# 7286 points left
# current time 681. Passing order 38
#
# 4343
# --------------------------------------------------------------------------------
# courier 11 begins route at [218, 157]
# processing courier 39..
#
# current time 360. Passing order 40
#
# the most far point: 14
# send courier on [135  51]
# Payment: 350, salary: 259
# 7285 points left
# current time 619. Passing order 41
#
# the most far point: 43
# send courier on [135  51]
# Payment: 284, salary: 364
# 7284 points left
# current time 983. Passing order 42
#
# 4627
# --------------------------------------------------------------------------------
# courier 12 begins route at [13, 91]
# processing courier 43..
#
# current time 360. Passing order 44
#
# the most far point: 23
# send courier on [135  51]
# Payment: 320, salary: 446
# 7283 points left
# current time 806. Passing order 45
#
# 4947
# --------------------------------------------------------------------------------
# courier 13 begins route at [223, 105]
# processing courier 46..
#
# current time 360. Passing order 47
#
# the most far point: 13
# send courier on [135  51]
# Payment: 255, salary: 222
# 7282 points left
# current time 582. Passing order 48
#
# the most far point: 51
# send courier on [135  51]
# Payment: 352, salary: 364
# 7281 points left
# current time 946. Passing order 49
#
# 5299
# --------------------------------------------------------------------------------
# courier 14 begins route at [0, 37]
# processing courier 50..
#
# current time 360. Passing order 51
#
# the most far point: 88
# send courier on [135  51]
# Payment: 402, salary: 513
# 7280 points left
# current time 873. Passing order 52
#
# 5701
# --------------------------------------------------------------------------------
# courier 15 begins route at [308, 103]
# processing courier 53..
#
# current time 360. Passing order 54
#
# the most far point: 13
# send courier on [135  51]
# Payment: 267, salary: 269
# 7279 points left
# current time 629. Passing order 55
#
# the most far point: 58
# send courier on [135  51]
# Payment: 291, salary: 364
# 7278 points left
# current time 993. Passing order 56
#
# 5992
# --------------------------------------------------------------------------------
# courier 16 begins route at [245, 161]
# processing courier 57..
#
# current time 360. Passing order 58
#
# the most far point: 16
# send courier on [135  51]
# Payment: 169, salary: 240
# 7277 points left
# current time 600. Passing order 59
#
# the most far point: 16
# send courier on [135  51]
# Payment: 250, salary: 364
# 7276 points left
# current time 964. Passing order 60
#
# 6242
# --------------------------------------------------------------------------------
# courier 17 begins route at [57, 195]
# processing courier 61..
#
# current time 360. Passing order 62
#
# the most far point: 13
# send courier on [135  51]
# Payment: 459, salary: 458
# 7275 points left
# current time 818. Passing order 63
#
# 6701
# --------------------------------------------------------------------------------
# courier 18 begins route at [219, 73]
# processing courier 64..
#
# current time 360. Passing order 65
#
# the most far point: 20
# send courier on [135  51]
# Payment: 403, salary: 258
# 7274 points left
# current time 618. Passing order 66
#
# the most far point: 36
# send courier on [135  51]
# Payment: 372, salary: 364
# 7273 points left
# current time 982. Passing order 67
#
# the most far point: 159
# send courier on [135  51]
# Payment: 380, salary: 364
# 7272 points left
# current time 1346. Passing order 68
#
# 7081
# --------------------------------------------------------------------------------
# courier 19 begins route at [145, 217]
# processing courier 69..
#
# current time 360. Passing order 70
#
# the most far point: 17
# send courier on [135  51]
# Payment: 440, salary: 392
# 7271 points left
# current time 752. Passing order 71
#
# 7521
# --------------------------------------------------------------------------------
# courier 20 begins route at [164, 111]
# processing courier 72..
#
# current time 360. Passing order 73
#
# the most far point: 15
# send courier on [135  51]
# Payment: 303, salary: 275
# 7270 points left
# current time 635. Passing order 74
#
# the most far point: 22
# send courier on [135  51]
# Payment: 500, salary: 364
# 7269 points left
# current time 999. Passing order 75
#
# the most far point: 222
# send courier on [135  51]
# Payment: 482, salary: 364
# 7268 points left
# current time 1363. Passing order 76
#
# 8003
# --------------------------------------------------------------------------------
# courier 21 begins route at [209, 77]
# processing courier 77..
#
# current time 360. Passing order 78
#
# the most far point: 13
# send courier on [135  51]
# Payment: 250, salary: 264
# 7267 points left
# current time 624. Passing order 79
#
# the most far point: 32
# send courier on [135  51]
# Payment: 650, salary: 364
# 7266 points left
# current time 988. Passing order 80
#
# the most far point: 108
# send courier on [135  51]
# Payment: 310, salary: 364
# 7265 points left
# current time 1352. Passing order 81
#
# 8313
# --------------------------------------------------------------------------------
# courier 22 begins route at [84, 155]
# processing courier 82..
#
# current time 360. Passing order 83
#
# the most far point: 17
# send courier on [135  51]
# Payment: 290, salary: 391
# 7264 points left
# current time 751. Passing order 84
#
# the most far point: 50
# send courier on [135  51]
# Payment: 244, salary: 364
# 7263 points left
# current time 1115. Passing order 85
#
# 8557
# --------------------------------------------------------------------------------
# courier 23 begins route at [222, 137]
# processing courier 86..
#
# current time 360. Passing order 87
#
# the most far point: 11
# send courier on [135  51]
# Payment: 394, salary: 235
# 7262 points left
# current time 595. Passing order 88
#
# the most far point: 20
# send courier on [135  51]
# Payment: 524, salary: 364
# 7261 points left
# current time 959. Passing order 89
#
# the most far point: 156
# send courier on [135  51]
# Payment: 155, salary: 364
# 7260 points left
# current time 1323. Passing order 90
#
# 8712
# --------------------------------------------------------------------------------
# courier 24 begins route at [218, 140]
# processing courier 91..
#
# current time 360. Passing order 92
#
# the most far point: 11
# send courier on [135  51]
# Payment: 390, salary: 242
# 7259 points left
# current time 602. Passing order 93
#
# the most far point: 63
# send courier on [135  51]
# Payment: 513, salary: 364
# 7258 points left
# current time 966. Passing order 94
#
# 9225
# --------------------------------------------------------------------------------
# courier 25 begins route at [210, 81]
# processing courier 95..
#
# current time 360. Passing order 96
#
# the most far point: 12
# send courier on [135  51]
# Payment: 423, salary: 259
# 7257 points left
# current time 619. Passing order 97
#
# the most far point: 37
# send courier on [135  51]
# Payment: 410, salary: 364
# 7256 points left
# current time 983. Passing order 98
#
# 9635
# --------------------------------------------------------------------------------
# courier 26 begins route at [295, 15]
# processing courier 99..
#
# current time 360. Passing order 100
#
# the most far point: 15
# send courier on [135  51]
# Payment: 417, salary: 344
# 7255 points left
# current time 704. Passing order 101
#
# the most far point: 237
# send courier on [135  51]
# Payment: 370, salary: 364
# 7254 points left
# current time 1068. Passing order 102
#
# 10005
# --------------------------------------------------------------------------------
# courier 27 begins route at [364, 158]
# processing courier 103..
#
# current time 360. Passing order 104
#
# the most far point: 14
# send courier on [135  51]
# Payment: 376, salary: 356
# 7253 points left
# current time 716. Passing order 105
#
# 10381
# --------------------------------------------------------------------------------
# courier 28 begins route at [201, 137]
# processing courier 106..
#
# current time 360. Passing order 107
#
# the most far point: 13
# send courier on [135  51]
# Payment: 374, salary: 256
# 7252 points left
# current time 616. Passing order 108
#
# the most far point: 39
# send courier on [135  51]
# Payment: 413, salary: 364
# 7251 points left
# current time 980. Passing order 109
#
# 10794
# --------------------------------------------------------------------------------
# courier 29 begins route at [220, 214]
# processing courier 110..
#
# current time 360. Passing order 111
#
# the most far point: 13
# send courier on [135  51]
# Payment: 579, salary: 314
# 7250 points left
# current time 674. Passing order 112
#
# 11373
# --------------------------------------------------------------------------------
# courier 30 begins route at [162, 158]
# processing courier 113..
#
# current time 360. Passing order 114
#
# the most far point: 15
# send courier on [135  51]
# Payment: 242, salary: 316
# 7249 points left
# current time 676. Passing order 115
#
# 11615
# --------------------------------------------------------------------------------
# courier 31 begins route at [98, 25]
# processing courier 116..
#
# current time 360. Passing order 117
#
# the most far point: 23
# send courier on [135  51]
# Payment: 382, salary: 427
# 7248 points left
# current time 787. Passing order 118
#
# 11997
# --------------------------------------------------------------------------------
# courier 32 begins route at [267, 77]
# processing courier 119..
#
# current time 360. Passing order 120
#
# the most far point: 11
# send courier on [135  51]
# Payment: 438, salary: 254
# 7247 points left
# current time 614. Passing order 121
#
# the most far point: 94
# send courier on [135  51]
# Payment: 346, salary: 364
# 7246 points left
# current time 978. Passing order 122
#
# 12343
# --------------------------------------------------------------------------------
# courier 33 begins route at [229, 143]
# processing courier 123..
#
# current time 360. Passing order 124
#
# the most far point: 14
# send courier on [135  51]
# Payment: 339, salary: 234
# 7245 points left
# current time 594. Passing order 125
#
# the most far point: 27
# send courier on [135  51]
# Payment: 385, salary: 364
# 7244 points left
# current time 958. Passing order 126
#
# 12728
# --------------------------------------------------------------------------------
# courier 34 begins route at [115, 46]
# processing courier 127..
#
# current time 360. Passing order 128
#
# the most far point: 22
# send courier on [135  51]
# Payment: 277, salary: 389
# 7243 points left
# current time 749. Passing order 129
#
# 13005
# --------------------------------------------------------------------------------
# courier 35 begins route at [201, 4]
# processing courier 130..
#
# current time 360. Passing order 131
#
# the most far point: 12
# send courier on [135  51]
# Payment: 370, salary: 345
# 7242 points left
# current time 705. Passing order 132
#
# 13375
# --------------------------------------------------------------------------------
# courier 36 begins route at [170, 169]
# processing courier 133..
#
# current time 360. Passing order 134
#
# the most far point: 14
# send courier on [135  51]
# Payment: 328, salary: 319
# 7241 points left
# current time 679. Passing order 135
#
# 13703
# --------------------------------------------------------------------------------
# courier 37 begins route at [216, 141]
# processing courier 136..
#
# current time 360. Passing order 137
#
# the most far point: 12
# send courier on [135  51]
# Payment: 488, salary: 245
# 7240 points left
# current time 605. Passing order 138
#
# the most far point: 21
# send courier on [135  51]
# Payment: 431, salary: 364
# 7239 points left
# current time 969. Passing order 139
#
# 14134
# --------------------------------------------------------------------------------
# courier 38 begins route at [199, 87]
# processing courier 140..
#
# current time 360. Passing order 141
#
# the most far point: 14
# send courier on [135  51]
# Payment: 268, salary: 264
# 7238 points left
# current time 624. Passing order 142
#
# the most far point: 36
# send courier on [135  51]
# Payment: 376, salary: 364
# 7237 points left
# current time 988. Passing order 143
#
# the most far point: 88
# send courier on [135  51]
# Payment: 260, salary: 364
# 7236 points left
# current time 1352. Passing order 144
#
# 14394
# --------------------------------------------------------------------------------
# courier 39 begins route at [295, 53]
# processing courier 145..
#
# current time 360. Passing order 146
#
# the most far point: 15
# send courier on [135  51]
# Payment: 451, salary: 306
# 7235 points left
# current time 666. Passing order 147
#
# 14845
# --------------------------------------------------------------------------------
# courier 40 begins route at [229, 125]
# processing courier 148..
#
# current time 360. Passing order 149
#
# the most far point: 13
# send courier on [135  51]
# Payment: 558, salary: 216
# 7234 points left
# current time 576. Passing order 150
#
# the most far point: 39
# send courier on [135  51]
# Payment: 368, salary: 364
# 7233 points left
# current time 940. Passing order 151
#
# 15213
# --------------------------------------------------------------------------------
# courier 41 begins route at [10, 31]
# processing courier 152..
#
# current time 360. Passing order 153
#
# the most far point: 84
# send courier on [135  51]
# Payment: 257, salary: 509
# 7232 points left
# current time 869. Passing order 154
#
# 15470
# --------------------------------------------------------------------------------
# courier 42 begins route at [106, 150]
# processing courier 155..
#
# current time 360. Passing order 156
#
# the most far point: 13
# send courier on [135  51]
# Payment: 426, salary: 364
# 7231 points left
# current time 724. Passing order 157
#
# 15896
# --------------------------------------------------------------------------------
# courier 43 begins route at [220, 130]
# processing courier 158..
#
# current time 360. Passing order 159
#
# the most far point: 13
# send courier on [135  51]
# Payment: 603, salary: 230
# 7230 points left
# current time 590. Passing order 160
# the most far point: 22
# send courier on [135  51]
# Payment: 321, salary: 364
# 7229 points left
# current time 954. Passing order 161
#
# the most far point: 41
# send courier on [135  51]
# Payment: 342, salary: 364
# 7228 points left
# current time 1318. Passing order 162
#
# 16238
# --------------------------------------------------------------------------------
# courier 44 begins route at [288, 106]
# processing courier 163..
#
# current time 360. Passing order 164
#
# the most far point: 13
# send courier on [135  51]
# Payment: 284, salary: 246
# 7227 points left
# current time 606. Passing order 165
#
# the most far point: 54
# send courier on [135  51]
# Payment: 242, salary: 364
# 7226 points left
# current time 970. Passing order 166
#
# 16480
# --------------------------------------------------------------------------------
# courier 45 begins route at [292, 112]
# processing courier 167..
#
# current time 360. Passing order 168
#
# the most far point: 21
# send courier on [135  51]
# Payment: 440, salary: 244
# 7225 points left
# current time 604. Passing order 169
#
# the most far point: 35
# send courier on [135  51]
# Payment: 293, salary: 364
# 7224 points left
# current time 968. Passing order 170
#
# the most far point: 111
# send courier on [135  51]
# Payment: 302, salary: 364
# 7223 points left
# current time 1332. Passing order 171
#
# 16782
# --------------------------------------------------------------------------------
# courier 46 begins route at [164, 156]
# processing courier 172..
#
# current time 360. Passing order 173
#
# the most far point: 11
# send courier on [135  51]
# Payment: 196, salary: 312
# 7222 points left
# current time 672. Passing order 174
#
# 16978
# --------------------------------------------------------------------------------
# courier 47 begins route at [57, 195]
# processing courier 175..
#
# current time 360. Passing order 176
#
# the most far point: 13
# send courier on [135  51]
# Payment: 407, salary: 458
# 7221 points left
# current time 818. Passing order 177
#
# 17385
# --------------------------------------------------------------------------------
# courier 48 begins route at [328, 42]
# processing courier 178..
#
# current time 360. Passing order 179
#
# the most far point: 18
# send courier on [135  51]
# Payment: 395, salary: 350
# 7220 points left
# current time 710. Passing order 180
#
# the most far point: 192
# send courier on [135  51]
# Payment: 294, salary: 364
# 7219 points left
# current time 1074. Passing order 181
#
# 17679
# --------------------------------------------------------------------------------
# courier 49 begins route at [147, 77]
# processing courier 182..
#
# current time 360. Passing order 183
#
# the most far point: 22
# send courier on [135  51]
# Payment: 275, salary: 326
# 7218 points left
# current time 686. Passing order 184
#
# 17954
# --------------------------------------------------------------------------------
# courier 50 begins route at [125, 126]
# processing courier 185..
#
# current time 360. Passing order 186
#
# the most far point: 15
# send courier on [135  51]
# Payment: 250, salary: 321
# 7217 points left
# current time 681. Passing order 187
#
# 18204
# --------------------------------------------------------------------------------
# courier 51 begins route at [204, 98]
# processing courier 188..
#
# current time 360. Passing order 189
#
# the most far point: 12
# send courier on [135  51]
# Payment: 354, salary: 248
# 7216 points left
# current time 608. Passing order 190
#
# the most far point: 58
# send courier on [135  51]
# Payment: 238, salary: 364
# 7215 points left
# current time 972. Passing order 191
#
# 18442
# --------------------------------------------------------------------------------
# courier 52 begins route at [59, 179]
# processing courier 192..
#
# current time 360. Passing order 193
#
# the most far point: 18
# send courier on [135  51]
# Payment: 374, salary: 440
# 7214 points left
# current time 800. Passing order 194
#
# 18816
# --------------------------------------------------------------------------------
# courier 53 begins route at [69, 125]
# processing courier 195..
#
# current time 360. Passing order 196
#
# the most far point: 12
# send courier on [135  51]
# Payment: 222, salary: 376
# 7213 points left
# current time 736. Passing order 197
#
# 19038
# --------------------------------------------------------------------------------
# courier 54 begins route at [288, 106]
# processing courier 198..
#
# current time 360. Passing order 199
#
# the most far point: 13
# send courier on [135  51]
# Payment: 270, salary: 246
# 7212 points left
# current time 606. Passing order 200
#
# the most far point: 54
# send courier on [135  51]
# Payment: 348, salary: 364
# 7211 points left
# current time 970. Passing order 201
#
# 19386
# --------------------------------------------------------------------------------
# courier 55 begins route at [336, 16]
# processing courier 202..
#
# current time 360. Passing order 203
#
# the most far point: 16
# send courier on [135  51]
# Payment: 628, salary: 384
# 7210 points left
# current time 744. Passing order 204
#
# the most far point: 316
# send courier on [135  51]
# Payment: 468, salary: 364
# 7209 points left
# current time 1108. Passing order 205
#
# 19854
# --------------------------------------------------------------------------------
# courier 56 begins route at [58, 211]
# processing courier 206..
#
# current time 360. Passing order 207
#
# the most far point: 30
# send courier on [135  51]
# Payment: 380, salary: 473
# 7208 points left
# current time 833. Passing order 208
#
# 20234
# --------------------------------------------------------------------------------
# courier 57 begins route at [104, 132]
# processing courier 209..
#
# current time 360. Passing order 210
#
# the most far point: 15
# send courier on [135  51]
# Payment: 108, salary: 348
# 7207 points left
# current time 708. Passing order 211
#
# 20342
# --------------------------------------------------------------------------------
# courier 58 begins route at [162, 224]
# processing courier 212..
#
# current time 360. Passing order 213
#
# the most far point: 14
# send courier on [135  51]
# Payment: 309, salary: 382
# 7206 points left
# current time 742. Passing order 214
#
# 20651
# --------------------------------------------------------------------------------
# courier 59 begins route at [163, 111]
# processing courier 215..
#
# current time 360. Passing order 216
#
# the most far point: 14
# send courier on [135  51]
# Payment: 584, salary: 276
# 7205 points left
# current time 636. Passing order 217
#
# the most far point: 31
# send courier on [135  51]
# Payment: 510, salary: 364
# 7204 points left
# current time 1000. Passing order 218
#
# 21161
# --------------------------------------------------------------------------------
# courier 60 begins route at [82, 69]
# processing courier 219..
#
# current time 360. Passing order 220
#
# the most far point: 20
# send courier on [135  51]
# Payment: 380, salary: 399
# 7203 points left
# current time 759. Passing order 221
#
# 21541
# --------------------------------------------------------------------------------
# courier 61 begins route at [254, 215]
# processing courier 222..
#
# current time 360. Passing order 223
#
# the most far point: 12
# send courier on [135  51]
# Payment: 350, salary: 303
# 7202 points left
# current time 663. Passing order 224
#
# 21891
# --------------------------------------------------------------------------------
# courier 62 begins route at [142, 103]
# processing courier 225..
#
# current time 360. Passing order 226
#
# the most far point: 11
# send courier on [135  51]
# Payment: 327, salary: 305
# 7201 points left
# current time 665. Passing order 227
#
# 22218
# --------------------------------------------------------------------------------
# courier 63 begins route at [337, 122]
# processing courier 228..
#
# current time 360. Passing order 229
#
# the most far point: 13
# send courier on [135  51]
# Payment: 350, salary: 293
# 7200 points left
# current time 653. Passing order 230
#
# the most far point: 43
# send courier on [135  51]
# Payment: 547, salary: 364
# 7199 points left
# current time 1017. Passing order 231
#
# 22765
# --------------------------------------------------------------------------------
# courier 64 begins route at [165, 309]
# processing courier 232..
#
# current time 360. Passing order 233
#
# the most far point: 50
# send courier on [135  51]
# Payment: 527, salary: 464
# 7198 points left
# current time 824. Passing order 234
#
# 23292
# --------------------------------------------------------------------------------
# courier 65 begins route at [176, 168]
# processing courier 235..
#
# current time 360. Passing order 236
#
# the most far point: 13
# send courier on [135  51]
# Payment: 250, salary: 312
# 7197 points left
# current time 672. Passing order 237
#
# 23542
# --------------------------------------------------------------------------------
# courier 66 begins route at [58, 211]
# processing courier 238..
#
# current time 360. Passing order 239
#
# the most far point: 30
# send courier on [135  51]
# Payment: 254, salary: 473
# 7196 points left
# current time 833. Passing order 240
#
# 23796
# --------------------------------------------------------------------------------
# courier 67 begins route at [147, 200]
# processing courier 241..
#
# current time 360. Passing order 242
# the most far point: 15
# send courier on [135  51]
# Payment: 504, salary: 373
# 7195 points left
# current time 733. Passing order 243
#
# 24300
# --------------------------------------------------------------------------------
# courier 68 begins route at [361, 121]
# processing courier 244..
#
# current time 360. Passing order 245
#
# the most far point: 16
# send courier on [135  51]
# Payment: 358, salary: 316
# 7194 points left
# current time 676. Passing order 246
#
# 24658
# --------------------------------------------------------------------------------
# courier 69 begins route at [237, 170]
# processing courier 247..
#
# current time 360. Passing order 248
#
# the most far point: 12
# send courier on [135  51]
# Payment: 268, salary: 253
# 7193 points left
# current time 613. Passing order 249
#
# the most far point: 50
# send courier on [135  51]
# Payment: 224, salary: 364
# 7192 points left
# current time 977. Passing order 250
#
# 24882
# --------------------------------------------------------------------------------
# courier 70 begins route at [247, 184]
# processing courier 251..
#
# current time 360. Passing order 252
#
# the most far point: 14
# send courier on [135  51]
# Payment: 371, salary: 265
# 7191 points left
# current time 625. Passing order 253
#
# the most far point: 63
# send courier on [135  51]
# Payment: 287, salary: 364
# 7190 points left
# current time 989. Passing order 254
#
# 25169
# --------------------------------------------------------------------------------
# courier 71 begins route at [328, 95]
# processing courier 255..
#
# current time 360. Passing order 256
#
# the most far point: 18
# send courier on [135  51]
# Payment: 331, salary: 297
# 7189 points left
# current time 657. Passing order 257
#
# the most far point: 99
# send courier on [135  51]
# Payment: 242, salary: 364
# 7188 points left
# current time 1021. Passing order 258
#
# 25411
# --------------------------------------------------------------------------------
# courier 72 begins route at [291, 114]
# processing courier 259..
#
# current time 360. Passing order 260
#
# the most far point: 20
# send courier on [135  51]
# Payment: 276, salary: 241
# 7187 points left
# current time 601. Passing order 261
#
# the most far point: 28
# send courier on [135  51]
# Payment: 380, salary: 364
# 7186 points left
# current time 965. Passing order 262
#
# 25791
# --------------------------------------------------------------------------------
# courier 73 begins route at [190, 200]
# processing courier 263..
#
# current time 360. Passing order 264
#
# the most far point: 11
# send courier on [135  51]
# Payment: 450, salary: 330
# 7185 points left
# current time 690. Passing order 265
#
# the most far point: 19
# send courier on [135  51]
# Payment: 312, salary: 364
# 7184 points left
# current time 1054. Passing order 266
#
# 26103
# --------------------------------------------------------------------------------
# courier 74 begins route at [205, 55]
# processing courier 267..
#
# current time 360. Passing order 268
#
# the most far point: 15
# send courier on [135  51]
# Payment: 465, salary: 290
# 7183 points left
# current time 650. Passing order 269
#
# the most far point: 52
# send courier on [135  51]
# Payment: 317, salary: 364
# 7182 points left
# current time 1014. Passing order 270
#
# the most far point: 83
# send courier on [135  51]
# Payment: 480, salary: 364
# 7181 points left
# current time 1378. Passing order 271
#
# 26583
# --------------------------------------------------------------------------------
# courier 75 begins route at [277, 244]
# processing courier 272..
#
# current time 360. Passing order 273
#
# the most far point: 11
# send courier on [135  51]
# Payment: 380, salary: 355
# 7180 points left
# current time 715. Passing order 274
#
# the most far point: 153
# send courier on [135  51]
# Payment: 408, salary: 364
# 7179 points left
# current time 1079. Passing order 275
#
# 26991
# --------------------------------------------------------------------------------
# courier 76 begins route at [291, 125]
# processing courier 276..
#
# current time 360. Passing order 277
#
# the most far point: 13
# send courier on [135  51]
# Payment: 326, salary: 250
# 7178 points left
# current time 610. Passing order 278
#
# the most far point: 38
# send courier on [135  51]
# Payment: 448, salary: 364
# 7177 points left
# current time 974. Passing order 279
#
# the most far point: 83
# send courier on [135  51]
# Payment: 426, salary: 364
# 7176 points left
# current time 1338. Passing order 280
#
# 27417
# --------------------------------------------------------------------------------
# courier 77 begins route at [266, 56]
# processing courier 281..
#
# current time 360. Passing order 282
#
# the most far point: 21
# send courier on [135  51]
# Payment: 501, salary: 274
# 7175 points left
# current time 634. Passing order 283
#
# the most far point: 37
# send courier on [135  51]
# Payment: 400, salary: 364
# 7174 points left
# current time 998. Passing order 284
#
# 27817
# --------------------------------------------------------------------------------
# courier 78 begins route at [99, 210]
# processing courier 285..
#
# current time 360. Passing order 286
#
# the most far point: 12
# send courier on [135  51]
# Payment: 398, salary: 431
# 7173 points left
# current time 791. Passing order 287
#
# 28215
# --------------------------------------------------------------------------------
# courier 79 begins route at [206, 120]
# processing courier 288..
#
# current time 360. Passing order 289
#
# the most far point: 19
# send courier on [135  51]
# Payment: 265, salary: 234
# 7172 points left
# current time 594. Passing order 290
#
# the most far point: 20
# send courier on [135  51]
# Payment: 181, salary: 364
# 7171 points left
# current time 958. Passing order 291
#
# 28396
# --------------------------------------------------------------------------------
# courier 80 begins route at [190, 22]
# processing courier 292..
#
# current time 360. Passing order 293
#
# the most far point: 18
# send courier on [135  51]
# Payment: 250, salary: 338
# 7170 points left
# current time 698. Passing order 294
#
# the most far point: 245
# send courier on [135  51]
# Payment: 374, salary: 364
# 7169 points left
# current time 1062. Passing order 295
#
# 28770
# --------------------------------------------------------------------------------
# courier 81 begins route at [247, 184]
# processing courier 296..
#
# current time 360. Passing order 297
#
# the most far point: 14
# send courier on [135  51]
# Payment: 438, salary: 265
# 7168 points left
# current time 625. Passing order 298
#
# the most far point: 63
# send courier on [135  51]
# Payment: 381, salary: 364
# 7167 points left
# current time 989. Passing order 299
#
# 29151
# --------------------------------------------------------------------------------
# courier 82 begins route at [181, 97]
# processing courier 300..
#
# current time 360. Passing order 301
#
# the most far point: 21
# send courier on [135  51]
# Payment: 380, salary: 272
# 7166 points left
# current time 632. Passing order 302
#
# the most far point: 25
# send courier on [135  51]
# Payment: 353, salary: 364
# 7165 points left
# current time 996. Passing order 303
#
# 29504
# --------------------------------------------------------------------------------
# courier 83 begins route at [187, 135]
# processing courier 304..
#
# current time 360. Passing order 305
#
# the most far point: 16
# send courier on [135  51]
# Payment: 271, salary: 268
# 7164 points left
# current time 628. Passing order 306
#
# the most far point: 64
# send courier on [135  51]
# Payment: 262, salary: 364
# 7163 points left
# current time 992. Passing order 307
#
# 29766
# --------------------------------------------------------------------------------
# courier 84 begins route at [200, 153]
# processing courier 308..
#
# current time 360. Passing order 309
#
# the most far point: 13
# send courier on [135  51]
# Payment: 200, salary: 273
# 7162 points left
# current time 633. Passing order 310
#
# the most far point: 51
# send courier on [135  51]
# Payment: 545, salary: 364
# 7161 points left
# current time 997. Passing order 311
#
# 30311
# --------------------------------------------------------------------------------
# courier 85 begins route at [190, 127]
# processing courier 312..
#
# current time 360. Passing order 313
#
# the most far point: 18
# send courier on [135  51]
# Payment: 604, salary: 257
# 7160 points left
# current time 617. Passing order 314
#
# the most far point: 53
# send courier on [135  51]
# Payment: 271, salary: 364
# 7159 points left
# current time 981. Passing order 315
#
# 30582
# --------------------------------------------------------------------------------
# courier 86 begins route at [145, 123]
# processing courier 316..
#
# current time 360. Passing order 317
#
# the most far point: 12
# send courier on [135  51]
# Payment: 250, salary: 298
# 7158 points left
# current time 658. Passing order 318
#
# the most far point: 25
# send courier on [135  51]
# Payment: 483, salary: 364
# 7157 points left
# current time 1022. Passing order 319
# the most far point: 162
# send courier on [135  51]
# Payment: 287, salary: 364
# 7156 points left
# current time 1386. Passing order 320
#
# 30869
# --------------------------------------------------------------------------------
# courier 87 begins route at [299, 148]
# processing courier 321..
#
# current time 360. Passing order 322
#
# the most far point: 18
# send courier on [135  51]
# Payment: 401, salary: 281
# 7155 points left
# current time 641. Passing order 323
#
# the most far point: 77
# send courier on [135  51]
# Payment: 553, salary: 364
# 7154 points left
# current time 1005. Passing order 324
#
# the most far point: 182
# send courier on [135  51]
# Payment: 380, salary: 364
# 7153 points left
# current time 1369. Passing order 325
#
# 31249
# --------------------------------------------------------------------------------
# courier 88 begins route at [342, 86]
# processing courier 326..
#
# current time 360. Passing order 327
#
# the most far point: 15
# send courier on [135  51]
# Payment: 385, salary: 320
# 7152 points left
# current time 680. Passing order 328
#
# the most far point: 213
# send courier on [135  51]
# Payment: 520, salary: 364
# 7151 points left
# current time 1044. Passing order 329
#
# 31769
# --------------------------------------------------------------------------------
# courier 89 begins route at [328, 42]
# processing courier 330..
#
# current time 360. Passing order 331
#
# the most far point: 18
# send courier on [135  51]
# Payment: 431, salary: 350
# 7150 points left
# current time 710. Passing order 332
#
# the most far point: 192
# send courier on [135  51]
# Payment: 188, salary: 364
# 7149 points left
# current time 1074. Passing order 333
#
# 31957
# --------------------------------------------------------------------------------
# courier 90 begins route at [218, 157]
# processing courier 334..
#
# current time 360. Passing order 335
#
# the most far point: 14
# send courier on [135  51]
# Payment: 621, salary: 259
# 7148 points left
# current time 619. Passing order 336
#
# the most far point: 43
# send courier on [135  51]
# Payment: 519, salary: 364
# 7147 points left
# current time 983. Passing order 337
#
# 32476
# --------------------------------------------------------------------------------
# courier 91 begins route at [241, 155]
# processing courier 338..
#
# current time 360. Passing order 339
#
# the most far point: 12
# send courier on [135  51]
# Payment: 361, salary: 234
# 7146 points left
# current time 594. Passing order 340
#
# the most far point: 27
# send courier on [135  51]
# Payment: 187, salary: 364
# 7145 points left
# current time 958. Passing order 341
#
# 32663
# --------------------------------------------------------------------------------
# courier 92 begins route at [328, 42]
# processing courier 342..
#
# current time 360. Passing order 343
#
# the most far point: 18
# send courier on [135  51]
# Payment: 329, salary: 350
# 7144 points left
# current time 710. Passing order 344
#
# the most far point: 192
# send courier on [135  51]
# Payment: 403, salary: 364
# 7143 points left
# current time 1074. Passing order 345
#
# 33066
# --------------------------------------------------------------------------------
# courier 93 begins route at [254, 210]
# processing courier 346..
#
# current time 360. Passing order 347
#
# the most far point: 11
# send courier on [135  51]
# Payment: 519, salary: 298
# 7142 points left
# current time 658. Passing order 348
#
# the most far point: 28
# send courier on [135  51]
# Payment: 231, salary: 364
# 7141 points left
# current time 1022. Passing order 349
#
# the most far point: 298
# send courier on [135  51]
# Payment: 363, salary: 364
# 7140 points left
# current time 1386. Passing order 350
#
# 33429
# --------------------------------------------------------------------------------
# courier 94 begins route at [198, 131]
# processing courier 351..
#
# current time 360. Passing order 352
#
# the most far point: 13
# send courier on [135  51]
# Payment: 334, salary: 253
# 7139 points left
# current time 613. Passing order 353
#
# the most far point: 70
# send courier on [135  51]
# Payment: 347, salary: 364
# 7138 points left
# current time 977. Passing order 354
#
# 33776
# --------------------------------------------------------------------------------
# courier 95 begins route at [240, 155]
# processing courier 355..
#
# current time 360. Passing order 356
#
# the most far point: 11
# send courier on [135  51]
# Payment: 528, salary: 235
# 7137 points left
# current time 595. Passing order 357
#
# the most far point: 37
# send courier on [135  51]
# Payment: 318, salary: 364
# 7136 points left
# current time 959. Passing order 358
#
# the most far point: 120
# send courier on [135  51]
# Payment: 343, salary: 364
# 7135 points left
# current time 1323. Passing order 359
#
# 34119
# --------------------------------------------------------------------------------
# courier 96 begins route at [165, 134]
# processing courier 360..
#
# current time 360. Passing order 361
#
# the most far point: 13
# send courier on [135  51]
# Payment: 288, salary: 289
# 7134 points left
# current time 649. Passing order 362
#
# the most far point: 19
# send courier on [135  51]
# Payment: 331, salary: 364
# 7133 points left
# current time 1013. Passing order 363
#
# 34450
# --------------------------------------------------------------------------------
# courier 97 begins route at [291, 114]
# processing courier 364..
#
# current time 360. Passing order 365
#
# the most far point: 20
# send courier on [135  51]
# Payment: 336, salary: 241
# 7132 points left
# current time 601. Passing order 366
#
# the most far point: 28
# send courier on [135  51]
# Payment: 470, salary: 364
# 7131 points left
# current time 965. Passing order 367
#
# 34920
# --------------------------------------------------------------------------------
# courier 98 begins route at [162, 158]
# processing courier 368..
#
# current time 360. Passing order 369
#
# the most far point: 15
# send courier on [135  51]
# Payment: 318, salary: 316
# 7130 points left
# current time 676. Passing order 370
#
# 35238
# --------------------------------------------------------------------------------
# courier 99 begins route at [319, 113]
# processing courier 371..
#
# current time 360. Passing order 372
#
# the most far point: 13
# send courier on [135  51]
# Payment: 338, salary: 270
# 7129 points left
# current time 630. Passing order 373
#
# the most far point: 20
# send courier on [135  51]
# Payment: 260, salary: 364
# 7128 points left
# current time 994. Passing order 374
#
# 35498
# --------------------------------------------------------------------------------
# courier 100 begins route at [354, 45]
# processing courier 375..
#
# current time 360. Passing order 376
#
# the most far point: 17
# send courier on [135  51]
# Payment: 376, salary: 373
# 7127 points left
# current time 733. Passing order 377
#
# 35874
# --------------------------------------------------------------------------------
# courier 101 begins route at [204, 99]
# processing courier 378..
#
# current time 360. Passing order 379
#
# the most far point: 13
# send courier on [135  51]
# Payment: 403, salary: 247
# 7126 points left
# current time 607. Passing order 380
#
# the most far point: 35
# send courier on [135  51]
# Payment: 380, salary: 364
# 7125 points left
# current time 971. Passing order 381
#
# 36254
# --------------------------------------------------------------------------------
# courier 102 begins route at [274, 108]
# processing courier 382..
#
# current time 360. Passing order 383
#
# the most far point: 12
# send courier on [135  51]
# Payment: 302, salary: 230
# 7124 points left
# current time 590. Passing order 384
#
# the most far point: 94
# send courier on [135  51]
# Payment: 376, salary: 364
# 7123 points left
# current time 954. Passing order 385
#
# the most far point: 55
# send courier on [135  51]
# Payment: 225, salary: 364
# 7122 points left
# current time 1318. Passing order 386
#
# 36479
# --------------------------------------------------------------------------------
# courier 103 begins route at [219, 1]
# processing courier 387..
#
# current time 360. Passing order 388
#
# the most far point: 12
# send courier on [135  51]
# Payment: 634, salary: 330
# 7121 points left
# current time 690. Passing order 389
#
# the most far point: 20
# send courier on [135  51]
# Payment: 250, salary: 364
# 7120 points left
# current time 1054. Passing order 390
#
# 36729
# --------------------------------------------------------------------------------
# courier 104 begins route at [200, 46]
# processing courier 391..
#
# current time 360. Passing order 392
#
# the most far point: 13
# send courier on [135  51]
# Payment: 383, salary: 304
# 7119 points left
# current time 664. Passing order 393
#
# 37112
# --------------------------------------------------------------------------------
# courier 105 begins route at [69, 210]
# processing courier 394..
#
# current time 360. Passing order 395
#
# the most far point: 27
# send courier on [135  51]
# Payment: 449, salary: 461
# 7118 points left
# current time 821. Passing order 396
# 37561
# --------------------------------------------------------------------------------
# courier 106 begins route at [205, 55]
# processing courier 397..
#
# current time 360. Passing order 398
#
# the most far point: 15
# send courier on [135  51]
# Payment: 383, salary: 290
# 7117 points left
# current time 650. Passing order 399
#
# the most far point: 52
# send courier on [135  51]
# Payment: 552, salary: 364
# 7116 points left
# current time 1014. Passing order 400
#
# the most far point: 83
# send courier on [135  51]
# Payment: 352, salary: 364
# 7115 points left
# current time 1378. Passing order 401
#
# 37913
# --------------------------------------------------------------------------------
# courier 107 begins route at [190, 23]
# processing courier 402..
#
# current time 360. Passing order 403
#
# the most far point: 19
# send courier on [135  51]
# Payment: 147, salary: 337
# 7114 points left
# current time 697. Passing order 404
#
# 38060
# --------------------------------------------------------------------------------
# courier 108 begins route at [57, 195]
# processing courier 405..
#
# current time 360. Passing order 406
#
# the most far point: 13
# send courier on [135  51]
# Payment: 514, salary: 458
# 7113 points left
# current time 818. Passing order 407
#
# 38574
# --------------------------------------------------------------------------------
# courier 109 begins route at [220, 130]
# processing courier 408..
#
# current time 360. Passing order 409
#
# the most far point: 13
# send courier on [135  51]
# Payment: 388, salary: 230
# 7112 points left
# current time 590. Passing order 410
#
# the most far point: 22
# send courier on [135  51]
# Payment: 333, salary: 364
# 7111 points left
# current time 954. Passing order 411
#
# the most far point: 41
# send courier on [135  51]
# Payment: 661, salary: 364
# 7110 points left
# current time 1318. Passing order 412
#
# 39235
# --------------------------------------------------------------------------------
# courier 110 begins route at [216, 141]
# processing courier 413..
#
# current time 360. Passing order 414
#
# the most far point: 12
# send courier on [135  51]
# Payment: 331, salary: 245
# 7109 points left
# current time 605. Passing order 415
#
# the most far point: 21
# send courier on [135  51]
# Payment: 540, salary: 364
# 7108 points left
# current time 969. Passing order 416
#
# 39775
# --------------------------------------------------------------------------------
# courier 111 begins route at [137, 134]
# processing courier 417..
#
# current time 360. Passing order 418
#
# the most far point: 12
# send courier on [135  51]
# Payment: 518, salary: 317
# 7107 points left
# current time 677. Passing order 419
#
# 40293
# --------------------------------------------------------------------------------
# courier 112 begins route at [160, 278]
# processing courier 420..
#
# current time 360. Passing order 421
#
# the most far point: 34
# send courier on [135  51]
# Payment: 365, salary: 438
# 7106 points left
# current time 798. Passing order 422
#
# 40658
# --------------------------------------------------------------------------------
# courier 113 begins route at [291, 136]
# processing courier 423..
#
# current time 360. Passing order 424
#
# the most far point: 17
# send courier on [135  51]
# Payment: 266, salary: 261
# 7105 points left
# current time 621. Passing order 425
#
# the most far point: 24
# send courier on [135  51]
# Payment: 528, salary: 364
# 7104 points left
# current time 985. Passing order 426
#
# 41186
# --------------------------------------------------------------------------------
# courier 114 begins route at [316, 104]
# processing courier 427..
#
# current time 360. Passing order 428
#
# the most far point: 18
# send courier on [135  51]
# Payment: 373, salary: 276
# 7103 points left
# current time 636. Passing order 429
#
# the most far point: 54
# send courier on [135  51]
# Payment: 447, salary: 364
# 7102 points left
# current time 1000. Passing order 430
#
# 41633
# --------------------------------------------------------------------------------
# courier 115 begins route at [111, 214]
# processing courier 431..
#
# current time 360. Passing order 432
#
# the most far point: 18
# send courier on [135  51]
# Payment: 316, salary: 423
# 7101 points left
# current time 783. Passing order 433
#
# 41949
# --------------------------------------------------------------------------------
# courier 116 begins route at [200, 78]
# processing courier 434..
#
# current time 360. Passing order 435
#
# the most far point: 16
# send courier on [135  51]
# Payment: 335, salary: 272
# 7100 points left
# ...
# courier 263 begins route at [210, 81]
# processing courier 982..
#
# current time 360. Passing order 983
#
# the most far point: 12
# send courier on [135  51]
# Payment: 500, salary: 259
# 6846 points left
# current time 619. Passing order 984
#
# the most far point: 37
# send courier on [135  51]
# Payment: 550, salary: 364
# 6845 points left
# current time 983. Passing order 985
#
# 98369
# --------------------------------------------------------------------------------
# courier 264 begins route at [81, 224]
# processing courier 986..
#
# current time 360. Passing order 987
#
# the most far point: 29
# send courier on [135  51]
# Payment: 339, salary: 463
# 6844 points left
# current time 823. Passing order 988
#
# 98708
# --------------------------------------------------------------------------------
# courier 265 begins route at [364, 158]
# processing courier 989..
#
# current time 360. Passing order 990
#
# the most far point: 14
# send courier on [135  51]
# Payment: 298, salary: 356
# 6843 points left
# current time 716. Passing order 991
#
# 99006
# --------------------------------------------------------------------------------
# courier 266 begins route at [256, 93]
# processing courier 992..
#
# current time 360. Passing order 993
#
# the most far point: 21
# send courier on [135  51]
# Payment: 385, salary: 227
# 6842 points left
# current time 587. Passing order 994
#
# the most far point: 48
# send courier on [135  51]
# Payment: 422, salary: 364
# 6841 points left
# current time 951. Passing order 995
#
# 99428
# --------------------------------------------------------------------------------
# courier 267 begins route at [69, 9]
# processing courier 996..
#
# current time 360. Passing order 997
#
# the most far point: 36
# send courier on [135  51]
# Payment: 397, salary: 472
# 6840 points left
# current time 832. Passing order 998
#
# 99825
# --------------------------------------------------------------------------------
# courier 268 begins route at [137, 134]
# processing courier 999..
#
# current time 360. Passing order 1000
#
# the most far point: 13
# send courier on [135  51]
# Payment: 373, salary: 317
# 6839 points left
# current time 677. Passing order 1001
#
# 100198
# --------------------------------------------------------------------------------
# courier 269 begins route at [195, 116]
# processing courier 1002..
#
# current time 360. Passing order 1003
#
# the most far point: 13
# send courier on [135  51]
# Payment: 385, salary: 241
# 6838 points left
# current time 601. Passing order 1004
#
# the most far point: 41
# send courier on [135  51]
# Payment: 403, salary: 364
# 6837 points left
# current time 965. Passing order 1005
#
# 100601
# --------------------------------------------------------------------------------
# courier 270 begins route at [292, 146]
# processing courier 1006..
#
# current time 360. Passing order 1007
#
# the most far point: 21
# send courier on [135  51]
# Payment: 340, salary: 272
# 6836 points left
# current time 632. Passing order 1008
#
# the most far point: 87
# send courier on [135  51]
# Payment: 307, salary: 364
# 6835 points left
# current time 996. Passing order 1009
#
# 100908
# --------------------------------------------------------------------------------
# courier 271 begins route at [267, 77]
# processing courier 1010..
#
# current time 360. Passing order 1011
#
# the most far point: 11
# send courier on [135  51]
# Payment: 250, salary: 254
# 6834 points left
# current time 614. Passing order 1012
#
# the most far point: 94
# send courier on [135  51]
# Payment: 704, salary: 364
# 6833 points left
# current time 978. Passing order 1013
#
# 101612
# --------------------------------------------------------------------------------
# courier 272 begins route at [319, 113]
# processing courier 1014..
#
# current time 360. Passing order 1015
#
# the most far point: 19
# send courier on [135  51]
# Payment: 223, salary: 270
# 6832 points left
# current time 630. Passing order 1016
#
# the most far point: 20
# send courier on [135  51]
# Payment: 568, salary: 364
# 6831 points left
# current time 994. Passing order 1017
#
# 102180
# --------------------------------------------------------------------------------
# courier 273 begins route at [206, 286]
# processing courier 1018..
#
# current time 360. Passing order 1019
#
# the most far point: 40
# send courier on [135  51]
# Payment: 369, salary: 400
# 6830 points left
# current time 760. Passing order 1020
# the most far point: 282
# send courier on [135  51]
# Payment: 265, salary: 364
# 6829 points left
# current time 1124. Passing order 1021
#
# 102445
# --------------------------------------------------------------------------------
# courier 274 begins route at [238, 86]
# processing courier 1022..
#
# current time 360. Passing order 1023
#
# the most far point: 13
# send courier on [135  51]
# Payment: 474, salary: 226
# 6828 points left
# current time 586. Passing order 1024
#
# the most far point: 45
# send courier on [135  51]
# Payment: 357, salary: 364
# 6827 points left
# current time 950. Passing order 1025
#
# 102802
# --------------------------------------------------------------------------------
# courier 275 begins route at [235, 116]
# processing courier 1026..
#
# current time 360. Passing order 1027
#
# the most far point: 11
# send courier on [135  51]
# Payment: 394, salary: 201
# 6826 points left
# current time 561. Passing order 1028
#
# the most far point: 31
# send courier on [135  51]
# Payment: 283, salary: 364
# 6825 points left
# current time 925. Passing order 1029
#
# 103085
# --------------------------------------------------------------------------------
# courier 276 begins route at [282, 121]
# processing courier 1030..
#
# current time 360. Passing order 1031
#
# the most far point: 13
# send courier on [135  51]
# Payment: 554, salary: 237
# 6824 points left
# current time 597. Passing order 1032
#
# the most far point: 72
# send courier on [135  51]
# Payment: 487, salary: 364
# 6823 points left
# current time 961. Passing order 1033
#
# the most far point: 65
# send courier on [135  51]
# Payment: 210, salary: 364
# 6822 points left
# current time 1325. Passing order 1034
#
# 103295
# --------------------------------------------------------------------------------
# courier 277 begins route at [283, 204]
# processing courier 1035..
#
# current time 360. Passing order 1036
#
# the most far point: 14
# send courier on [135  51]
# Payment: 430, salary: 321
# 6821 points left
# current time 681. Passing order 1037
#
# 103725
# --------------------------------------------------------------------------------
# courier 278 begins route at [210, 81]
# processing courier 1038..
#
# current time 360. Passing order 1039
#
# the most far point: 12
# send courier on [135  51]
# Payment: 364, salary: 259
# 6820 points left
# current time 619. Passing order 1040
#
# the most far point: 37
# send courier on [135  51]
# Payment: 442, salary: 364
# 6819 points left
# current time 983. Passing order 1041
#
# 104167
# --------------------------------------------------------------------------------
# courier 279 begins route at [255, 170]
# processing courier 1042..
#
# current time 360. Passing order 1043
#
# the most far point: 13
# send courier on [135  51]
# Payment: 430, salary: 259
# 6818 points left
# current time 619. Passing order 1044
#
# the most far point: 27
# send courier on [135  51]
# Payment: 329, salary: 364
# 6817 points left
# current time 983. Passing order 1045
#
# 104496
# --------------------------------------------------------------------------------
# courier 280 begins route at [131, 160]
# processing courier 1046..
#
# current time 360. Passing order 1047
#
# the most far point: 16
# send courier on [135  51]
# Payment: 483, salary: 349
# 6816 points left
# current time 709. Passing order 1048
#
# 104979
# --------------------------------------------------------------------------------
# courier 281 begins route at [255, 59]
# processing courier 1049..
#
# current time 360. Passing order 1050
#
# the most far point: 13
# send courier on [135  51]
# Payment: 380, salary: 260
# 6815 points left
# current time 620. Passing order 1051
#
# the most far point: 39
# send courier on [135  51]
# Payment: 704, salary: 364
# 6814 points left
# current time 984. Passing order 1052
#
# 105683
# --------------------------------------------------------------------------------
# courier 282 begins route at [319, 113]
# processing courier 1053..
#
# current time 360. Passing order 1054
#
# the most far point: 19
# send courier on [135  51]
# Payment: 674, salary: 270
# 6813 points left
# current time 630. Passing order 1055
#
# the most far point: 20
# send courier on [135  51]
# Payment: 250, salary: 364
# 6812 points left
# current time 994. Passing order 1056
#
# 105933
# --------------------------------------------------------------------------------
# courier 283 begins route at [228, 95]
# processing courier 1057..
#
# current time 360. Passing order 1058
#
# the most far point: 14
# send courier on [135  51]
# Payment: 290, salary: 227
# 6811 points left
# current time 587. Passing order 1059
#
# the most far point: 54
# send courier on [135  51]
# Payment: 420, salary: 364
# 6810 points left
# current time 951. Passing order 1060
#
# 106353
# --------------------------------------------------------------------------------
# courier 284 begins route at [96, 39]
# processing courier 1061..
#
# current time 360. Passing order 1062
#
# the most far point: 15
# send courier on [135  51]
# Payment: 220, salary: 415
# 6809 points left
# current time 775. Passing order 1063
#
# 106573
# --------------------------------------------------------------------------------
# courier 285 begins route at [51, 77]
# processing courier 1064..
#
# current time 360. Passing order 1065
#
# the most far point: 18
# send courier on [135  51]
# Payment: 271, salary: 422
# 6808 points left
# current time 782. Passing order 1066
#
# 106844
# --------------------------------------------------------------------------------
# courier 286 begins route at [199, 87]
# processing courier 1067..
#
# current time 360. Passing order 1068
#
# the most far point: 14
# send courier on [135  51]
# Payment: 476, salary: 264
# 6807 points left
# current time 624. Passing order 1069
#
# the most far point: 36
# send courier on [135  51]
# Payment: 309, salary: 364
# 6806 points left
# current time 988. Passing order 1070
#
# the most far point: 88
# send courier on [135  51]
# Payment: 662, salary: 364
# 6805 points left
# current time 1352. Passing order 1071
#
# 107506
# --------------------------------------------------------------------------------
# courier 287 begins route at [191, 161]
# processing courier 1072..
#
# current time 360. Passing order 1073
#
# the most far point: 13
# send courier on [135  51]
# Payment: 315, salary: 290
# 6804 points left
# current time 650. Passing order 1074
#
# the most far point: 59
# send courier on [135  51]
# Payment: 389, salary: 364
# 6803 points left
# current time 1014. Passing order 1075
#
# the most far point: 203
# send courier on [135  51]
# Payment: 474, salary: 364
# 6802 points left
# current time 1378. Passing order 1076
#
# 107980
# --------------------------------------------------------------------------------
# courier 288 begins route at [81, 20]
# processing courier 1077..
#
# current time 360. Passing order 1078
#
# the most far point: 13
# send courier on [135  51]
# Payment: 254, salary: 449
# 6801 points left
# current time 809. Passing order 1079
#
# 108234
# --------------------------------------------------------------------------------
# courier 289 begins route at [207, 66]
# processing courier 1080..
#
# current time 360. Passing order 1081
#
# the most far point: 17
# send courier on [135  51]
# Payment: 408, salary: 277
# 6800 points left
# current time 637. Passing order 1082
#
# the most far point: 93
# send courier on [135  51]
# Payment: 378, salary: 364
# 6799 points left
# current time 1001. Passing order 1083
#
# 108612
# --------------------------------------------------------------------------------
# courier 290 begins route at [233, 117]
# processing courier 1084..
#
# current time 360. Passing order 1085
#
# the most far point: 13
# send courier on [135  51]
# Payment: 475, salary: 204
# 6798 points left
# current time 564. Passing order 1086
#
# the most far point: 17
# send courier on [135  51]
# Payment: 310, salary: 364
# 6797 points left
# current time 928. Passing order 1087
#
# 108922
# --------------------------------------------------------------------------------
# courier 291 begins route at [241, 155]
# processing courier 1088..
#
# current time 360. Passing order 1089
#
# the most far point: 13
# send courier on [135  51]
# Payment: 386, salary: 234
# 6796 points left
# current time 594. Passing order 1090
#
# the most far point: 27
# send courier on [135  51]
# Payment: 573, salary: 364
# 6795 points left
# current time 958. Passing order 1091
#
# 109495
# --------------------------------------------------------------------------------
# courier 292 begins route at [220, 131]
# processing courier 1092..
#
# current time 360. Passing order 1093
#
# the most far point: 12
# send courier on [135  51]
# Payment: 393, salary: 231
# 6794 points left
# current time 591. Passing order 1094
#
# the most far point: 23
# send courier on [135  51]
# Payment: 411, salary: 364
# 6793 points left
# current time 955. Passing order 1095
#
# 109906
# --------------------------------------------------------------------------------
# courier 293 begins route at [102, 119]
# processing courier 1096..
#
# current time 360. Passing order 1097
#
# the most far point: 12
# send courier on [135  51]
# Payment: 458, salary: 337
# 6792 points left
# current time 697. Passing order 1098
# 110364
# --------------------------------------------------------------------------------
# courier 294 begins route at [258, 93]
# processing courier 1099..
#
# current time 360. Passing order 1100
#
# the most far point: 20
# send courier on [135  51]
# Payment: 445, salary: 229
# 6791 points left
# current time 589. Passing order 1101
#
# the most far point: 46
# send courier on [135  51]
# Payment: 497, salary: 364
# 6790 points left
# current time 953. Passing order 1102
#
# the most far point: 199
# send courier on [135  51]
# Payment: 377, salary: 364
# 6789 points left
# current time 1317. Passing order 1103
#
# 110741
# --------------------------------------------------------------------------------
# courier 295 begins route at [266, 56]
# processing courier 1104..
#
# current time 360. Passing order 1105
#
# the most far point: 21
# send courier on [135  51]
# Payment: 505, salary: 274
# 6788 points left
# current time 634. Passing order 1106
#
# the most far point: 37
# send courier on [135  51]
# Payment: 230, salary: 364
# 6787 points left
# current time 998. Passing order 1107
#
# 110971
# --------------------------------------------------------------------------------
# courier 296 begins route at [214, 124]
# processing courier 1108..
#
# current time 360. Passing order 1109
#
# the most far point: 13
# send courier on [135  51]
# Payment: 250, salary: 230
# 6786 points left
# current time 590. Passing order 1110
#
# the most far point: 34
# send courier on [135  51]
# Payment: 340, salary: 364
# 6785 points left
# current time 954. Passing order 1111
#
# the most far point: 41
# send courier on [135  51]
# Payment: 457, salary: 364
# 6784 points left
# current time 1318. Passing order 1112
#
# 111428
# --------------------------------------------------------------------------------
# courier 297 begins route at [229, 143]
# processing courier 1113..
#
# current time 360. Passing order 1114
#
# the most far point: 14
# send courier on [135  51]
# Payment: 312, salary: 234
# 6783 points left
# current time 594. Passing order 1115
#
# the most far point: 27
# send courier on [135  51]
# Payment: 250, salary: 364
# 6782 points left
# current time 958. Passing order 1116
#
# 111678
# --------------------------------------------------------------------------------
# courier 298 begins route at [106, 150]
# processing courier 1117..
#
# current time 360. Passing order 1118
#
# the most far point: 13
# send courier on [135  51]
# Payment: 305, salary: 364
# 6781 points left
# current time 724. Passing order 1119
#
# 111983
# --------------------------------------------------------------------------------
# courier 299 begins route at [220, 131]
# processing courier 1120..
#
# current time 360. Passing order 1121
#
# the most far point: 12
# send courier on [135  51]
# Payment: 370, salary: 231
# 6780 points left
# current time 591. Passing order 1122
#
# the most far point: 23
# send courier on [135  51]
# Payment: 260, salary: 364
# 6779 points left
# current time 955. Passing order 1123
#
# 112243
# --------------------------------------------------------------------------------
# total reward: 111053

# %%
routes = routes[0]

# %%
routes_dict = dict({})

# %%
routes_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-90e6eb951194> in <module>
#       1 with open('output.json', 'w', encoding='utf-8') as f:
# ----> 2     json.dump(routes, f, ensure_ascii=False, indent=4)
#
# /anaconda3/lib/python3.6/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /anaconda3/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     426             yield _floatstr(o)
#     427         elif isinstance(o, (list, tuple)):
# --> 428             yield from _iterencode_list(o, _current_indent_level)
#     429         elif isinstance(o, dict):
#     430             yield from _iterencode_dict(o, _current_indent_level)
#
# /anaconda3/lib/python3.6/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# /anaconda3/lib/python3.6/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# /anaconda3/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
#     439             if markers is not None:
#
# /anaconda3/lib/python3.6/json/encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'int64' is not JSON serializable
